# %%
#Predicting label image from entire folder #Numpy #x,y,z,depth,intensity

import os
import torch
import numpy as np
from model import Darknet
import time

def process_lidar_intensity(lidar_path, intensity_path, x_path, y_path, z_path, model, device, trial):
    # Load the lidar data (depth)
    lidar = np.load(lidar_path)
    lidar = np.expand_dims(lidar, axis=0)  # Add channel dimension
    lidar = torch.from_numpy(lidar).float().to(device)

    # Load the intensity data
    intensity = np.load(intensity_path)
    intensity = np.expand_dims(intensity, axis=0)  # Add channel dimension
    intensity = torch.from_numpy(intensity).float().to(device)

    # Load the x coordinate data
    x = np.load(x_path)
    x = np.expand_dims(x, axis=0)  # Add channel dimension
    x = torch.from_numpy(x).float().to(device)

    # Load the y coordinate data
    y = np.load(y_path)
    y = np.expand_dims(y, axis=0)  # Add channel dimension
    y = torch.from_numpy(y).float().to(device)

    # Load the z coordinate data
    z = np.load(z_path)
    z = np.expand_dims(z, axis=0)  # Add channel dimension
    z = torch.from_numpy(z).float().to(device)

    # Concatenate the lidar (depth), intensity, x, y, and z data
    input_data = torch.cat((x, y, z, lidar, intensity), dim=0) 

    # Add a batch dimension
    input_data = input_data.unsqueeze(0)

    # Perform inference
    with torch.no_grad():
        output = model(input_data)

    output = output.squeeze(dim=0)

    # Move the output tensor to CPU and convert to numpy array
    output_array = output.cpu().numpy()

    # Find the class with the highest probability for each pixel
    output_array = np.argmax(output_array, axis=0)

    return output_array


trial = "T2"
in_channel = 5
intensity_type = "lidar_intensity"
#intensity_type = "lidar_cycle_intensity"

# Define the paths to the folders containing lidar, intensity, and xyz images
base_path = "/DATA2/Vivek/Data/Downstream Task/Test/"

#base_path = "/DATA2/Vivek/Data/Downstream Task/Test/"

lidar_folder = os.path.join(base_path, "test_lidar_depth")
intensity_folder = os.path.join(base_path, f"test_{intensity_type}")
x_folder = os.path.join(base_path, "test_lidar_x")
y_folder = os.path.join(base_path, "test_lidar_y")
z_folder = os.path.join(base_path, "test_lidar_z")

output_folder = f"/DATA2/Vivek/Code/Implementation/Downstream_Task/RangeNet++/Mix_Training/Output_2.0/{trial}/Pred_Image"  # Specify the output folder path

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Initialize your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Darknet(in_channels=in_channel, out_channels=20)  # Update in_channels to 5 (depth + intensity + x + y + z)
checkpoint = torch.load(f'/DATA2/Vivek/Code/Implementation/Downstream_Task/RangeNet++/Mix_Training/Output_2.0/{trial}/{trial}_model.pth.tar')
model.load_state_dict(checkpoint['state_dict'])
model.to(device)
model.eval()  # Switch the model to evaluation mode

# Iterate through the files in the folders
lidar_files = [f for f in os.listdir(lidar_folder) if f.endswith(".npy")]
total_files = len(lidar_files)
start_time = time.time()

for idx, lidar_file in enumerate(lidar_files, start=1):
    lidar_path = os.path.join(lidar_folder, lidar_file)
    intensity_file = lidar_file.replace("depth", "intensity")
    intensity_path = os.path.join(intensity_folder, intensity_file)
    x_file = lidar_file.replace("depth", "x")
    x_path = os.path.join(x_folder, x_file)
    y_file = lidar_file.replace("depth", "y")
    y_path = os.path.join(y_folder, y_file)
    z_file = lidar_file.replace("depth", "z")
    z_path = os.path.join(z_folder, z_file)

    # Process lidar, intensity, and xyz data
    output_array = process_lidar_intensity(lidar_path, intensity_path, x_path, y_path, z_path, model, device, trial=trial)

    # Save output array to .npy file in the output folder
    output_filename = os.path.splitext(lidar_file)[0] + ".npy"
    output_filepath = os.path.join(output_folder, output_filename)
    np.save(output_filepath, output_array)

    # Calculate and print progress and estimated remaining time
    elapsed_time = time.time() - start_time
    avg_time_per_file = elapsed_time / idx
    remaining_time = avg_time_per_file * (total_files - idx)
    print(f"Processed {idx}/{total_files} files. Estimated time remaining: {remaining_time:.2f} seconds.")

print("Processing completed.")
# Out:
# Processed 1/2000 files. Estimated time remaining: 100.27 seconds.
# Processed 2/2000 files. Estimated time remaining: 195.12 seconds.
# Processed 3/2000 files. Estimated time remaining: 254.03 seconds.
# Processed 4/2000 files. Estimated time remaining: 281.83 seconds.
# Processed 5/2000 files. Estimated time remaining: 299.17 seconds.
# Processed 6/2000 files. Estimated time remaining: 310.78 seconds.
# Processed 7/2000 files. Estimated time remaining: 318.08 seconds.
# Processed 8/2000 files. Estimated time remaining: 322.48 seconds.
# Processed 9/2000 files. Estimated time remaining: 326.07 seconds.
# Processed 10/2000 files. Estimated time remaining: 328.91 seconds.
# Processed 11/2000 files. Estimated time remaining: 330.73 seconds.
# Processed 12/2000 files. Estimated time remaining: 332.09 seconds.
# Processed 13/2000 files. Estimated time remaining: 334.00 seconds.
# Processed 14/2000 files. Estimated time remaining: 336.06 seconds.
# Processed 15/2000 files. Estimated time remaining: 338.34 seconds.
# Processed 16/2000 files. Estimated time remaining: 340.12 seconds.
# Processed 17/2000 files. Estimated time remaining: 340.80 seconds.
# Processed 18/2000 files. Estimated time remaining: 341.60 seconds.
# Processed 19/2000 files. Estimated time remaining: 342.80 seconds.
# Processed 20/2000 files. Estimated time remaining: 344.06 seconds.
# Processed 21/2000 files. Estimated time remaining: 344.03 seconds.
# Processed 22/2000 files. Estimated time remaining: 344.69 seconds.
# Processed 23/2000 files. Estimated time remaining: 346.27 seconds.
# Processed 24/2000 files. Estimated time remaining: 346.91 seconds.
# Processed 25/2000 files. Estimated time remaining: 346.45 seconds.
# Processed 26/2000 files. Estimated time remaining: 346.52 seconds.
# Processed 27/2000 files. Estimated time remaining: 347.57 seconds.
# Processed 28/2000 files. Estimated time remaining: 347.68 seconds.
# Processed 29/2000 files. Estimated time remaining: 347.32 seconds.
# Processed 30/2000 files. Estimated time remaining: 347.77 seconds.
# Processed 31/2000 files. Estimated time remaining: 347.62 seconds.
# Processed 32/2000 files. Estimated time remaining: 347.57 seconds.
# Processed 33/2000 files. Estimated time remaining: 348.31 seconds.
# Processed 34/2000 files. Estimated time remaining: 347.96 seconds.
# Processed 35/2000 files. Estimated time remaining: 348.40 seconds.
# Processed 36/2000 files. Estimated time remaining: 348.83 seconds.
# Processed 37/2000 files. Estimated time remaining: 349.00 seconds.
# Processed 38/2000 files. Estimated time remaining: 349.03 seconds.
# Processed 39/2000 files. Estimated time remaining: 349.21 seconds.
# Processed 40/2000 files. Estimated time remaining: 349.12 seconds.
# Processed 41/2000 files. Estimated time remaining: 348.79 seconds.
# Processed 42/2000 files. Estimated time remaining: 349.18 seconds.
# Processed 43/2000 files. Estimated time remaining: 348.84 seconds.
# Processed 44/2000 files. Estimated time remaining: 348.69 seconds.
# Processed 45/2000 files. Estimated time remaining: 348.52 seconds.
# Processed 46/2000 files. Estimated time remaining: 348.90 seconds.
# Processed 47/2000 files. Estimated time remaining: 349.08 seconds.
# Processed 48/2000 files. Estimated time remaining: 349.17 seconds.
# Processed 49/2000 files. Estimated time remaining: 349.27 seconds.
# Processed 50/2000 files. Estimated time remaining: 348.98 seconds.
# Processed 51/2000 files. Estimated time remaining: 348.79 seconds.
# Processed 52/2000 files. Estimated time remaining: 348.96 seconds.
# Processed 53/2000 files. Estimated time remaining: 348.82 seconds.
# Processed 54/2000 files. Estimated time remaining: 348.94 seconds.
# Processed 55/2000 files. Estimated time remaining: 348.62 seconds.
# Processed 56/2000 files. Estimated time remaining: 348.57 seconds.
# Processed 57/2000 files. Estimated time remaining: 348.33 seconds.
# Processed 58/2000 files. Estimated time remaining: 348.93 seconds.
# Processed 59/2000 files. Estimated time remaining: 349.09 seconds.
# Processed 60/2000 files. Estimated time remaining: 349.12 seconds.
# Processed 61/2000 files. Estimated time remaining: 349.13 seconds.
# Processed 62/2000 files. Estimated time remaining: 349.12 seconds.
# Processed 63/2000 files. Estimated time remaining: 348.99 seconds.
# Processed 64/2000 files. Estimated time remaining: 348.82 seconds.
# Processed 65/2000 files. Estimated time remaining: 348.94 seconds.
# Processed 66/2000 files. Estimated time remaining: 348.80 seconds.
# Processed 67/2000 files. Estimated time remaining: 348.58 seconds.
# Processed 68/2000 files. Estimated time remaining: 348.49 seconds.
# Processed 69/2000 files. Estimated time remaining: 347.95 seconds.
# Processed 70/2000 files. Estimated time remaining: 348.03 seconds.
# Processed 71/2000 files. Estimated time remaining: 347.86 seconds.
# Processed 72/2000 files. Estimated time remaining: 347.86 seconds.
# Processed 73/2000 files. Estimated time remaining: 347.70 seconds.
# Processed 74/2000 files. Estimated time remaining: 347.58 seconds.
# Processed 75/2000 files. Estimated time remaining: 347.47 seconds.
# Processed 76/2000 files. Estimated time remaining: 347.45 seconds.
# Processed 77/2000 files. Estimated time remaining: 347.54 seconds.
# Processed 78/2000 files. Estimated time remaining: 347.68 seconds.
# Processed 79/2000 files. Estimated time remaining: 347.41 seconds.
# Processed 80/2000 files. Estimated time remaining: 347.39 seconds.
# Processed 81/2000 files. Estimated time remaining: 347.23 seconds.
# Processed 82/2000 files. Estimated time remaining: 347.01 seconds.
# Processed 83/2000 files. Estimated time remaining: 346.91 seconds.
# Processed 84/2000 files. Estimated time remaining: 346.82 seconds.
# Processed 85/2000 files. Estimated time remaining: 346.73 seconds.
# Processed 86/2000 files. Estimated time remaining: 346.54 seconds.
# Processed 87/2000 files. Estimated time remaining: 346.14 seconds.
# Processed 88/2000 files. Estimated time remaining: 346.13 seconds.
# Processed 89/2000 files. Estimated time remaining: 346.02 seconds.
# Processed 90/2000 files. Estimated time remaining: 345.77 seconds.
# Processed 91/2000 files. Estimated time remaining: 345.50 seconds.
# Processed 92/2000 files. Estimated time remaining: 345.32 seconds.
# Processed 93/2000 files. Estimated time remaining: 345.40 seconds.
# Processed 94/2000 files. Estimated time remaining: 345.25 seconds.
# Processed 95/2000 files. Estimated time remaining: 345.13 seconds.
# Processed 96/2000 files. Estimated time remaining: 345.11 seconds.
# Processed 97/2000 files. Estimated time remaining: 345.16 seconds.
# Processed 98/2000 files. Estimated time remaining: 345.19 seconds.
# Processed 99/2000 files. Estimated time remaining: 345.05 seconds.
# Processed 100/2000 files. Estimated time remaining: 345.25 seconds.
# Processed 101/2000 files. Estimated time remaining: 345.16 seconds.
# Processed 102/2000 files. Estimated time remaining: 345.03 seconds.
# Processed 103/2000 files. Estimated time remaining: 344.82 seconds.
# Processed 104/2000 files. Estimated time remaining: 344.65 seconds.
# Processed 105/2000 files. Estimated time remaining: 344.37 seconds.
# Processed 106/2000 files. Estimated time remaining: 344.11 seconds.
# Processed 107/2000 files. Estimated time remaining: 343.98 seconds.
# Processed 108/2000 files. Estimated time remaining: 343.78 seconds.
# Processed 109/2000 files. Estimated time remaining: 343.57 seconds.
# Processed 110/2000 files. Estimated time remaining: 343.40 seconds.
# Processed 111/2000 files. Estimated time remaining: 343.16 seconds.
# Processed 112/2000 files. Estimated time remaining: 342.85 seconds.
# Processed 113/2000 files. Estimated time remaining: 342.61 seconds.
# Processed 114/2000 files. Estimated time remaining: 342.56 seconds.
# Processed 115/2000 files. Estimated time remaining: 342.42 seconds.
# Processed 116/2000 files. Estimated time remaining: 342.40 seconds.
# Processed 117/2000 files. Estimated time remaining: 342.18 seconds.
# Processed 118/2000 files. Estimated time remaining: 342.20 seconds.
# Processed 119/2000 files. Estimated time remaining: 342.14 seconds.
# Processed 120/2000 files. Estimated time remaining: 342.07 seconds.
# Processed 121/2000 files. Estimated time remaining: 341.99 seconds.
# Processed 122/2000 files. Estimated time remaining: 341.94 seconds.
# Processed 123/2000 files. Estimated time remaining: 341.67 seconds.
# Processed 124/2000 files. Estimated time remaining: 341.44 seconds.
# Processed 125/2000 files. Estimated time remaining: 341.30 seconds.
# Processed 126/2000 files. Estimated time remaining: 341.14 seconds.
# Processed 127/2000 files. Estimated time remaining: 340.95 seconds.
# Processed 128/2000 files. Estimated time remaining: 340.79 seconds.
# Processed 129/2000 files. Estimated time remaining: 340.54 seconds.
# Processed 130/2000 files. Estimated time remaining: 340.23 seconds.
# Processed 131/2000 files. Estimated time remaining: 340.02 seconds.
# Processed 132/2000 files. Estimated time remaining: 339.81 seconds.
# Processed 133/2000 files. Estimated time remaining: 339.61 seconds.
# Processed 134/2000 files. Estimated time remaining: 339.43 seconds.
# Processed 135/2000 files. Estimated time remaining: 339.26 seconds.
# Processed 136/2000 files. Estimated time remaining: 339.17 seconds.
# Processed 137/2000 files. Estimated time remaining: 339.01 seconds.
# Processed 138/2000 files. Estimated time remaining: 338.81 seconds.
# Processed 139/2000 files. Estimated time remaining: 338.70 seconds.
# Processed 140/2000 files. Estimated time remaining: 338.53 seconds.
# Processed 141/2000 files. Estimated time remaining: 338.33 seconds.
# Processed 142/2000 files. Estimated time remaining: 338.23 seconds.
# Processed 143/2000 files. Estimated time remaining: 338.13 seconds.
# Processed 144/2000 files. Estimated time remaining: 337.88 seconds.
# Processed 145/2000 files. Estimated time remaining: 337.74 seconds.
# Processed 146/2000 files. Estimated time remaining: 337.50 seconds.
# Processed 147/2000 files. Estimated time remaining: 337.28 seconds.
# Processed 148/2000 files. Estimated time remaining: 337.07 seconds.
# Processed 149/2000 files. Estimated time remaining: 336.91 seconds.
# Processed 150/2000 files. Estimated time remaining: 336.71 seconds.
# Processed 151/2000 files. Estimated time remaining: 336.51 seconds.
# Processed 152/2000 files. Estimated time remaining: 336.31 seconds.
# Processed 153/2000 files. Estimated time remaining: 336.14 seconds.
# Processed 154/2000 files. Estimated time remaining: 335.90 seconds.
# Processed 155/2000 files. Estimated time remaining: 335.76 seconds.
# Processed 156/2000 files. Estimated time remaining: 335.62 seconds.
# Processed 157/2000 files. Estimated time remaining: 335.50 seconds.
# Processed 158/2000 files. Estimated time remaining: 335.29 seconds.
# Processed 159/2000 files. Estimated time remaining: 335.06 seconds.
# Processed 160/2000 files. Estimated time remaining: 334.77 seconds.
# Processed 161/2000 files. Estimated time remaining: 334.55 seconds.
# Processed 162/2000 files. Estimated time remaining: 334.38 seconds.
# Processed 163/2000 files. Estimated time remaining: 334.23 seconds.
# Processed 164/2000 files. Estimated time remaining: 334.09 seconds.
# Processed 165/2000 files. Estimated time remaining: 333.98 seconds.
# Processed 166/2000 files. Estimated time remaining: 333.83 seconds.
# Processed 167/2000 files. Estimated time remaining: 333.63 seconds.
# Processed 168/2000 files. Estimated time remaining: 333.45 seconds.
# Processed 169/2000 files. Estimated time remaining: 333.30 seconds.
# Processed 170/2000 files. Estimated time remaining: 333.13 seconds.
# Processed 171/2000 files. Estimated time remaining: 332.91 seconds.
# Processed 172/2000 files. Estimated time remaining: 332.58 seconds.
# Processed 173/2000 files. Estimated time remaining: 332.38 seconds.
# Processed 174/2000 files. Estimated time remaining: 332.11 seconds.
# Processed 175/2000 files. Estimated time remaining: 331.87 seconds.
# Processed 176/2000 files. Estimated time remaining: 331.74 seconds.
# Processed 177/2000 files. Estimated time remaining: 331.60 seconds.
# Processed 178/2000 files. Estimated time remaining: 331.43 seconds.
# Processed 179/2000 files. Estimated time remaining: 331.13 seconds.
# Processed 180/2000 files. Estimated time remaining: 330.92 seconds.
# Processed 181/2000 files. Estimated time remaining: 330.80 seconds.
# Processed 182/2000 files. Estimated time remaining: 330.57 seconds.
# Processed 183/2000 files. Estimated time remaining: 330.31 seconds.
# Processed 184/2000 files. Estimated time remaining: 330.05 seconds.
# Processed 185/2000 files. Estimated time remaining: 329.89 seconds.
# Processed 186/2000 files. Estimated time remaining: 329.75 seconds.
# Processed 187/2000 files. Estimated time remaining: 329.56 seconds.
# Processed 188/2000 files. Estimated time remaining: 329.35 seconds.
# Processed 189/2000 files. Estimated time remaining: 329.19 seconds.
# Processed 190/2000 files. Estimated time remaining: 328.91 seconds.
# Processed 191/2000 files. Estimated time remaining: 328.70 seconds.
# Processed 192/2000 files. Estimated time remaining: 328.50 seconds.
# Processed 193/2000 files. Estimated time remaining: 328.31 seconds.
# Processed 194/2000 files. Estimated time remaining: 328.08 seconds.
# Processed 195/2000 files. Estimated time remaining: 327.89 seconds.
# Processed 196/2000 files. Estimated time remaining: 327.68 seconds.
# Processed 197/2000 files. Estimated time remaining: 327.53 seconds.
# Processed 198/2000 files. Estimated time remaining: 327.30 seconds.
# Processed 199/2000 files. Estimated time remaining: 327.13 seconds.
# Processed 200/2000 files. Estimated time remaining: 326.91 seconds.
# Processed 201/2000 files. Estimated time remaining: 326.82 seconds.
# Processed 202/2000 files. Estimated time remaining: 326.72 seconds.
# Processed 203/2000 files. Estimated time remaining: 326.49 seconds.
# Processed 204/2000 files. Estimated time remaining: 326.28 seconds.
# Processed 205/2000 files. Estimated time remaining: 326.18 seconds.
# Processed 206/2000 files. Estimated time remaining: 326.03 seconds.
# Processed 207/2000 files. Estimated time remaining: 325.79 seconds.
# Processed 208/2000 files. Estimated time remaining: 325.58 seconds.
# Processed 209/2000 files. Estimated time remaining: 325.38 seconds.
# Processed 210/2000 files. Estimated time remaining: 325.24 seconds.
# Processed 211/2000 files. Estimated time remaining: 325.07 seconds.
# Processed 212/2000 files. Estimated time remaining: 324.93 seconds.
# Processed 213/2000 files. Estimated time remaining: 324.71 seconds.
# Processed 214/2000 files. Estimated time remaining: 324.48 seconds.
# Processed 215/2000 files. Estimated time remaining: 324.31 seconds.
# Processed 216/2000 files. Estimated time remaining: 324.07 seconds.
# Processed 217/2000 files. Estimated time remaining: 323.87 seconds.
# Processed 218/2000 files. Estimated time remaining: 323.70 seconds.
# Processed 219/2000 files. Estimated time remaining: 323.60 seconds.
# Processed 220/2000 files. Estimated time remaining: 323.51 seconds.
# Processed 221/2000 files. Estimated time remaining: 323.35 seconds.
# Processed 222/2000 files. Estimated time remaining: 323.45 seconds.
# Processed 223/2000 files. Estimated time remaining: 323.31 seconds.
# Processed 224/2000 files. Estimated time remaining: 323.16 seconds.
# Processed 225/2000 files. Estimated time remaining: 323.12 seconds.
# Processed 226/2000 files. Estimated time remaining: 322.90 seconds.
# Processed 227/2000 files. Estimated time remaining: 322.73 seconds.
# Processed 228/2000 files. Estimated time remaining: 322.63 seconds.
# Processed 229/2000 files. Estimated time remaining: 322.53 seconds.
# Processed 230/2000 files. Estimated time remaining: 322.40 seconds.
# Processed 231/2000 files. Estimated time remaining: 322.25 seconds.
# Processed 232/2000 files. Estimated time remaining: 322.10 seconds.
# Processed 233/2000 files. Estimated time remaining: 321.89 seconds.
# Processed 234/2000 files. Estimated time remaining: 321.76 seconds.
# Processed 235/2000 files. Estimated time remaining: 321.61 seconds.
# Processed 236/2000 files. Estimated time remaining: 321.49 seconds.
# Processed 237/2000 files. Estimated time remaining: 321.34 seconds.
# Processed 238/2000 files. Estimated time remaining: 321.19 seconds.
# Processed 239/2000 files. Estimated time remaining: 321.02 seconds.
# Processed 240/2000 files. Estimated time remaining: 320.81 seconds.
# Processed 241/2000 files. Estimated time remaining: 320.62 seconds.
# Processed 242/2000 files. Estimated time remaining: 320.45 seconds.
# Processed 243/2000 files. Estimated time remaining: 320.29 seconds.
# Processed 244/2000 files. Estimated time remaining: 320.06 seconds.
# Processed 245/2000 files. Estimated time remaining: 319.88 seconds.
# Processed 246/2000 files. Estimated time remaining: 319.71 seconds.
# Processed 247/2000 files. Estimated time remaining: 319.53 seconds.
# Processed 248/2000 files. Estimated time remaining: 319.32 seconds.
# Processed 249/2000 files. Estimated time remaining: 319.13 seconds.
# Processed 250/2000 files. Estimated time remaining: 318.97 seconds.
# Processed 251/2000 files. Estimated time remaining: 318.80 seconds.
# Processed 252/2000 files. Estimated time remaining: 318.59 seconds.
# Processed 253/2000 files. Estimated time remaining: 318.44 seconds.
# Processed 254/2000 files. Estimated time remaining: 318.29 seconds.
# Processed 255/2000 files. Estimated time remaining: 318.06 seconds.
# Processed 256/2000 files. Estimated time remaining: 317.88 seconds.
# Processed 257/2000 files. Estimated time remaining: 317.68 seconds.
# Processed 258/2000 files. Estimated time remaining: 317.43 seconds.
# Processed 259/2000 files. Estimated time remaining: 317.24 seconds.
# Processed 260/2000 files. Estimated time remaining: 317.05 seconds.
# Processed 261/2000 files. Estimated time remaining: 316.84 seconds.
# Processed 262/2000 files. Estimated time remaining: 316.66 seconds.
# Processed 263/2000 files. Estimated time remaining: 316.43 seconds.
# Processed 264/2000 files. Estimated time remaining: 316.27 seconds.
# Processed 265/2000 files. Estimated time remaining: 316.03 seconds.
# Processed 266/2000 files. Estimated time remaining: 315.87 seconds.
# Processed 267/2000 files. Estimated time remaining: 315.70 seconds.
# Processed 268/2000 files. Estimated time remaining: 315.46 seconds.
# Processed 269/2000 files. Estimated time remaining: 315.27 seconds.
# Processed 270/2000 files. Estimated time remaining: 315.09 seconds.
# Processed 271/2000 files. Estimated time remaining: 314.93 seconds.
# Processed 272/2000 files. Estimated time remaining: 314.78 seconds.
# Processed 273/2000 files. Estimated time remaining: 314.63 seconds.
# Processed 274/2000 files. Estimated time remaining: 314.44 seconds.
# Processed 275/2000 files. Estimated time remaining: 314.21 seconds.
# Processed 276/2000 files. Estimated time remaining: 314.00 seconds.
# Processed 277/2000 files. Estimated time remaining: 313.81 seconds.
# Processed 278/2000 files. Estimated time remaining: 313.62 seconds.
# Processed 279/2000 files. Estimated time remaining: 313.43 seconds.
# Processed 280/2000 files. Estimated time remaining: 313.22 seconds.
# Processed 281/2000 files. Estimated time remaining: 312.96 seconds.
# Processed 282/2000 files. Estimated time remaining: 312.77 seconds.
# Processed 283/2000 files. Estimated time remaining: 312.62 seconds.
# Processed 284/2000 files. Estimated time remaining: 312.40 seconds.
# Processed 285/2000 files. Estimated time remaining: 312.19 seconds.
# Processed 286/2000 files. Estimated time remaining: 311.97 seconds.
# Processed 287/2000 files. Estimated time remaining: 311.79 seconds.
# Processed 288/2000 files. Estimated time remaining: 311.64 seconds.
# Processed 289/2000 files. Estimated time remaining: 311.43 seconds.
# Processed 290/2000 files. Estimated time remaining: 311.24 seconds.
# Processed 291/2000 files. Estimated time remaining: 311.07 seconds.
# Processed 292/2000 files. Estimated time remaining: 310.89 seconds.
# Processed 293/2000 files. Estimated time remaining: 310.73 seconds.
# Processed 294/2000 files. Estimated time remaining: 310.53 seconds.
# Processed 295/2000 files. Estimated time remaining: 310.33 seconds.
# Processed 296/2000 files. Estimated time remaining: 310.13 seconds.
# Processed 297/2000 files. Estimated time remaining: 309.95 seconds.
# Processed 298/2000 files. Estimated time remaining: 309.80 seconds.
# Processed 299/2000 files. Estimated time remaining: 309.67 seconds.
# Processed 300/2000 files. Estimated time remaining: 309.44 seconds.
# Processed 301/2000 files. Estimated time remaining: 309.22 seconds.
# Processed 302/2000 files. Estimated time remaining: 309.03 seconds.
# Processed 303/2000 files. Estimated time remaining: 308.83 seconds.
# Processed 304/2000 files. Estimated time remaining: 308.61 seconds.
# Processed 305/2000 files. Estimated time remaining: 308.43 seconds.
# Processed 306/2000 files. Estimated time remaining: 308.28 seconds.
# Processed 307/2000 files. Estimated time remaining: 308.06 seconds.
# Processed 308/2000 files. Estimated time remaining: 307.90 seconds.
# Processed 309/2000 files. Estimated time remaining: 307.75 seconds.
# Processed 310/2000 files. Estimated time remaining: 307.57 seconds.
# Processed 311/2000 files. Estimated time remaining: 307.41 seconds.
# Processed 312/2000 files. Estimated time remaining: 307.21 seconds.
# Processed 313/2000 files. Estimated time remaining: 306.99 seconds.
# Processed 314/2000 files. Estimated time remaining: 306.77 seconds.
# Processed 315/2000 files. Estimated time remaining: 306.60 seconds.
# Processed 316/2000 files. Estimated time remaining: 306.44 seconds.
# Processed 317/2000 files. Estimated time remaining: 306.22 seconds.
# Processed 318/2000 files. Estimated time remaining: 306.04 seconds.
# Processed 319/2000 files. Estimated time remaining: 305.87 seconds.
# Processed 320/2000 files. Estimated time remaining: 305.70 seconds.
# Processed 321/2000 files. Estimated time remaining: 305.52 seconds.
# Processed 322/2000 files. Estimated time remaining: 305.36 seconds.
# Processed 323/2000 files. Estimated time remaining: 305.14 seconds.
# Processed 324/2000 files. Estimated time remaining: 304.91 seconds.
# Processed 325/2000 files. Estimated time remaining: 304.75 seconds.
# Processed 326/2000 files. Estimated time remaining: 304.58 seconds.
# Processed 327/2000 files. Estimated time remaining: 304.38 seconds.
# Processed 328/2000 files. Estimated time remaining: 304.21 seconds.
# Processed 329/2000 files. Estimated time remaining: 304.05 seconds.
# Processed 330/2000 files. Estimated time remaining: 303.87 seconds.
# Processed 331/2000 files. Estimated time remaining: 303.70 seconds.
# Processed 332/2000 files. Estimated time remaining: 303.55 seconds.
# Processed 333/2000 files. Estimated time remaining: 303.39 seconds.
# Processed 334/2000 files. Estimated time remaining: 303.24 seconds.
# Processed 335/2000 files. Estimated time remaining: 303.00 seconds.
# Processed 336/2000 files. Estimated time remaining: 302.77 seconds.
# Processed 337/2000 files. Estimated time remaining: 302.56 seconds.
# Processed 338/2000 files. Estimated time remaining: 302.34 seconds.
# Processed 339/2000 files. Estimated time remaining: 302.11 seconds.
# Processed 340/2000 files. Estimated time remaining: 301.96 seconds.
# Processed 341/2000 files. Estimated time remaining: 301.76 seconds.
# Processed 342/2000 files. Estimated time remaining: 301.58 seconds.
# Processed 343/2000 files. Estimated time remaining: 301.37 seconds.
# Processed 344/2000 files. Estimated time remaining: 301.16 seconds.
# Processed 345/2000 files. Estimated time remaining: 300.96 seconds.
# Processed 346/2000 files. Estimated time remaining: 300.76 seconds.
# Processed 347/2000 files. Estimated time remaining: 300.58 seconds.
# Processed 348/2000 files. Estimated time remaining: 300.40 seconds.
# Processed 349/2000 files. Estimated time remaining: 300.23 seconds.
# Processed 350/2000 files. Estimated time remaining: 300.07 seconds.
# Processed 351/2000 files. Estimated time remaining: 299.90 seconds.
# Processed 352/2000 files. Estimated time remaining: 299.74 seconds.
# Processed 353/2000 files. Estimated time remaining: 299.58 seconds.
# Processed 354/2000 files. Estimated time remaining: 299.40 seconds.
# Processed 355/2000 files. Estimated time remaining: 299.20 seconds.
# Processed 356/2000 files. Estimated time remaining: 299.02 seconds.
# Processed 357/2000 files. Estimated time remaining: 298.87 seconds.
# Processed 358/2000 files. Estimated time remaining: 298.70 seconds.
# Processed 359/2000 files. Estimated time remaining: 298.51 seconds.
# Processed 360/2000 files. Estimated time remaining: 298.38 seconds.
# Processed 361/2000 files. Estimated time remaining: 298.18 seconds.
# Processed 362/2000 files. Estimated time remaining: 297.99 seconds.
# Processed 363/2000 files. Estimated time remaining: 297.87 seconds.
# Processed 364/2000 files. Estimated time remaining: 297.70 seconds.
# Processed 365/2000 files. Estimated time remaining: 297.49 seconds.
# Processed 366/2000 files. Estimated time remaining: 297.33 seconds.
# Processed 367/2000 files. Estimated time remaining: 297.12 seconds.
# Processed 368/2000 files. Estimated time remaining: 296.97 seconds.
# Processed 369/2000 files. Estimated time remaining: 296.75 seconds.
# Processed 370/2000 files. Estimated time remaining: 296.52 seconds.
# Processed 371/2000 files. Estimated time remaining: 296.29 seconds.
# Processed 372/2000 files. Estimated time remaining: 296.07 seconds.
# Processed 373/2000 files. Estimated time remaining: 295.87 seconds.
# Processed 374/2000 files. Estimated time remaining: 295.65 seconds.
# Processed 375/2000 files. Estimated time remaining: 295.52 seconds.
# Processed 376/2000 files. Estimated time remaining: 295.29 seconds.
# Processed 377/2000 files. Estimated time remaining: 295.16 seconds.
# Processed 378/2000 files. Estimated time remaining: 295.01 seconds.
# Processed 379/2000 files. Estimated time remaining: 294.82 seconds.
# Processed 380/2000 files. Estimated time remaining: 294.60 seconds.
# Processed 381/2000 files. Estimated time remaining: 294.44 seconds.
# Processed 382/2000 files. Estimated time remaining: 294.25 seconds.
# Processed 383/2000 files. Estimated time remaining: 294.12 seconds.
# Processed 384/2000 files. Estimated time remaining: 293.94 seconds.
# Processed 385/2000 files. Estimated time remaining: 293.77 seconds.
# Processed 386/2000 files. Estimated time remaining: 293.61 seconds.
# Processed 387/2000 files. Estimated time remaining: 293.41 seconds.
# Processed 388/2000 files. Estimated time remaining: 293.23 seconds.
# Processed 389/2000 files. Estimated time remaining: 293.07 seconds.
# Processed 390/2000 files. Estimated time remaining: 292.86 seconds.
# Processed 391/2000 files. Estimated time remaining: 292.65 seconds.
# Processed 392/2000 files. Estimated time remaining: 292.46 seconds.
# Processed 393/2000 files. Estimated time remaining: 292.27 seconds.
# Processed 394/2000 files. Estimated time remaining: 292.05 seconds.
# Processed 395/2000 files. Estimated time remaining: 291.88 seconds.
# Processed 396/2000 files. Estimated time remaining: 291.71 seconds.
# Processed 397/2000 files. Estimated time remaining: 291.55 seconds.
# Processed 398/2000 files. Estimated time remaining: 291.34 seconds.
# Processed 399/2000 files. Estimated time remaining: 291.17 seconds.
# Processed 400/2000 files. Estimated time remaining: 290.98 seconds.
# Processed 401/2000 files. Estimated time remaining: 290.79 seconds.
# Processed 402/2000 files. Estimated time remaining: 290.58 seconds.
# Processed 403/2000 files. Estimated time remaining: 290.40 seconds.
# Processed 404/2000 files. Estimated time remaining: 290.18 seconds.
# Processed 405/2000 files. Estimated time remaining: 289.97 seconds.
# Processed 406/2000 files. Estimated time remaining: 289.74 seconds.
# Processed 407/2000 files. Estimated time remaining: 289.54 seconds.
# Processed 408/2000 files. Estimated time remaining: 289.38 seconds.
# Processed 409/2000 files. Estimated time remaining: 289.18 seconds.
# Processed 410/2000 files. Estimated time remaining: 288.98 seconds.
# Processed 411/2000 files. Estimated time remaining: 288.77 seconds.
# Processed 412/2000 files. Estimated time remaining: 288.60 seconds.
# Processed 413/2000 files. Estimated time remaining: 288.40 seconds.
# Processed 414/2000 files. Estimated time remaining: 288.24 seconds.
# Processed 415/2000 files. Estimated time remaining: 288.07 seconds.
# Processed 416/2000 files. Estimated time remaining: 287.85 seconds.
# Processed 417/2000 files. Estimated time remaining: 287.67 seconds.
# Processed 418/2000 files. Estimated time remaining: 287.46 seconds.
# Processed 419/2000 files. Estimated time remaining: 287.31 seconds.
# Processed 420/2000 files. Estimated time remaining: 287.15 seconds.
# Processed 421/2000 files. Estimated time remaining: 286.93 seconds.
# Processed 422/2000 files. Estimated time remaining: 286.74 seconds.
# Processed 423/2000 files. Estimated time remaining: 286.58 seconds.
# Processed 424/2000 files. Estimated time remaining: 286.39 seconds.
# Processed 425/2000 files. Estimated time remaining: 286.21 seconds.
# Processed 426/2000 files. Estimated time remaining: 286.02 seconds.
# Processed 427/2000 files. Estimated time remaining: 285.83 seconds.
# Processed 428/2000 files. Estimated time remaining: 285.64 seconds.
# Processed 429/2000 files. Estimated time remaining: 285.43 seconds.
# Processed 430/2000 files. Estimated time remaining: 285.23 seconds.
# Processed 431/2000 files. Estimated time remaining: 285.05 seconds.
# Processed 432/2000 files. Estimated time remaining: 284.87 seconds.
# Processed 433/2000 files. Estimated time remaining: 284.68 seconds.
# Processed 434/2000 files. Estimated time remaining: 284.48 seconds.
# Processed 435/2000 files. Estimated time remaining: 284.27 seconds.
# Processed 436/2000 files. Estimated time remaining: 284.10 seconds.
# Processed 437/2000 files. Estimated time remaining: 283.93 seconds.
# Processed 438/2000 files. Estimated time remaining: 283.74 seconds.
# Processed 439/2000 files. Estimated time remaining: 283.52 seconds.
# Processed 440/2000 files. Estimated time remaining: 283.35 seconds.
# Processed 441/2000 files. Estimated time remaining: 283.15 seconds.
# Processed 442/2000 files. Estimated time remaining: 282.97 seconds.
# Processed 443/2000 files. Estimated time remaining: 282.79 seconds.
# Processed 444/2000 files. Estimated time remaining: 282.59 seconds.
# Processed 445/2000 files. Estimated time remaining: 282.42 seconds.
# Processed 446/2000 files. Estimated time remaining: 282.22 seconds.
# Processed 447/2000 files. Estimated time remaining: 282.04 seconds.
# Processed 448/2000 files. Estimated time remaining: 281.88 seconds.
# Processed 449/2000 files. Estimated time remaining: 281.67 seconds.
# Processed 450/2000 files. Estimated time remaining: 281.51 seconds.
# Processed 451/2000 files. Estimated time remaining: 281.31 seconds.
# Processed 452/2000 files. Estimated time remaining: 281.15 seconds.
# Processed 453/2000 files. Estimated time remaining: 281.00 seconds.
# Processed 454/2000 files. Estimated time remaining: 280.80 seconds.
# Processed 455/2000 files. Estimated time remaining: 280.63 seconds.
# Processed 456/2000 files. Estimated time remaining: 280.45 seconds.
# Processed 457/2000 files. Estimated time remaining: 280.32 seconds.
# Processed 458/2000 files. Estimated time remaining: 280.14 seconds.
# Processed 459/2000 files. Estimated time remaining: 279.97 seconds.
# Processed 460/2000 files. Estimated time remaining: 279.79 seconds.
# Processed 461/2000 files. Estimated time remaining: 279.60 seconds.
# Processed 462/2000 files. Estimated time remaining: 279.40 seconds.
# Processed 463/2000 files. Estimated time remaining: 279.17 seconds.
# Processed 464/2000 files. Estimated time remaining: 278.99 seconds.
# Processed 465/2000 files. Estimated time remaining: 278.79 seconds.
# Processed 466/2000 files. Estimated time remaining: 278.60 seconds.
# Processed 467/2000 files. Estimated time remaining: 278.43 seconds.
# Processed 468/2000 files. Estimated time remaining: 278.27 seconds.
# Processed 469/2000 files. Estimated time remaining: 278.06 seconds.
# Processed 470/2000 files. Estimated time remaining: 277.89 seconds.
# Processed 471/2000 files. Estimated time remaining: 277.71 seconds.
# Processed 472/2000 files. Estimated time remaining: 277.55 seconds.
# Processed 473/2000 files. Estimated time remaining: 277.35 seconds.
# Processed 474/2000 files. Estimated time remaining: 277.16 seconds.
# Processed 475/2000 files. Estimated time remaining: 276.96 seconds.
# Processed 476/2000 files. Estimated time remaining: 276.75 seconds.
# Processed 477/2000 files. Estimated time remaining: 276.57 seconds.
# Processed 478/2000 files. Estimated time remaining: 276.38 seconds.
# Processed 479/2000 files. Estimated time remaining: 276.20 seconds.
# Processed 480/2000 files. Estimated time remaining: 276.02 seconds.
# Processed 481/2000 files. Estimated time remaining: 275.81 seconds.
# Processed 482/2000 files. Estimated time remaining: 275.65 seconds.
# Processed 483/2000 files. Estimated time remaining: 275.47 seconds.
# Processed 484/2000 files. Estimated time remaining: 275.29 seconds.
# Processed 485/2000 files. Estimated time remaining: 275.10 seconds.
# Processed 486/2000 files. Estimated time remaining: 274.92 seconds.
# Processed 487/2000 files. Estimated time remaining: 274.76 seconds.
# Processed 488/2000 files. Estimated time remaining: 274.59 seconds.
# Processed 489/2000 files. Estimated time remaining: 274.44 seconds.
# Processed 490/2000 files. Estimated time remaining: 274.27 seconds.
# Processed 491/2000 files. Estimated time remaining: 274.11 seconds.
# Processed 492/2000 files. Estimated time remaining: 273.95 seconds.
# Processed 493/2000 files. Estimated time remaining: 273.73 seconds.
# Processed 494/2000 files. Estimated time remaining: 273.56 seconds.
# Processed 495/2000 files. Estimated time remaining: 273.36 seconds.
# Processed 496/2000 files. Estimated time remaining: 273.19 seconds.
# Processed 497/2000 files. Estimated time remaining: 273.01 seconds.
# Processed 498/2000 files. Estimated time remaining: 272.84 seconds.
# Processed 499/2000 files. Estimated time remaining: 272.64 seconds.
# Processed 500/2000 files. Estimated time remaining: 272.44 seconds.
# Processed 501/2000 files. Estimated time remaining: 272.27 seconds.
# Processed 502/2000 files. Estimated time remaining: 272.09 seconds.
# Processed 503/2000 files. Estimated time remaining: 271.88 seconds.
# Processed 504/2000 files. Estimated time remaining: 271.68 seconds.
# Processed 505/2000 files. Estimated time remaining: 271.52 seconds.
# Processed 506/2000 files. Estimated time remaining: 271.34 seconds.
# Processed 507/2000 files. Estimated time remaining: 271.17 seconds.
# Processed 508/2000 files. Estimated time remaining: 271.01 seconds.
# Processed 509/2000 files. Estimated time remaining: 270.83 seconds.
# Processed 510/2000 files. Estimated time remaining: 270.66 seconds.
# Processed 511/2000 files. Estimated time remaining: 270.49 seconds.
# Processed 512/2000 files. Estimated time remaining: 270.30 seconds.
# Processed 513/2000 files. Estimated time remaining: 270.12 seconds.
# Processed 514/2000 files. Estimated time remaining: 269.94 seconds.
# Processed 515/2000 files. Estimated time remaining: 269.75 seconds.
# Processed 516/2000 files. Estimated time remaining: 269.54 seconds.
# Processed 517/2000 files. Estimated time remaining: 269.34 seconds.
# Processed 518/2000 files. Estimated time remaining: 269.14 seconds.
# Processed 519/2000 files. Estimated time remaining: 268.93 seconds.
# Processed 520/2000 files. Estimated time remaining: 268.75 seconds.
# Processed 521/2000 files. Estimated time remaining: 268.57 seconds.
# Processed 522/2000 files. Estimated time remaining: 268.37 seconds.
# Processed 523/2000 files. Estimated time remaining: 268.20 seconds.
# Processed 524/2000 files. Estimated time remaining: 268.02 seconds.
# Processed 525/2000 files. Estimated time remaining: 267.81 seconds.
# Processed 526/2000 files. Estimated time remaining: 267.62 seconds.
# Processed 527/2000 files. Estimated time remaining: 267.44 seconds.
# Processed 528/2000 files. Estimated time remaining: 267.26 seconds.
# Processed 529/2000 files. Estimated time remaining: 267.06 seconds.
# Processed 530/2000 files. Estimated time remaining: 266.88 seconds.
# Processed 531/2000 files. Estimated time remaining: 266.69 seconds.
# Processed 532/2000 files. Estimated time remaining: 266.49 seconds.
# Processed 533/2000 files. Estimated time remaining: 266.30 seconds.
# Processed 534/2000 files. Estimated time remaining: 266.11 seconds.
# Processed 535/2000 files. Estimated time remaining: 265.92 seconds.
# Processed 536/2000 files. Estimated time remaining: 265.77 seconds.
# Processed 537/2000 files. Estimated time remaining: 265.57 seconds.
# Processed 538/2000 files. Estimated time remaining: 265.39 seconds.
# Processed 539/2000 files. Estimated time remaining: 265.24 seconds.
# Processed 540/2000 files. Estimated time remaining: 265.07 seconds.
# Processed 541/2000 files. Estimated time remaining: 264.89 seconds.
# Processed 542/2000 files. Estimated time remaining: 264.71 seconds.
# Processed 543/2000 files. Estimated time remaining: 264.53 seconds.
# Processed 544/2000 files. Estimated time remaining: 264.32 seconds.
# Processed 545/2000 files. Estimated time remaining: 264.13 seconds.
# Processed 546/2000 files. Estimated time remaining: 263.95 seconds.
# Processed 547/2000 files. Estimated time remaining: 263.78 seconds.
# Processed 548/2000 files. Estimated time remaining: 263.60 seconds.
# Processed 549/2000 files. Estimated time remaining: 263.43 seconds.
# Processed 550/2000 files. Estimated time remaining: 263.23 seconds.
# Processed 551/2000 files. Estimated time remaining: 263.06 seconds.
# Processed 552/2000 files. Estimated time remaining: 262.85 seconds.
# Processed 553/2000 files. Estimated time remaining: 262.69 seconds.
# Processed 554/2000 files. Estimated time remaining: 262.52 seconds.
# Processed 555/2000 files. Estimated time remaining: 262.32 seconds.
# Processed 556/2000 files. Estimated time remaining: 262.13 seconds.
# Processed 557/2000 files. Estimated time remaining: 261.95 seconds.
# Processed 558/2000 files. Estimated time remaining: 261.74 seconds.
# Processed 559/2000 files. Estimated time remaining: 261.55 seconds.
# Processed 560/2000 files. Estimated time remaining: 261.36 seconds.
# Processed 561/2000 files. Estimated time remaining: 261.18 seconds.
# Processed 562/2000 files. Estimated time remaining: 261.00 seconds.
# Processed 563/2000 files. Estimated time remaining: 260.82 seconds.
# Processed 564/2000 files. Estimated time remaining: 260.61 seconds.
# Processed 565/2000 files. Estimated time remaining: 260.42 seconds.
# Processed 566/2000 files. Estimated time remaining: 260.24 seconds.
# Processed 567/2000 files. Estimated time remaining: 260.07 seconds.
# Processed 568/2000 files. Estimated time remaining: 259.89 seconds.
# Processed 569/2000 files. Estimated time remaining: 259.69 seconds.
# Processed 570/2000 files. Estimated time remaining: 259.52 seconds.
# Processed 571/2000 files. Estimated time remaining: 259.35 seconds.
# Processed 572/2000 files. Estimated time remaining: 259.14 seconds.
# Processed 573/2000 files. Estimated time remaining: 258.95 seconds.
# Processed 574/2000 files. Estimated time remaining: 258.77 seconds.
# Processed 575/2000 files. Estimated time remaining: 258.60 seconds.
# Processed 576/2000 files. Estimated time remaining: 258.43 seconds.
# Processed 577/2000 files. Estimated time remaining: 258.26 seconds.
# Processed 578/2000 files. Estimated time remaining: 258.05 seconds.
# Processed 579/2000 files. Estimated time remaining: 257.87 seconds.
# Processed 580/2000 files. Estimated time remaining: 257.66 seconds.
# Processed 581/2000 files. Estimated time remaining: 257.49 seconds.
# Processed 582/2000 files. Estimated time remaining: 257.30 seconds.
# Processed 583/2000 files. Estimated time remaining: 257.11 seconds.
# Processed 584/2000 files. Estimated time remaining: 256.94 seconds.
# Processed 585/2000 files. Estimated time remaining: 256.73 seconds.
# Processed 586/2000 files. Estimated time remaining: 256.56 seconds.
# Processed 587/2000 files. Estimated time remaining: 256.36 seconds.
# Processed 588/2000 files. Estimated time remaining: 256.21 seconds.
# Processed 589/2000 files. Estimated time remaining: 256.04 seconds.
# Processed 590/2000 files. Estimated time remaining: 255.88 seconds.
# Processed 591/2000 files. Estimated time remaining: 255.70 seconds.
# Processed 592/2000 files. Estimated time remaining: 255.50 seconds.
# Processed 593/2000 files. Estimated time remaining: 255.33 seconds.
# Processed 594/2000 files. Estimated time remaining: 255.16 seconds.
# Processed 595/2000 files. Estimated time remaining: 254.98 seconds.
# Processed 596/2000 files. Estimated time remaining: 254.79 seconds.
# Processed 597/2000 files. Estimated time remaining: 254.61 seconds.
# Processed 598/2000 files. Estimated time remaining: 254.42 seconds.
# Processed 599/2000 files. Estimated time remaining: 254.24 seconds.
# Processed 600/2000 files. Estimated time remaining: 254.07 seconds.
# Processed 601/2000 files. Estimated time remaining: 253.88 seconds.
# Processed 602/2000 files. Estimated time remaining: 253.70 seconds.
# Processed 603/2000 files. Estimated time remaining: 253.53 seconds.
# Processed 604/2000 files. Estimated time remaining: 253.32 seconds.
# Processed 605/2000 files. Estimated time remaining: 253.14 seconds.
# Processed 606/2000 files. Estimated time remaining: 252.94 seconds.
# Processed 607/2000 files. Estimated time remaining: 252.77 seconds.
# Processed 608/2000 files. Estimated time remaining: 252.61 seconds.
# Processed 609/2000 files. Estimated time remaining: 252.41 seconds.
# Processed 610/2000 files. Estimated time remaining: 252.23 seconds.
# Processed 611/2000 files. Estimated time remaining: 252.04 seconds.
# Processed 612/2000 files. Estimated time remaining: 251.86 seconds.
# Processed 613/2000 files. Estimated time remaining: 251.68 seconds.
# Processed 614/2000 files. Estimated time remaining: 251.47 seconds.
# Processed 615/2000 files. Estimated time remaining: 251.28 seconds.
# Processed 616/2000 files. Estimated time remaining: 251.10 seconds.
# Processed 617/2000 files. Estimated time remaining: 250.90 seconds.
# Processed 618/2000 files. Estimated time remaining: 250.71 seconds.
# Processed 619/2000 files. Estimated time remaining: 250.55 seconds.
# Processed 620/2000 files. Estimated time remaining: 250.38 seconds.
# Processed 621/2000 files. Estimated time remaining: 250.19 seconds.
# Processed 622/2000 files. Estimated time remaining: 250.01 seconds.
# Processed 623/2000 files. Estimated time remaining: 249.80 seconds.
# Processed 624/2000 files. Estimated time remaining: 249.61 seconds.
# Processed 625/2000 files. Estimated time remaining: 249.43 seconds.
# Processed 626/2000 files. Estimated time remaining: 249.24 seconds.
# Processed 627/2000 files. Estimated time remaining: 249.05 seconds.
# Processed 628/2000 files. Estimated time remaining: 248.86 seconds.
# Processed 629/2000 files. Estimated time remaining: 248.68 seconds.
# Processed 630/2000 files. Estimated time remaining: 248.48 seconds.
# Processed 631/2000 files. Estimated time remaining: 248.31 seconds.
# Processed 632/2000 files. Estimated time remaining: 248.13 seconds.
# Processed 633/2000 files. Estimated time remaining: 247.94 seconds.
# Processed 634/2000 files. Estimated time remaining: 247.75 seconds.
# Processed 635/2000 files. Estimated time remaining: 247.58 seconds.
# Processed 636/2000 files. Estimated time remaining: 247.40 seconds.
# Processed 637/2000 files. Estimated time remaining: 247.22 seconds.
# Processed 638/2000 files. Estimated time remaining: 247.03 seconds.
# Processed 639/2000 files. Estimated time remaining: 246.84 seconds.
# Processed 640/2000 files. Estimated time remaining: 246.66 seconds.
# Processed 641/2000 files. Estimated time remaining: 246.46 seconds.
# Processed 642/2000 files. Estimated time remaining: 246.28 seconds.
# Processed 643/2000 files. Estimated time remaining: 246.13 seconds.
# Processed 644/2000 files. Estimated time remaining: 245.93 seconds.
# Processed 645/2000 files. Estimated time remaining: 245.73 seconds.
# Processed 646/2000 files. Estimated time remaining: 245.55 seconds.
# Processed 647/2000 files. Estimated time remaining: 245.38 seconds.
# Processed 648/2000 files. Estimated time remaining: 245.21 seconds.
# Processed 649/2000 files. Estimated time remaining: 245.02 seconds.
# Processed 650/2000 files. Estimated time remaining: 244.85 seconds.
# Processed 651/2000 files. Estimated time remaining: 244.65 seconds.
# Processed 652/2000 files. Estimated time remaining: 244.48 seconds.
# Processed 653/2000 files. Estimated time remaining: 244.30 seconds.
# Processed 654/2000 files. Estimated time remaining: 244.12 seconds.
# Processed 655/2000 files. Estimated time remaining: 243.95 seconds.
# Processed 656/2000 files. Estimated time remaining: 243.77 seconds.
# Processed 657/2000 files. Estimated time remaining: 243.60 seconds.
# Processed 658/2000 files. Estimated time remaining: 243.43 seconds.
# Processed 659/2000 files. Estimated time remaining: 243.25 seconds.
# Processed 660/2000 files. Estimated time remaining: 243.06 seconds.
# Processed 661/2000 files. Estimated time remaining: 242.89 seconds.
# Processed 662/2000 files. Estimated time remaining: 242.69 seconds.
# Processed 663/2000 files. Estimated time remaining: 242.51 seconds.
# Processed 664/2000 files. Estimated time remaining: 242.33 seconds.
# Processed 665/2000 files. Estimated time remaining: 242.14 seconds.
# Processed 666/2000 files. Estimated time remaining: 241.94 seconds.
# Processed 667/2000 files. Estimated time remaining: 241.76 seconds.
# Processed 668/2000 files. Estimated time remaining: 241.56 seconds.
# Processed 669/2000 files. Estimated time remaining: 241.38 seconds.
# Processed 670/2000 files. Estimated time remaining: 241.20 seconds.
# Processed 671/2000 files. Estimated time remaining: 241.02 seconds.
# Processed 672/2000 files. Estimated time remaining: 240.82 seconds.
# Processed 673/2000 files. Estimated time remaining: 240.64 seconds.
# Processed 674/2000 files. Estimated time remaining: 240.45 seconds.
# Processed 675/2000 files. Estimated time remaining: 240.27 seconds.
# Processed 676/2000 files. Estimated time remaining: 240.10 seconds.
# Processed 677/2000 files. Estimated time remaining: 239.92 seconds.
# Processed 678/2000 files. Estimated time remaining: 239.71 seconds.
# Processed 679/2000 files. Estimated time remaining: 239.53 seconds.
# Processed 680/2000 files. Estimated time remaining: 239.37 seconds.
# Processed 681/2000 files. Estimated time remaining: 239.20 seconds.
# Processed 682/2000 files. Estimated time remaining: 239.02 seconds.
# Processed 683/2000 files. Estimated time remaining: 238.82 seconds.
# Processed 684/2000 files. Estimated time remaining: 238.62 seconds.
# Processed 685/2000 files. Estimated time remaining: 238.41 seconds.
# Processed 686/2000 files. Estimated time remaining: 238.23 seconds.
# Processed 687/2000 files. Estimated time remaining: 238.06 seconds.
# Processed 688/2000 files. Estimated time remaining: 237.87 seconds.
# Processed 689/2000 files. Estimated time remaining: 237.68 seconds.
# Processed 690/2000 files. Estimated time remaining: 237.50 seconds.
# Processed 691/2000 files. Estimated time remaining: 237.32 seconds.
# Processed 692/2000 files. Estimated time remaining: 237.14 seconds.
# Processed 693/2000 files. Estimated time remaining: 236.95 seconds.
# Processed 694/2000 files. Estimated time remaining: 236.78 seconds.
# Processed 695/2000 files. Estimated time remaining: 236.61 seconds.
# Processed 696/2000 files. Estimated time remaining: 236.43 seconds.
# Processed 697/2000 files. Estimated time remaining: 236.24 seconds.
# Processed 698/2000 files. Estimated time remaining: 236.05 seconds.
# Processed 699/2000 files. Estimated time remaining: 235.85 seconds.
# Processed 700/2000 files. Estimated time remaining: 235.68 seconds.
# Processed 701/2000 files. Estimated time remaining: 235.51 seconds.
# Processed 702/2000 files. Estimated time remaining: 235.32 seconds.
# Processed 703/2000 files. Estimated time remaining: 235.15 seconds.
# Processed 704/2000 files. Estimated time remaining: 234.95 seconds.
# Processed 705/2000 files. Estimated time remaining: 234.76 seconds.
# Processed 706/2000 files. Estimated time remaining: 234.57 seconds.
# Processed 707/2000 files. Estimated time remaining: 234.41 seconds.
# ...
# Processed 1766/2000 files. Estimated time remaining: 42.38 seconds.
# Processed 1767/2000 files. Estimated time remaining: 42.20 seconds.
# Processed 1768/2000 files. Estimated time remaining: 42.02 seconds.
# Processed 1769/2000 files. Estimated time remaining: 41.84 seconds.
# Processed 1770/2000 files. Estimated time remaining: 41.66 seconds.
# Processed 1771/2000 files. Estimated time remaining: 41.48 seconds.
# Processed 1772/2000 files. Estimated time remaining: 41.30 seconds.
# Processed 1773/2000 files. Estimated time remaining: 41.12 seconds.
# Processed 1774/2000 files. Estimated time remaining: 40.94 seconds.
# Processed 1775/2000 files. Estimated time remaining: 40.76 seconds.
# Processed 1776/2000 files. Estimated time remaining: 40.58 seconds.
# Processed 1777/2000 files. Estimated time remaining: 40.39 seconds.
# Processed 1778/2000 files. Estimated time remaining: 40.21 seconds.
# Processed 1779/2000 files. Estimated time remaining: 40.03 seconds.
# Processed 1780/2000 files. Estimated time remaining: 39.85 seconds.
# Processed 1781/2000 files. Estimated time remaining: 39.67 seconds.
# Processed 1782/2000 files. Estimated time remaining: 39.49 seconds.
# Processed 1783/2000 files. Estimated time remaining: 39.31 seconds.
# Processed 1784/2000 files. Estimated time remaining: 39.13 seconds.
# Processed 1785/2000 files. Estimated time remaining: 38.95 seconds.
# Processed 1786/2000 files. Estimated time remaining: 38.77 seconds.
# Processed 1787/2000 files. Estimated time remaining: 38.59 seconds.
# Processed 1788/2000 files. Estimated time remaining: 38.41 seconds.
# Processed 1789/2000 files. Estimated time remaining: 38.22 seconds.
# Processed 1790/2000 files. Estimated time remaining: 38.04 seconds.
# Processed 1791/2000 files. Estimated time remaining: 37.86 seconds.
# Processed 1792/2000 files. Estimated time remaining: 37.68 seconds.
# Processed 1793/2000 files. Estimated time remaining: 37.50 seconds.
# Processed 1794/2000 files. Estimated time remaining: 37.32 seconds.
# Processed 1795/2000 files. Estimated time remaining: 37.14 seconds.
# Processed 1796/2000 files. Estimated time remaining: 36.96 seconds.
# Processed 1797/2000 files. Estimated time remaining: 36.78 seconds.
# Processed 1798/2000 files. Estimated time remaining: 36.60 seconds.
# Processed 1799/2000 files. Estimated time remaining: 36.42 seconds.
# Processed 1800/2000 files. Estimated time remaining: 36.24 seconds.
# Processed 1801/2000 files. Estimated time remaining: 36.05 seconds.
# Processed 1802/2000 files. Estimated time remaining: 35.87 seconds.
# Processed 1803/2000 files. Estimated time remaining: 35.69 seconds.
# Processed 1804/2000 files. Estimated time remaining: 35.51 seconds.
# Processed 1805/2000 files. Estimated time remaining: 35.33 seconds.
# Processed 1806/2000 files. Estimated time remaining: 35.15 seconds.
# Processed 1807/2000 files. Estimated time remaining: 34.97 seconds.
# Processed 1808/2000 files. Estimated time remaining: 34.79 seconds.
# Processed 1809/2000 files. Estimated time remaining: 34.61 seconds.
# Processed 1810/2000 files. Estimated time remaining: 34.42 seconds.
# Processed 1811/2000 files. Estimated time remaining: 34.24 seconds.
# Processed 1812/2000 files. Estimated time remaining: 34.06 seconds.
# Processed 1813/2000 files. Estimated time remaining: 33.88 seconds.
# Processed 1814/2000 files. Estimated time remaining: 33.70 seconds.
# Processed 1815/2000 files. Estimated time remaining: 33.52 seconds.
# Processed 1816/2000 files. Estimated time remaining: 33.34 seconds.
# Processed 1817/2000 files. Estimated time remaining: 33.15 seconds.
# Processed 1818/2000 files. Estimated time remaining: 32.97 seconds.
# Processed 1819/2000 files. Estimated time remaining: 32.79 seconds.
# Processed 1820/2000 files. Estimated time remaining: 32.61 seconds.
# Processed 1821/2000 files. Estimated time remaining: 32.43 seconds.
# Processed 1822/2000 files. Estimated time remaining: 32.25 seconds.
# Processed 1823/2000 files. Estimated time remaining: 32.07 seconds.
# Processed 1824/2000 files. Estimated time remaining: 31.89 seconds.
# Processed 1825/2000 files. Estimated time remaining: 31.71 seconds.
# Processed 1826/2000 files. Estimated time remaining: 31.53 seconds.
# Processed 1827/2000 files. Estimated time remaining: 31.35 seconds.
# Processed 1828/2000 files. Estimated time remaining: 31.16 seconds.
# Processed 1829/2000 files. Estimated time remaining: 30.98 seconds.
# Processed 1830/2000 files. Estimated time remaining: 30.80 seconds.
# Processed 1831/2000 files. Estimated time remaining: 30.62 seconds.
# Processed 1832/2000 files. Estimated time remaining: 30.44 seconds.
# Processed 1833/2000 files. Estimated time remaining: 30.26 seconds.
# Processed 1834/2000 files. Estimated time remaining: 30.08 seconds.
# Processed 1835/2000 files. Estimated time remaining: 29.90 seconds.
# Processed 1836/2000 files. Estimated time remaining: 29.72 seconds.
# Processed 1837/2000 files. Estimated time remaining: 29.53 seconds.
# Processed 1838/2000 files. Estimated time remaining: 29.35 seconds.
# Processed 1839/2000 files. Estimated time remaining: 29.17 seconds.
# Processed 1840/2000 files. Estimated time remaining: 28.99 seconds.
# Processed 1841/2000 files. Estimated time remaining: 28.81 seconds.
# Processed 1842/2000 files. Estimated time remaining: 28.63 seconds.
# Processed 1843/2000 files. Estimated time remaining: 28.45 seconds.
# Processed 1844/2000 files. Estimated time remaining: 28.27 seconds.
# Processed 1845/2000 files. Estimated time remaining: 28.09 seconds.
# Processed 1846/2000 files. Estimated time remaining: 27.91 seconds.
# Processed 1847/2000 files. Estimated time remaining: 27.72 seconds.
# Processed 1848/2000 files. Estimated time remaining: 27.54 seconds.
# Processed 1849/2000 files. Estimated time remaining: 27.36 seconds.
# Processed 1850/2000 files. Estimated time remaining: 27.18 seconds.
# Processed 1851/2000 files. Estimated time remaining: 27.00 seconds.
# Processed 1852/2000 files. Estimated time remaining: 26.82 seconds.
# Processed 1853/2000 files. Estimated time remaining: 26.64 seconds.
# Processed 1854/2000 files. Estimated time remaining: 26.46 seconds.
# Processed 1855/2000 files. Estimated time remaining: 26.27 seconds.
# Processed 1856/2000 files. Estimated time remaining: 26.09 seconds.
# Processed 1857/2000 files. Estimated time remaining: 25.91 seconds.
# Processed 1858/2000 files. Estimated time remaining: 25.73 seconds.
# Processed 1859/2000 files. Estimated time remaining: 25.55 seconds.
# Processed 1860/2000 files. Estimated time remaining: 25.37 seconds.
# Processed 1861/2000 files. Estimated time remaining: 25.19 seconds.
# Processed 1862/2000 files. Estimated time remaining: 25.01 seconds.
# Processed 1863/2000 files. Estimated time remaining: 24.83 seconds.
# Processed 1864/2000 files. Estimated time remaining: 24.64 seconds.
# Processed 1865/2000 files. Estimated time remaining: 24.46 seconds.
# Processed 1866/2000 files. Estimated time remaining: 24.28 seconds.
# Processed 1867/2000 files. Estimated time remaining: 24.10 seconds.
# Processed 1868/2000 files. Estimated time remaining: 23.92 seconds.
# Processed 1869/2000 files. Estimated time remaining: 23.74 seconds.
# Processed 1870/2000 files. Estimated time remaining: 23.56 seconds.
# Processed 1871/2000 files. Estimated time remaining: 23.38 seconds.
# Processed 1872/2000 files. Estimated time remaining: 23.19 seconds.
# Processed 1873/2000 files. Estimated time remaining: 23.01 seconds.
# Processed 1874/2000 files. Estimated time remaining: 22.83 seconds.
# Processed 1875/2000 files. Estimated time remaining: 22.65 seconds.
# Processed 1876/2000 files. Estimated time remaining: 22.47 seconds.
# Processed 1877/2000 files. Estimated time remaining: 22.29 seconds.
# Processed 1878/2000 files. Estimated time remaining: 22.11 seconds.
# Processed 1879/2000 files. Estimated time remaining: 21.93 seconds.
# Processed 1880/2000 files. Estimated time remaining: 21.75 seconds.
# Processed 1881/2000 files. Estimated time remaining: 21.57 seconds.
# Processed 1882/2000 files. Estimated time remaining: 21.38 seconds.
# Processed 1883/2000 files. Estimated time remaining: 21.20 seconds.
# Processed 1884/2000 files. Estimated time remaining: 21.02 seconds.
# Processed 1885/2000 files. Estimated time remaining: 20.84 seconds.
# Processed 1886/2000 files. Estimated time remaining: 20.66 seconds.
# Processed 1887/2000 files. Estimated time remaining: 20.48 seconds.
# Processed 1888/2000 files. Estimated time remaining: 20.30 seconds.
# Processed 1889/2000 files. Estimated time remaining: 20.12 seconds.
# Processed 1890/2000 files. Estimated time remaining: 19.93 seconds.
# Processed 1891/2000 files. Estimated time remaining: 19.75 seconds.
# Processed 1892/2000 files. Estimated time remaining: 19.57 seconds.
# Processed 1893/2000 files. Estimated time remaining: 19.39 seconds.
# Processed 1894/2000 files. Estimated time remaining: 19.21 seconds.
# Processed 1895/2000 files. Estimated time remaining: 19.03 seconds.
# Processed 1896/2000 files. Estimated time remaining: 18.85 seconds.
# Processed 1897/2000 files. Estimated time remaining: 18.67 seconds.
# Processed 1898/2000 files. Estimated time remaining: 18.48 seconds.
# Processed 1899/2000 files. Estimated time remaining: 18.30 seconds.
# Processed 1900/2000 files. Estimated time remaining: 18.12 seconds.
# Processed 1901/2000 files. Estimated time remaining: 17.94 seconds.
# Processed 1902/2000 files. Estimated time remaining: 17.76 seconds.
# Processed 1903/2000 files. Estimated time remaining: 17.58 seconds.
# Processed 1904/2000 files. Estimated time remaining: 17.40 seconds.
# Processed 1905/2000 files. Estimated time remaining: 17.22 seconds.
# Processed 1906/2000 files. Estimated time remaining: 17.04 seconds.
# Processed 1907/2000 files. Estimated time remaining: 16.85 seconds.
# Processed 1908/2000 files. Estimated time remaining: 16.67 seconds.
# Processed 1909/2000 files. Estimated time remaining: 16.49 seconds.
# Processed 1910/2000 files. Estimated time remaining: 16.31 seconds.
# Processed 1911/2000 files. Estimated time remaining: 16.13 seconds.
# Processed 1912/2000 files. Estimated time remaining: 15.95 seconds.
# Processed 1913/2000 files. Estimated time remaining: 15.77 seconds.
# Processed 1914/2000 files. Estimated time remaining: 15.59 seconds.
# Processed 1915/2000 files. Estimated time remaining: 15.40 seconds.
# Processed 1916/2000 files. Estimated time remaining: 15.22 seconds.
# Processed 1917/2000 files. Estimated time remaining: 15.04 seconds.
# Processed 1918/2000 files. Estimated time remaining: 14.86 seconds.
# Processed 1919/2000 files. Estimated time remaining: 14.68 seconds.
# Processed 1920/2000 files. Estimated time remaining: 14.50 seconds.
# Processed 1921/2000 files. Estimated time remaining: 14.32 seconds.
# Processed 1922/2000 files. Estimated time remaining: 14.14 seconds.
# Processed 1923/2000 files. Estimated time remaining: 13.95 seconds.
# Processed 1924/2000 files. Estimated time remaining: 13.77 seconds.
# Processed 1925/2000 files. Estimated time remaining: 13.59 seconds.
# Processed 1926/2000 files. Estimated time remaining: 13.41 seconds.
# Processed 1927/2000 files. Estimated time remaining: 13.23 seconds.
# Processed 1928/2000 files. Estimated time remaining: 13.05 seconds.
# Processed 1929/2000 files. Estimated time remaining: 12.87 seconds.
# Processed 1930/2000 files. Estimated time remaining: 12.69 seconds.
# Processed 1931/2000 files. Estimated time remaining: 12.51 seconds.
# Processed 1932/2000 files. Estimated time remaining: 12.32 seconds.
# Processed 1933/2000 files. Estimated time remaining: 12.14 seconds.
# Processed 1934/2000 files. Estimated time remaining: 11.96 seconds.
# Processed 1935/2000 files. Estimated time remaining: 11.78 seconds.
# Processed 1936/2000 files. Estimated time remaining: 11.60 seconds.
# Processed 1937/2000 files. Estimated time remaining: 11.42 seconds.
# Processed 1938/2000 files. Estimated time remaining: 11.24 seconds.
# Processed 1939/2000 files. Estimated time remaining: 11.06 seconds.
# Processed 1940/2000 files. Estimated time remaining: 10.88 seconds.
# Processed 1941/2000 files. Estimated time remaining: 10.70 seconds.
# Processed 1942/2000 files. Estimated time remaining: 10.51 seconds.
# Processed 1943/2000 files. Estimated time remaining: 10.33 seconds.
# Processed 1944/2000 files. Estimated time remaining: 10.15 seconds.
# Processed 1945/2000 files. Estimated time remaining: 9.97 seconds.
# Processed 1946/2000 files. Estimated time remaining: 9.79 seconds.
# Processed 1947/2000 files. Estimated time remaining: 9.61 seconds.
# Processed 1948/2000 files. Estimated time remaining: 9.43 seconds.
# Processed 1949/2000 files. Estimated time remaining: 9.24 seconds.
# Processed 1950/2000 files. Estimated time remaining: 9.06 seconds.
# Processed 1951/2000 files. Estimated time remaining: 8.88 seconds.
# Processed 1952/2000 files. Estimated time remaining: 8.70 seconds.
# Processed 1953/2000 files. Estimated time remaining: 8.52 seconds.
# Processed 1954/2000 files. Estimated time remaining: 8.34 seconds.
# Processed 1955/2000 files. Estimated time remaining: 8.16 seconds.
# Processed 1956/2000 files. Estimated time remaining: 7.98 seconds.
# Processed 1957/2000 files. Estimated time remaining: 7.79 seconds.
# Processed 1958/2000 files. Estimated time remaining: 7.61 seconds.
# Processed 1959/2000 files. Estimated time remaining: 7.43 seconds.
# Processed 1960/2000 files. Estimated time remaining: 7.25 seconds.
# Processed 1961/2000 files. Estimated time remaining: 7.07 seconds.
# Processed 1962/2000 files. Estimated time remaining: 6.89 seconds.
# Processed 1963/2000 files. Estimated time remaining: 6.71 seconds.
# Processed 1964/2000 files. Estimated time remaining: 6.53 seconds.
# Processed 1965/2000 files. Estimated time remaining: 6.34 seconds.
# Processed 1966/2000 files. Estimated time remaining: 6.16 seconds.
# Processed 1967/2000 files. Estimated time remaining: 5.98 seconds.
# Processed 1968/2000 files. Estimated time remaining: 5.80 seconds.
# Processed 1969/2000 files. Estimated time remaining: 5.62 seconds.
# Processed 1970/2000 files. Estimated time remaining: 5.44 seconds.
# Processed 1971/2000 files. Estimated time remaining: 5.26 seconds.
# Processed 1972/2000 files. Estimated time remaining: 5.08 seconds.
# Processed 1973/2000 files. Estimated time remaining: 4.89 seconds.
# Processed 1974/2000 files. Estimated time remaining: 4.71 seconds.
# Processed 1975/2000 files. Estimated time remaining: 4.53 seconds.
# Processed 1976/2000 files. Estimated time remaining: 4.35 seconds.
# Processed 1977/2000 files. Estimated time remaining: 4.17 seconds.
# Processed 1978/2000 files. Estimated time remaining: 3.99 seconds.
# Processed 1979/2000 files. Estimated time remaining: 3.81 seconds.
# Processed 1980/2000 files. Estimated time remaining: 3.63 seconds.
# Processed 1981/2000 files. Estimated time remaining: 3.44 seconds.
# Processed 1982/2000 files. Estimated time remaining: 3.26 seconds.
# Processed 1983/2000 files. Estimated time remaining: 3.08 seconds.
# Processed 1984/2000 files. Estimated time remaining: 2.90 seconds.
# Processed 1985/2000 files. Estimated time remaining: 2.72 seconds.
# Processed 1986/2000 files. Estimated time remaining: 2.54 seconds.
# Processed 1987/2000 files. Estimated time remaining: 2.36 seconds.
# Processed 1988/2000 files. Estimated time remaining: 2.18 seconds.
# Processed 1989/2000 files. Estimated time remaining: 1.99 seconds.
# Processed 1990/2000 files. Estimated time remaining: 1.81 seconds.
# Processed 1991/2000 files. Estimated time remaining: 1.63 seconds.
# Processed 1992/2000 files. Estimated time remaining: 1.45 seconds.
# Processed 1993/2000 files. Estimated time remaining: 1.27 seconds.
# Processed 1994/2000 files. Estimated time remaining: 1.09 seconds.
# Processed 1995/2000 files. Estimated time remaining: 0.91 seconds.
# Processed 1996/2000 files. Estimated time remaining: 0.73 seconds.
# Processed 1997/2000 files. Estimated time remaining: 0.54 seconds.
# Processed 1998/2000 files. Estimated time remaining: 0.36 seconds.
# Processed 1999/2000 files. Estimated time remaining: 0.18 seconds.
# Processed 2000/2000 files. Estimated time remaining: 0.00 seconds.
# Processing completed.

# %%
#Predicting label image from individual files
import torch
from PIL import Image
from model import Darknet
from torchvision.utils import save_image
import numpy as np
from transform_utils import lidar_transform,intensity_transform


# Prepare the input data
lidar_path = "/DATA2/Vivek/Data/Downstream Task/Test/test_lidar_depth/03_000002.npy"
intensity_path = "/DATA2/Vivek/Data/Downstream Task/Train/train_lidar_depth/03_000011.npy"

# Load the input images
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Darknet(in_channels=1, out_channels=20)  # Initialize your model architecture
#optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
checkpoint = torch.load('/DATA2/Vivek/Code/Implementation/Downstream Task/RangeNet/Output/T1/T1_model.pth.tar')

model.load_state_dict(checkpoint['state_dict'])
#optimizer.load_state_dict(checkpoint['optimizer'])

model.to(device)
model.eval()  # Switch the model to evaluation mode

lidar = np.load(lidar_path)
lidar = np.expand_dims(lidar, axis=0)  # Add channel dimension
lidar = torch.from_numpy(lidar).float()

# Load intensity data with channel dimension added
intensity = np.load(intensity_path)
intensity = np.expand_dims(intensity, axis=0)  # Add channel dimension
intensity = torch.from_numpy(intensity).float()

       
            
#concatenated_img = np.concatenate((lidar[..., np.newaxis], camera,incidence[..., np.newaxis]), axis=2)
#input_data = torch.cat((binary, label,incidence,lidar, color, rgb), dim=0)
input_data = lidar
input_data = input_data.unsqueeze(0) 

input_data = input_data.to(device)
with torch.no_grad():
    output = model(input_data)

output = output.squeeze(dim=0)


# Check if the output tensor is on the GPU and move it to CPU
if output.is_cuda:
    output = output.cpu()

output_array = output.numpy()

output_array = np.argmax(output_array, axis=0)

# Save output array to .npy file
np.save('output.npy', output_array)

# %%
#Predicting label image from entire folder


import os
import torch
import numpy as np
from model import Darknet

def process_lidar_intensity(lidar_path, intensity_path, model, device):
    # Load the lidar data
    lidar = np.load(lidar_path)
    lidar = np.expand_dims(lidar, axis=0)  # Add channel dimension
    lidar = torch.from_numpy(lidar).float().to(device)

    # Load the intensity data
    intensity = np.load(intensity_path)
    intensity = np.expand_dims(intensity, axis=0)  # Add channel dimension
    intensity = torch.from_numpy(intensity).float().to(device)

    # Concatenate the lidar and intensity data
    #input_data = torch.cat((lidar, intensity), dim=0)
    input_data = lidar
    # Add a batch dimension
    input_data = input_data.unsqueeze(0)

    # Perform inference
    with torch.no_grad():
        output = model(input_data)

    output = output.squeeze(dim=0)

    # Move the output tensor to CPU and convert to numpy array
    output_array = output.cpu().numpy()

    # Find the class with the highest probability for each pixel
    output_array = np.argmax(output_array, axis=0)

    return output_array


# Define the paths to the folders containing lidar and intensity images
lidar_folder = "/DATA2/Vivek/Data/Downstream Task/Train/train_lidar_depth/"
intensity_folder = "/DATA2/Vivek/Data/Downstream Task/Train/train_lidar_depth/"
output_folder = "/DATA2/Vivek/Code/Implementation/Downstream Task/RangeNet/Output/Pred_output_train"  # Specify the output folder path

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Initialize your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Darknet(in_channels=1, out_channels=20)  # Initialize your model architecture
checkpoint = torch.load('/DATA2/Vivek/Code/Implementation/Downstream Task/RangeNet/Output/T1/T1_model.pth.tar')
model.load_state_dict(checkpoint['state_dict'])
model.to(device)
model.eval()  # Switch the model to evaluation mode

# Iterate through the files in the folders
for lidar_file in os.listdir(lidar_folder):
    if lidar_file.endswith(".npy"):
        lidar_path = os.path.join(lidar_folder, lidar_file)
        intensity_file = lidar_file.replace("lidar_depth", "intensity_depth")
        intensity_path = os.path.join(intensity_folder, intensity_file)

        # Process lidar and intensity data
        output_array = process_lidar_intensity(lidar_path, intensity_path, model, device)

        # Save output array to .npy file in the output folder
        output_filename = os.path.splitext(lidar_file)[0] + ".npy"
        output_filepath = os.path.join(output_folder, output_filename)
        np.save(output_filepath, output_array)

# %%
#Checking the float and long operation on label tensor 

import numpy as np
import torch

# Load the label file
label_file_path = "/DATA2/Vivek/Vivekk/Data/VoxelScape/Voxel_Downstream_Task/Train/train_lidar_label/03_000859.npy"
semantic_image = np.load(label_file_path)

# Display the unique values before conversion
print("Semantic Image (Before Conversion):")
print(np.unique(semantic_image))

# Convert the label image to a PyTorch tensor and to long data type
semantic_tensor = torch.from_numpy(semantic_image).float()

# Display the unique values after conversion
print("\nSemantic Tensor (After Conversion):")
print(torch.unique(semantic_tensor))
# Out:
# Semantic Image (Before Conversion):
# [ 0.  1.  2.  3.  4.  5.  6.  7.  9. 13. 15. 17. 18.]
#
# Semantic Tensor (After Conversion):
# tensor([ 0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  9., 13., 15., 17., 18.])

# %%
#Predicted Output
import numpy as np
import matplotlib.pyplot as plt

learning_map = {
    0: 0,     # "unlabeled"
    1: 0,     # "outlier" mapped to "unlabeled"
    10: 1,    # "car"
    11: 2,    # "bicycle"
    13: 5,    # "bus" mapped to "other-vehicle"
    15: 3,    # "motorcycle"
    16: 5,    # "on-rails" mapped to "other-vehicle"
    18: 4,    # "truck"
    20: 5,    # "other-vehicle"
    30: 6,    # "person"
    31: 7,    # "bicyclist"
    32: 8,    # "motorcyclist"
    40: 9,    # "road"
    44: 10,   # "parking"
    48: 11,   # "sidewalk"
    49: 12,   # "other-ground"
    50: 13,   # "building"
    51: 14,   # "fence"
    52: 0,    # "other-structure" mapped to "unlabeled"
    60: 9,    # "lane-marking" to "road"
    70: 15,   # "vegetation"
    71: 16,   # "trunk"
    72: 17,   # "terrain"
    80: 18,   # "pole"
    81: 19,   # "traffic-sign"
    99: 0,    # "other-object" to "unlabeled"
    252: 1,   # "moving-car" to "car"
    253: 7,   # "moving-bicyclist" to "bicyclist"
    254: 6,   # "moving-person" to "person"
    255: 8,   # "moving-motorcyclist" to "motorcyclist"
    256: 5,   # "moving-on-rails" mapped to "other-vehicle"
    257: 5,   # "moving-bus" mapped to "other-vehicle"
    258: 4,   # "moving-truck" to "truck"
    259: 5    # "moving-other-vehicle" to "other-vehicle"
}

# Define the inverse mapping dictionary
learning_map_inv = {
    0: 0,     # "unlabeled"
    1: 0,     # "outlier" mapped to "unlabeled"
    10: 1,    # "car"
    11: 2,    # "bicycle"
    13: 5,    # "bus" mapped to "other-vehicle"
    15: 3,    # "motorcycle"
    16: 5,    # "on-rails" mapped to "other-vehicle"
    18: 4,    # "truck"
    20: 5,    # "other-vehicle"
    30: 6,    # "person"
    31: 7,    # "bicyclist"
    32: 8,    # "motorcyclist"
    40: 9,    # "road"
    44: 10,   # "parking"
    48: 11,   # "sidewalk"
    49: 12,   # "other-ground"
    50: 13,   # "building"
    51: 14,   # "fence"
    52: 0,    # "other-structure" mapped to "unlabeled"
    60: 9,    # "lane-marking" to "road"
    70: 15,   # "vegetation"
    71: 16,   # "trunk"
    72: 17,   # "terrain"
    80: 18,   # "pole"
    81: 19,   # "traffic-sign"
    99: 0,    # "other-object" to "unlabeled"
    252: 1,   # "moving-car" to "car"
    253: 7,   # "moving-bicyclist" to "bicyclist"
    254: 6,   # "moving-person" to "person"
    255: 8,   # "moving-motorcyclist" to "motorcyclist"
    256: 5,   # "moving-on-rails" mapped to "other-vehicle"
    257: 5,   # "moving-bus" mapped to "other-vehicle"
    258: 4,   # "moving-truck" to "truck"
    259: 5    # "moving-other-vehicle" to "other-vehicle"
}

# Define the color mapping dictionary
color_map = {
    0: [0, 0, 0],
    1: [0, 0, 255],
    10: [245, 150, 100],
    11: [245, 230, 100],
    13: [250, 80, 100],
    15: [150, 60, 30],
    16: [255, 0, 0],
    18: [180, 30, 80],
    20: [255, 0, 0],
    30: [30, 30, 255],
    31: [200, 40, 255],
    32: [90, 30, 150],
    40: [255, 0, 255],
    44: [255, 150, 255],
    48: [75, 0, 75],
    49: [75, 0, 175],
    50: [0, 200, 255],
    51: [50, 120, 255],
    52: [0, 150, 255],
    60: [170, 255, 150],
    70: [0, 175, 0],
    71: [0, 60, 135],
    72: [80, 240, 150],
    80: [150, 240, 255],
    81: [0, 0, 255],
    99: [255, 255, 50],
    252: [245, 150, 100],
    256: [255, 0, 0],
    253: [200, 40, 255],
    254: [30, 30, 255],
    255: [90, 30, 150],
    257: [250, 80, 100],
    258: [180, 30, 80],
    259: [255, 0, 0]
}

# Load the NumPy file
file_path = "/DATA2/Vivek/Vivekk/Data/VoxelScape/Voxel_Downstream_Task/Train/train_lidar_label/03_000859.npy"
data = np.load(file_path)

# Define inverse mapping function (assuming keys are unique)
def inverse_map(val):
  for key, value in learning_map.items():
    if value == val:
      return key
  return 0  # Assign unlabeled value if not found

# Apply inverse mapping to the data
data_mapped = np.vectorize(inverse_map)(data)

# Create color image based on color map
color_image = np.empty((data.shape[0], data.shape[1], 3), dtype=np.uint8)
for i in range(data_mapped.shape[0]):
  for j in range(data_mapped.shape[1]):
    color_image[i, j] = color_map[data_mapped[i, j]]

# Display the color image without ticks and border
plt.imshow(color_image, extent=(0, data.shape[1], 0, data.shape[0]))  # Set extent
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#target
import numpy as np
import matplotlib.pyplot as plt


# Load the NumPy file
file_path = "/DATA2/Vivek/Data/Downstream Task/Test/test_lidar_label/03_000002.npy"
data = np.load(file_path)

# Define inverse mapping function (assuming keys are unique)
def inverse_map(val):
  for key, value in learning_map.items():
    if value == val:
      return key
  return 0  # Assign unlabeled value if not found

# Apply inverse mapping to the data
data_mapped = np.vectorize(inverse_map)(data)

# Create color image based on color map
color_image = np.empty((data.shape[0], data.shape[1], 3), dtype=np.uint8)
for i in range(data_mapped.shape[0]):
  for j in range(data_mapped.shape[1]):
    color_image[i, j] = color_map[data_mapped[i, j]]

# Display the color image without ticks and border
plt.imshow(color_image, extent=(0, data.shape[1], 0, data.shape[0]))  # Set extent
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the label file
file_path = "/DATA2/Vivek/Vivekk/Data/VoxelScape/Voxel_Downstream_Task/Train/train_lidar_z/03_000668.npy"
data = np.load(file_path)
print(data.shape)

# Plot the 2D data as a grayscale image
plt.imshow(data, cmap='gray')
#plt.xlabel('X-axis')
#plt.ylabel('Y-axis')
plt.show()

print("Data values:\n", data)

# Calculate and print the data range
data_min = np.min(data)
data_max = np.max(data)
print(f"Data range: {data_min} to {data_max}")
# Out:
# (64, 1024)
# Data values:
#  [[ 0.61219656  0.6123923   0.6128005  ...  0.61098206  0.6113018
#    0.61164343]
#  [ 0.3351072   0.3352114   0.33542883 ...  0.3344592   0.33462846
#    0.33480966]
#  [ 0.19663036  0.19668901  0.19681108 ...  0.19627273  0.19636667
#    0.19646752]
#  ...
#  [ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [-1.9636306  -1.9636331  -1.9636378  ... -1.9636095  -1.9636161
#   -1.9636223 ]
#  [ 0.          0.          0.         ...  0.          0.
#    0.        ]]
# Data range: -2.1288056 to 2.318141
