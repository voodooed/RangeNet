# %%
#Predicting label image from entire folder #Numpy #x,y,z,depth,intensity

import os
import torch
import numpy as np
from model import Darknet
import time

def process_lidar_intensity(lidar_path, intensity_path, x_path, y_path, z_path, model, device, trial):
    # Load the lidar data (depth)
    lidar = np.load(lidar_path)
    lidar = np.expand_dims(lidar, axis=0)  # Add channel dimension
    lidar = torch.from_numpy(lidar).float().to(device)

    # Load the intensity data
    intensity = np.load(intensity_path)
    intensity = np.expand_dims(intensity, axis=0)  # Add channel dimension
    intensity = torch.from_numpy(intensity).float().to(device)

    # Load the x coordinate data
    x = np.load(x_path)
    x = np.expand_dims(x, axis=0)  # Add channel dimension
    x = torch.from_numpy(x).float().to(device)

    # Load the y coordinate data
    y = np.load(y_path)
    y = np.expand_dims(y, axis=0)  # Add channel dimension
    y = torch.from_numpy(y).float().to(device)

    # Load the z coordinate data
    z = np.load(z_path)
    z = np.expand_dims(z, axis=0)  # Add channel dimension
    z = torch.from_numpy(z).float().to(device)

    # Concatenate the lidar (depth), intensity, x, y, and z data
    input_data = torch.cat((x, y, z, lidar, intensity), dim=0) 

    # Add a batch dimension
    input_data = input_data.unsqueeze(0)

    # Perform inference
    with torch.no_grad():
        output = model(input_data)

    output = output.squeeze(dim=0)

    # Move the output tensor to CPU and convert to numpy array
    output_array = output.cpu().numpy()

    # Find the class with the highest probability for each pixel
    output_array = np.argmax(output_array, axis=0)

    return output_array


trial = "T1"
in_channel = 5
intensity_type = "lidar_intensity"
#intensity_type = "lidar_cycle_intensity"

# Define the paths to the folders containing lidar, intensity, and xyz images
base_path = "/DATA2/Vivek/Data/Downstream Task/Test/"

#base_path = "/DATA2/Vivek/Data/Downstream Task/Test/"

lidar_folder = os.path.join(base_path, "test_lidar_depth")
intensity_folder = os.path.join(base_path, f"test_{intensity_type}")
x_folder = os.path.join(base_path, "test_lidar_x")
y_folder = os.path.join(base_path, "test_lidar_y")
z_folder = os.path.join(base_path, "test_lidar_z")

output_folder = f"/DATA2/Vivek/Code/Implementation/Downstream_Task/RangeNet++/Mix_Training/Output_1.0/{trial}/Pred_Image"  # Specify the output folder path

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Initialize your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Darknet(in_channels=in_channel, out_channels=20)  # Update in_channels to 5 (depth + intensity + x + y + z)
checkpoint = torch.load(f'/DATA2/Vivek/Code/Implementation/Downstream_Task/RangeNet++/Mix_Training/Output_1.0/{trial}/{trial}_model.pth.tar')
model.load_state_dict(checkpoint['state_dict'])
model.to(device)
model.eval()  # Switch the model to evaluation mode

# Iterate through the files in the folders
lidar_files = [f for f in os.listdir(lidar_folder) if f.endswith(".npy")]
total_files = len(lidar_files)
start_time = time.time()

for idx, lidar_file in enumerate(lidar_files, start=1):
    lidar_path = os.path.join(lidar_folder, lidar_file)
    intensity_file = lidar_file.replace("depth", "intensity")
    intensity_path = os.path.join(intensity_folder, intensity_file)
    x_file = lidar_file.replace("depth", "x")
    x_path = os.path.join(x_folder, x_file)
    y_file = lidar_file.replace("depth", "y")
    y_path = os.path.join(y_folder, y_file)
    z_file = lidar_file.replace("depth", "z")
    z_path = os.path.join(z_folder, z_file)

    # Process lidar, intensity, and xyz data
    output_array = process_lidar_intensity(lidar_path, intensity_path, x_path, y_path, z_path, model, device, trial=trial)

    # Save output array to .npy file in the output folder
    output_filename = os.path.splitext(lidar_file)[0] + ".npy"
    output_filepath = os.path.join(output_folder, output_filename)
    np.save(output_filepath, output_array)

    # Calculate and print progress and estimated remaining time
    elapsed_time = time.time() - start_time
    avg_time_per_file = elapsed_time / idx
    remaining_time = avg_time_per_file * (total_files - idx)
    print(f"Processed {idx}/{total_files} files. Estimated time remaining: {remaining_time:.2f} seconds.")

print("Processing completed.")
# Out:
# Processed 1/2000 files. Estimated time remaining: 3901.38 seconds.
# Processed 2/2000 files. Estimated time remaining: 2066.02 seconds.
# Processed 3/2000 files. Estimated time remaining: 1438.87 seconds.
# Processed 4/2000 files. Estimated time remaining: 1137.94 seconds.
# Processed 5/2000 files. Estimated time remaining: 947.94 seconds.
# Processed 6/2000 files. Estimated time remaining: 834.01 seconds.
# Processed 7/2000 files. Estimated time remaining: 746.62 seconds.
# Processed 8/2000 files. Estimated time remaining: 683.38 seconds.
# Processed 9/2000 files. Estimated time remaining: 627.77 seconds.
# Processed 10/2000 files. Estimated time remaining: 585.99 seconds.
# Processed 11/2000 files. Estimated time remaining: 551.93 seconds.
# Processed 12/2000 files. Estimated time remaining: 523.13 seconds.
# Processed 13/2000 files. Estimated time remaining: 500.90 seconds.
# Processed 14/2000 files. Estimated time remaining: 480.71 seconds.
# Processed 15/2000 files. Estimated time remaining: 462.97 seconds.
# Processed 16/2000 files. Estimated time remaining: 447.33 seconds.
# Processed 17/2000 files. Estimated time remaining: 434.84 seconds.
# Processed 18/2000 files. Estimated time remaining: 422.22 seconds.
# Processed 19/2000 files. Estimated time remaining: 410.52 seconds.
# Processed 20/2000 files. Estimated time remaining: 401.62 seconds.
# Processed 21/2000 files. Estimated time remaining: 391.37 seconds.
# Processed 22/2000 files. Estimated time remaining: 389.21 seconds.
# Processed 23/2000 files. Estimated time remaining: 381.66 seconds.
# Processed 24/2000 files. Estimated time remaining: 375.65 seconds.
# Processed 25/2000 files. Estimated time remaining: 368.48 seconds.
# Processed 26/2000 files. Estimated time remaining: 362.94 seconds.
# Processed 27/2000 files. Estimated time remaining: 355.73 seconds.
# Processed 28/2000 files. Estimated time remaining: 350.21 seconds.
# Processed 29/2000 files. Estimated time remaining: 351.98 seconds.
# Processed 30/2000 files. Estimated time remaining: 348.06 seconds.
# Processed 31/2000 files. Estimated time remaining: 344.37 seconds.
# Processed 32/2000 files. Estimated time remaining: 340.39 seconds.
# Processed 33/2000 files. Estimated time remaining: 336.35 seconds.
# Processed 34/2000 files. Estimated time remaining: 332.61 seconds.
# Processed 35/2000 files. Estimated time remaining: 328.57 seconds.
# Processed 36/2000 files. Estimated time remaining: 324.96 seconds.
# Processed 37/2000 files. Estimated time remaining: 322.21 seconds.
# Processed 38/2000 files. Estimated time remaining: 318.77 seconds.
# Processed 39/2000 files. Estimated time remaining: 314.40 seconds.
# Processed 40/2000 files. Estimated time remaining: 311.17 seconds.
# Processed 41/2000 files. Estimated time remaining: 307.49 seconds.
# Processed 42/2000 files. Estimated time remaining: 305.34 seconds.
# Processed 43/2000 files. Estimated time remaining: 302.69 seconds.
# Processed 44/2000 files. Estimated time remaining: 299.98 seconds.
# Processed 45/2000 files. Estimated time remaining: 299.31 seconds.
# Processed 46/2000 files. Estimated time remaining: 297.11 seconds.
# Processed 47/2000 files. Estimated time remaining: 295.34 seconds.
# Processed 48/2000 files. Estimated time remaining: 294.26 seconds.
# Processed 49/2000 files. Estimated time remaining: 293.25 seconds.
# Processed 50/2000 files. Estimated time remaining: 291.25 seconds.
# Processed 51/2000 files. Estimated time remaining: 290.32 seconds.
# Processed 52/2000 files. Estimated time remaining: 288.94 seconds.
# Processed 53/2000 files. Estimated time remaining: 287.18 seconds.
# Processed 54/2000 files. Estimated time remaining: 286.06 seconds.
# Processed 55/2000 files. Estimated time remaining: 284.52 seconds.
# Processed 56/2000 files. Estimated time remaining: 283.96 seconds.
# Processed 57/2000 files. Estimated time remaining: 282.73 seconds.
# Processed 58/2000 files. Estimated time remaining: 280.94 seconds.
# Processed 59/2000 files. Estimated time remaining: 279.39 seconds.
# Processed 60/2000 files. Estimated time remaining: 278.14 seconds.
# Processed 61/2000 files. Estimated time remaining: 277.03 seconds.
# Processed 62/2000 files. Estimated time remaining: 275.32 seconds.
# Processed 63/2000 files. Estimated time remaining: 273.85 seconds.
# Processed 64/2000 files. Estimated time remaining: 272.76 seconds.
# Processed 65/2000 files. Estimated time remaining: 271.99 seconds.
# Processed 66/2000 files. Estimated time remaining: 270.66 seconds.
# Processed 67/2000 files. Estimated time remaining: 270.15 seconds.
# Processed 68/2000 files. Estimated time remaining: 269.26 seconds.
# Processed 69/2000 files. Estimated time remaining: 269.11 seconds.
# Processed 70/2000 files. Estimated time remaining: 267.72 seconds.
# Processed 71/2000 files. Estimated time remaining: 266.82 seconds.
# Processed 72/2000 files. Estimated time remaining: 266.28 seconds.
# Processed 73/2000 files. Estimated time remaining: 265.61 seconds.
# Processed 74/2000 files. Estimated time remaining: 265.29 seconds.
# Processed 75/2000 files. Estimated time remaining: 264.09 seconds.
# Processed 76/2000 files. Estimated time remaining: 262.93 seconds.
# Processed 77/2000 files. Estimated time remaining: 262.27 seconds.
# Processed 78/2000 files. Estimated time remaining: 261.36 seconds.
# Processed 79/2000 files. Estimated time remaining: 260.81 seconds.
# Processed 80/2000 files. Estimated time remaining: 259.99 seconds.
# Processed 81/2000 files. Estimated time remaining: 259.57 seconds.
# Processed 82/2000 files. Estimated time remaining: 258.44 seconds.
# Processed 83/2000 files. Estimated time remaining: 257.39 seconds.
# Processed 84/2000 files. Estimated time remaining: 256.97 seconds.
# Processed 85/2000 files. Estimated time remaining: 256.04 seconds.
# Processed 86/2000 files. Estimated time remaining: 255.16 seconds.
# Processed 87/2000 files. Estimated time remaining: 254.74 seconds.
# Processed 88/2000 files. Estimated time remaining: 254.11 seconds.
# Processed 89/2000 files. Estimated time remaining: 252.85 seconds.
# Processed 90/2000 files. Estimated time remaining: 252.04 seconds.
# Processed 91/2000 files. Estimated time remaining: 251.39 seconds.
# Processed 92/2000 files. Estimated time remaining: 250.52 seconds.
# Processed 93/2000 files. Estimated time remaining: 250.33 seconds.
# Processed 94/2000 files. Estimated time remaining: 249.24 seconds.
# Processed 95/2000 files. Estimated time remaining: 248.68 seconds.
# Processed 96/2000 files. Estimated time remaining: 247.70 seconds.
# Processed 97/2000 files. Estimated time remaining: 247.00 seconds.
# Processed 98/2000 files. Estimated time remaining: 245.90 seconds.
# Processed 99/2000 files. Estimated time remaining: 245.38 seconds.
# Processed 100/2000 files. Estimated time remaining: 244.41 seconds.
# Processed 101/2000 files. Estimated time remaining: 243.81 seconds.
# Processed 102/2000 files. Estimated time remaining: 243.43 seconds.
# Processed 103/2000 files. Estimated time remaining: 242.82 seconds.
# Processed 104/2000 files. Estimated time remaining: 242.11 seconds.
# Processed 105/2000 files. Estimated time remaining: 241.71 seconds.
# Processed 106/2000 files. Estimated time remaining: 241.16 seconds.
# Processed 107/2000 files. Estimated time remaining: 240.46 seconds.
# Processed 108/2000 files. Estimated time remaining: 240.01 seconds.
# Processed 109/2000 files. Estimated time remaining: 239.61 seconds.
# Processed 110/2000 files. Estimated time remaining: 239.11 seconds.
# Processed 111/2000 files. Estimated time remaining: 238.75 seconds.
# Processed 112/2000 files. Estimated time remaining: 238.11 seconds.
# Processed 113/2000 files. Estimated time remaining: 237.82 seconds.
# Processed 114/2000 files. Estimated time remaining: 237.28 seconds.
# Processed 115/2000 files. Estimated time remaining: 236.42 seconds.
# Processed 116/2000 files. Estimated time remaining: 236.13 seconds.
# Processed 117/2000 files. Estimated time remaining: 235.60 seconds.
# Processed 118/2000 files. Estimated time remaining: 235.25 seconds.
# Processed 119/2000 files. Estimated time remaining: 234.91 seconds.
# Processed 120/2000 files. Estimated time remaining: 234.42 seconds.
# Processed 121/2000 files. Estimated time remaining: 233.74 seconds.
# Processed 122/2000 files. Estimated time remaining: 233.57 seconds.
# Processed 123/2000 files. Estimated time remaining: 233.50 seconds.
# Processed 124/2000 files. Estimated time remaining: 233.15 seconds.
# Processed 125/2000 files. Estimated time remaining: 232.62 seconds.
# Processed 126/2000 files. Estimated time remaining: 231.96 seconds.
# Processed 127/2000 files. Estimated time remaining: 231.37 seconds.
# Processed 128/2000 files. Estimated time remaining: 231.00 seconds.
# Processed 129/2000 files. Estimated time remaining: 230.78 seconds.
# Processed 130/2000 files. Estimated time remaining: 232.53 seconds.
# Processed 131/2000 files. Estimated time remaining: 232.10 seconds.
# Processed 132/2000 files. Estimated time remaining: 231.80 seconds.
# Processed 133/2000 files. Estimated time remaining: 231.32 seconds.
# Processed 134/2000 files. Estimated time remaining: 230.78 seconds.
# Processed 135/2000 files. Estimated time remaining: 230.46 seconds.
# Processed 136/2000 files. Estimated time remaining: 230.39 seconds.
# Processed 137/2000 files. Estimated time remaining: 229.74 seconds.
# Processed 138/2000 files. Estimated time remaining: 229.55 seconds.
# Processed 139/2000 files. Estimated time remaining: 228.95 seconds.
# Processed 140/2000 files. Estimated time remaining: 228.65 seconds.
# Processed 141/2000 files. Estimated time remaining: 228.15 seconds.
# Processed 142/2000 files. Estimated time remaining: 227.95 seconds.
# Processed 143/2000 files. Estimated time remaining: 227.90 seconds.
# Processed 144/2000 files. Estimated time remaining: 227.28 seconds.
# Processed 145/2000 files. Estimated time remaining: 227.09 seconds.
# Processed 146/2000 files. Estimated time remaining: 226.42 seconds.
# Processed 147/2000 files. Estimated time remaining: 226.01 seconds.
# Processed 148/2000 files. Estimated time remaining: 225.94 seconds.
# Processed 149/2000 files. Estimated time remaining: 225.96 seconds.
# Processed 150/2000 files. Estimated time remaining: 225.82 seconds.
# Processed 151/2000 files. Estimated time remaining: 225.67 seconds.
# Processed 152/2000 files. Estimated time remaining: 225.44 seconds.
# Processed 153/2000 files. Estimated time remaining: 225.27 seconds.
# Processed 154/2000 files. Estimated time remaining: 224.98 seconds.
# Processed 155/2000 files. Estimated time remaining: 224.59 seconds.
# Processed 156/2000 files. Estimated time remaining: 224.33 seconds.
# Processed 157/2000 files. Estimated time remaining: 223.83 seconds.
# Processed 158/2000 files. Estimated time remaining: 223.61 seconds.
# Processed 159/2000 files. Estimated time remaining: 223.50 seconds.
# Processed 160/2000 files. Estimated time remaining: 222.92 seconds.
# Processed 161/2000 files. Estimated time remaining: 222.68 seconds.
# Processed 162/2000 files. Estimated time remaining: 223.46 seconds.
# Processed 163/2000 files. Estimated time remaining: 223.23 seconds.
# Processed 164/2000 files. Estimated time remaining: 222.78 seconds.
# Processed 165/2000 files. Estimated time remaining: 222.41 seconds.
# Processed 166/2000 files. Estimated time remaining: 222.16 seconds.
# Processed 167/2000 files. Estimated time remaining: 222.82 seconds.
# Processed 168/2000 files. Estimated time remaining: 222.35 seconds.
# Processed 169/2000 files. Estimated time remaining: 222.01 seconds.
# Processed 170/2000 files. Estimated time remaining: 221.62 seconds.
# Processed 171/2000 files. Estimated time remaining: 221.19 seconds.
# Processed 172/2000 files. Estimated time remaining: 220.77 seconds.
# Processed 173/2000 files. Estimated time remaining: 220.56 seconds.
# Processed 174/2000 files. Estimated time remaining: 220.50 seconds.
# Processed 175/2000 files. Estimated time remaining: 220.50 seconds.
# Processed 176/2000 files. Estimated time remaining: 220.32 seconds.
# Processed 177/2000 files. Estimated time remaining: 220.09 seconds.
# Processed 178/2000 files. Estimated time remaining: 219.87 seconds.
# Processed 179/2000 files. Estimated time remaining: 219.61 seconds.
# Processed 180/2000 files. Estimated time remaining: 219.36 seconds.
# Processed 181/2000 files. Estimated time remaining: 219.04 seconds.
# Processed 182/2000 files. Estimated time remaining: 219.09 seconds.
# Processed 183/2000 files. Estimated time remaining: 218.86 seconds.
# Processed 184/2000 files. Estimated time remaining: 218.38 seconds.
# Processed 185/2000 files. Estimated time remaining: 218.25 seconds.
# Processed 186/2000 files. Estimated time remaining: 218.27 seconds.
# Processed 187/2000 files. Estimated time remaining: 217.98 seconds.
# Processed 188/2000 files. Estimated time remaining: 217.59 seconds.
# Processed 189/2000 files. Estimated time remaining: 217.30 seconds.
# Processed 190/2000 files. Estimated time remaining: 217.21 seconds.
# Processed 191/2000 files. Estimated time remaining: 217.02 seconds.
# Processed 192/2000 files. Estimated time remaining: 216.78 seconds.
# Processed 193/2000 files. Estimated time remaining: 216.70 seconds.
# Processed 194/2000 files. Estimated time remaining: 216.58 seconds.
# Processed 195/2000 files. Estimated time remaining: 216.27 seconds.
# Processed 196/2000 files. Estimated time remaining: 216.08 seconds.
# Processed 197/2000 files. Estimated time remaining: 215.79 seconds.
# Processed 198/2000 files. Estimated time remaining: 215.54 seconds.
# Processed 199/2000 files. Estimated time remaining: 215.27 seconds.
# Processed 200/2000 files. Estimated time remaining: 215.14 seconds.
# Processed 201/2000 files. Estimated time remaining: 214.81 seconds.
# Processed 202/2000 files. Estimated time remaining: 214.48 seconds.
# Processed 203/2000 files. Estimated time remaining: 214.30 seconds.
# Processed 204/2000 files. Estimated time remaining: 213.88 seconds.
# Processed 205/2000 files. Estimated time remaining: 213.66 seconds.
# Processed 206/2000 files. Estimated time remaining: 213.38 seconds.
# Processed 207/2000 files. Estimated time remaining: 213.14 seconds.
# Processed 208/2000 files. Estimated time remaining: 214.45 seconds.
# Processed 209/2000 files. Estimated time remaining: 214.42 seconds.
# Processed 210/2000 files. Estimated time remaining: 214.17 seconds.
# Processed 211/2000 files. Estimated time remaining: 213.93 seconds.
# Processed 212/2000 files. Estimated time remaining: 216.26 seconds.
# Processed 213/2000 files. Estimated time remaining: 216.11 seconds.
# Processed 214/2000 files. Estimated time remaining: 215.65 seconds.
# Processed 215/2000 files. Estimated time remaining: 215.56 seconds.
# Processed 216/2000 files. Estimated time remaining: 215.30 seconds.
# Processed 217/2000 files. Estimated time remaining: 214.83 seconds.
# Processed 218/2000 files. Estimated time remaining: 214.68 seconds.
# Processed 219/2000 files. Estimated time remaining: 214.30 seconds.
# Processed 220/2000 files. Estimated time remaining: 214.05 seconds.
# Processed 221/2000 files. Estimated time remaining: 213.70 seconds.
# Processed 222/2000 files. Estimated time remaining: 213.73 seconds.
# Processed 223/2000 files. Estimated time remaining: 213.49 seconds.
# Processed 224/2000 files. Estimated time remaining: 213.09 seconds.
# Processed 225/2000 files. Estimated time remaining: 212.95 seconds.
# Processed 226/2000 files. Estimated time remaining: 212.79 seconds.
# Processed 227/2000 files. Estimated time remaining: 212.33 seconds.
# Processed 228/2000 files. Estimated time remaining: 212.16 seconds.
# Processed 229/2000 files. Estimated time remaining: 212.08 seconds.
# Processed 230/2000 files. Estimated time remaining: 211.78 seconds.
# Processed 231/2000 files. Estimated time remaining: 211.47 seconds.
# Processed 232/2000 files. Estimated time remaining: 211.40 seconds.
# Processed 233/2000 files. Estimated time remaining: 211.40 seconds.
# Processed 234/2000 files. Estimated time remaining: 211.12 seconds.
# Processed 235/2000 files. Estimated time remaining: 211.06 seconds.
# Processed 236/2000 files. Estimated time remaining: 210.80 seconds.
# Processed 237/2000 files. Estimated time remaining: 210.60 seconds.
# Processed 238/2000 files. Estimated time remaining: 210.28 seconds.
# Processed 239/2000 files. Estimated time remaining: 210.05 seconds.
# Processed 240/2000 files. Estimated time remaining: 209.90 seconds.
# Processed 241/2000 files. Estimated time remaining: 209.63 seconds.
# Processed 242/2000 files. Estimated time remaining: 209.46 seconds.
# Processed 243/2000 files. Estimated time remaining: 209.16 seconds.
# Processed 244/2000 files. Estimated time remaining: 208.76 seconds.
# Processed 245/2000 files. Estimated time remaining: 208.63 seconds.
# Processed 246/2000 files. Estimated time remaining: 208.52 seconds.
# Processed 247/2000 files. Estimated time remaining: 208.30 seconds.
# Processed 248/2000 files. Estimated time remaining: 208.09 seconds.
# Processed 249/2000 files. Estimated time remaining: 207.84 seconds.
# Processed 250/2000 files. Estimated time remaining: 207.58 seconds.
# Processed 251/2000 files. Estimated time remaining: 207.35 seconds.
# Processed 252/2000 files. Estimated time remaining: 207.04 seconds.
# Processed 253/2000 files. Estimated time remaining: 206.91 seconds.
# Processed 254/2000 files. Estimated time remaining: 206.67 seconds.
# Processed 255/2000 files. Estimated time remaining: 206.62 seconds.
# Processed 256/2000 files. Estimated time remaining: 206.40 seconds.
# Processed 257/2000 files. Estimated time remaining: 206.22 seconds.
# Processed 258/2000 files. Estimated time remaining: 206.22 seconds.
# Processed 259/2000 files. Estimated time remaining: 206.23 seconds.
# Processed 260/2000 files. Estimated time remaining: 206.12 seconds.
# Processed 261/2000 files. Estimated time remaining: 205.93 seconds.
# Processed 262/2000 files. Estimated time remaining: 205.81 seconds.
# Processed 263/2000 files. Estimated time remaining: 205.54 seconds.
# Processed 264/2000 files. Estimated time remaining: 205.30 seconds.
# Processed 265/2000 files. Estimated time remaining: 205.11 seconds.
# Processed 266/2000 files. Estimated time remaining: 204.96 seconds.
# Processed 267/2000 files. Estimated time remaining: 204.90 seconds.
# Processed 268/2000 files. Estimated time remaining: 204.61 seconds.
# Processed 269/2000 files. Estimated time remaining: 204.39 seconds.
# Processed 270/2000 files. Estimated time remaining: 204.12 seconds.
# Processed 271/2000 files. Estimated time remaining: 203.93 seconds.
# Processed 272/2000 files. Estimated time remaining: 203.60 seconds.
# Processed 273/2000 files. Estimated time remaining: 203.40 seconds.
# Processed 274/2000 files. Estimated time remaining: 203.15 seconds.
# Processed 275/2000 files. Estimated time remaining: 202.91 seconds.
# Processed 276/2000 files. Estimated time remaining: 202.70 seconds.
# Processed 277/2000 files. Estimated time remaining: 202.59 seconds.
# Processed 278/2000 files. Estimated time remaining: 202.49 seconds.
# Processed 279/2000 files. Estimated time remaining: 202.21 seconds.
# Processed 280/2000 files. Estimated time remaining: 201.95 seconds.
# Processed 281/2000 files. Estimated time remaining: 201.69 seconds.
# Processed 282/2000 files. Estimated time remaining: 201.54 seconds.
# Processed 283/2000 files. Estimated time remaining: 201.30 seconds.
# Processed 284/2000 files. Estimated time remaining: 201.08 seconds.
# Processed 285/2000 files. Estimated time remaining: 200.92 seconds.
# Processed 286/2000 files. Estimated time remaining: 200.72 seconds.
# Processed 287/2000 files. Estimated time remaining: 200.58 seconds.
# Processed 288/2000 files. Estimated time remaining: 200.53 seconds.
# Processed 289/2000 files. Estimated time remaining: 200.42 seconds.
# Processed 290/2000 files. Estimated time remaining: 200.32 seconds.
# Processed 291/2000 files. Estimated time remaining: 200.25 seconds.
# Processed 292/2000 files. Estimated time remaining: 200.11 seconds.
# Processed 293/2000 files. Estimated time remaining: 200.03 seconds.
# Processed 294/2000 files. Estimated time remaining: 199.81 seconds.
# Processed 295/2000 files. Estimated time remaining: 199.54 seconds.
# Processed 296/2000 files. Estimated time remaining: 199.38 seconds.
# Processed 297/2000 files. Estimated time remaining: 199.25 seconds.
# Processed 298/2000 files. Estimated time remaining: 199.22 seconds.
# Processed 299/2000 files. Estimated time remaining: 198.95 seconds.
# Processed 300/2000 files. Estimated time remaining: 198.79 seconds.
# Processed 301/2000 files. Estimated time remaining: 198.51 seconds.
# Processed 302/2000 files. Estimated time remaining: 198.34 seconds.
# Processed 303/2000 files. Estimated time remaining: 198.29 seconds.
# Processed 304/2000 files. Estimated time remaining: 198.02 seconds.
# Processed 305/2000 files. Estimated time remaining: 197.90 seconds.
# Processed 306/2000 files. Estimated time remaining: 197.86 seconds.
# Processed 307/2000 files. Estimated time remaining: 197.57 seconds.
# Processed 308/2000 files. Estimated time remaining: 197.53 seconds.
# Processed 309/2000 files. Estimated time remaining: 197.30 seconds.
# Processed 310/2000 files. Estimated time remaining: 197.10 seconds.
# Processed 311/2000 files. Estimated time remaining: 196.89 seconds.
# Processed 312/2000 files. Estimated time remaining: 196.80 seconds.
# Processed 313/2000 files. Estimated time remaining: 196.75 seconds.
# Processed 314/2000 files. Estimated time remaining: 196.57 seconds.
# Processed 315/2000 files. Estimated time remaining: 196.34 seconds.
# Processed 316/2000 files. Estimated time remaining: 196.21 seconds.
# Processed 317/2000 files. Estimated time remaining: 195.97 seconds.
# Processed 318/2000 files. Estimated time remaining: 195.65 seconds.
# Processed 319/2000 files. Estimated time remaining: 196.13 seconds.
# Processed 320/2000 files. Estimated time remaining: 196.01 seconds.
# Processed 321/2000 files. Estimated time remaining: 195.84 seconds.
# Processed 322/2000 files. Estimated time remaining: 195.69 seconds.
# Processed 323/2000 files. Estimated time remaining: 195.44 seconds.
# Processed 324/2000 files. Estimated time remaining: 195.34 seconds.
# Processed 325/2000 files. Estimated time remaining: 195.17 seconds.
# Processed 326/2000 files. Estimated time remaining: 195.01 seconds.
# Processed 327/2000 files. Estimated time remaining: 194.80 seconds.
# Processed 328/2000 files. Estimated time remaining: 194.62 seconds.
# Processed 329/2000 files. Estimated time remaining: 194.54 seconds.
# Processed 330/2000 files. Estimated time remaining: 194.62 seconds.
# Processed 331/2000 files. Estimated time remaining: 194.50 seconds.
# Processed 332/2000 files. Estimated time remaining: 194.35 seconds.
# Processed 333/2000 files. Estimated time remaining: 194.34 seconds.
# Processed 334/2000 files. Estimated time remaining: 194.14 seconds.
# Processed 335/2000 files. Estimated time remaining: 194.10 seconds.
# Processed 336/2000 files. Estimated time remaining: 193.92 seconds.
# Processed 337/2000 files. Estimated time remaining: 193.63 seconds.
# Processed 338/2000 files. Estimated time remaining: 193.37 seconds.
# Processed 339/2000 files. Estimated time remaining: 193.09 seconds.
# Processed 340/2000 files. Estimated time remaining: 192.96 seconds.
# Processed 341/2000 files. Estimated time remaining: 192.85 seconds.
# Processed 342/2000 files. Estimated time remaining: 192.68 seconds.
# Processed 343/2000 files. Estimated time remaining: 192.54 seconds.
# Processed 344/2000 files. Estimated time remaining: 192.28 seconds.
# Processed 345/2000 files. Estimated time remaining: 192.04 seconds.
# Processed 346/2000 files. Estimated time remaining: 191.93 seconds.
# Processed 347/2000 files. Estimated time remaining: 191.72 seconds.
# Processed 348/2000 files. Estimated time remaining: 191.55 seconds.
# Processed 349/2000 files. Estimated time remaining: 191.38 seconds.
# Processed 350/2000 files. Estimated time remaining: 191.17 seconds.
# Processed 351/2000 files. Estimated time remaining: 191.03 seconds.
# Processed 352/2000 files. Estimated time remaining: 190.84 seconds.
# Processed 353/2000 files. Estimated time remaining: 190.65 seconds.
# Processed 354/2000 files. Estimated time remaining: 190.53 seconds.
# Processed 355/2000 files. Estimated time remaining: 190.35 seconds.
# Processed 356/2000 files. Estimated time remaining: 190.22 seconds.
# Processed 357/2000 files. Estimated time remaining: 190.16 seconds.
# Processed 358/2000 files. Estimated time remaining: 189.98 seconds.
# Processed 359/2000 files. Estimated time remaining: 189.86 seconds.
# Processed 360/2000 files. Estimated time remaining: 189.68 seconds.
# Processed 361/2000 files. Estimated time remaining: 189.52 seconds.
# Processed 362/2000 files. Estimated time remaining: 189.46 seconds.
# Processed 363/2000 files. Estimated time remaining: 189.35 seconds.
# Processed 364/2000 files. Estimated time remaining: 189.36 seconds.
# Processed 365/2000 files. Estimated time remaining: 189.67 seconds.
# Processed 366/2000 files. Estimated time remaining: 189.54 seconds.
# Processed 367/2000 files. Estimated time remaining: 189.42 seconds.
# Processed 368/2000 files. Estimated time remaining: 189.32 seconds.
# Processed 369/2000 files. Estimated time remaining: 189.11 seconds.
# Processed 370/2000 files. Estimated time remaining: 188.97 seconds.
# Processed 371/2000 files. Estimated time remaining: 188.78 seconds.
# Processed 372/2000 files. Estimated time remaining: 188.75 seconds.
# Processed 373/2000 files. Estimated time remaining: 188.69 seconds.
# Processed 374/2000 files. Estimated time remaining: 188.65 seconds.
# Processed 375/2000 files. Estimated time remaining: 188.50 seconds.
# Processed 376/2000 files. Estimated time remaining: 188.29 seconds.
# Processed 377/2000 files. Estimated time remaining: 188.12 seconds.
# Processed 378/2000 files. Estimated time remaining: 188.02 seconds.
# Processed 379/2000 files. Estimated time remaining: 187.93 seconds.
# Processed 380/2000 files. Estimated time remaining: 187.78 seconds.
# Processed 381/2000 files. Estimated time remaining: 187.60 seconds.
# Processed 382/2000 files. Estimated time remaining: 187.46 seconds.
# Processed 383/2000 files. Estimated time remaining: 187.38 seconds.
# Processed 384/2000 files. Estimated time remaining: 187.20 seconds.
# Processed 385/2000 files. Estimated time remaining: 187.05 seconds.
# Processed 386/2000 files. Estimated time remaining: 186.82 seconds.
# Processed 387/2000 files. Estimated time remaining: 186.64 seconds.
# Processed 388/2000 files. Estimated time remaining: 186.40 seconds.
# Processed 389/2000 files. Estimated time remaining: 186.26 seconds.
# Processed 390/2000 files. Estimated time remaining: 186.06 seconds.
# Processed 391/2000 files. Estimated time remaining: 185.93 seconds.
# Processed 392/2000 files. Estimated time remaining: 185.74 seconds.
# Processed 393/2000 files. Estimated time remaining: 185.62 seconds.
# Processed 394/2000 files. Estimated time remaining: 185.47 seconds.
# Processed 395/2000 files. Estimated time remaining: 185.31 seconds.
# Processed 396/2000 files. Estimated time remaining: 185.63 seconds.
# Processed 397/2000 files. Estimated time remaining: 185.46 seconds.
# Processed 398/2000 files. Estimated time remaining: 185.30 seconds.
# Processed 399/2000 files. Estimated time remaining: 185.24 seconds.
# Processed 400/2000 files. Estimated time remaining: 185.22 seconds.
# Processed 401/2000 files. Estimated time remaining: 185.00 seconds.
# Processed 402/2000 files. Estimated time remaining: 184.85 seconds.
# Processed 403/2000 files. Estimated time remaining: 184.71 seconds.
# Processed 404/2000 files. Estimated time remaining: 184.50 seconds.
# Processed 405/2000 files. Estimated time remaining: 184.85 seconds.
# Processed 406/2000 files. Estimated time remaining: 185.52 seconds.
# Processed 407/2000 files. Estimated time remaining: 185.68 seconds.
# Processed 408/2000 files. Estimated time remaining: 185.44 seconds.
# Processed 409/2000 files. Estimated time remaining: 185.27 seconds.
# Processed 410/2000 files. Estimated time remaining: 185.09 seconds.
# Processed 411/2000 files. Estimated time remaining: 184.98 seconds.
# Processed 412/2000 files. Estimated time remaining: 184.82 seconds.
# Processed 413/2000 files. Estimated time remaining: 184.69 seconds.
# Processed 414/2000 files. Estimated time remaining: 184.55 seconds.
# Processed 415/2000 files. Estimated time remaining: 184.51 seconds.
# Processed 416/2000 files. Estimated time remaining: 184.39 seconds.
# Processed 417/2000 files. Estimated time remaining: 184.32 seconds.
# Processed 418/2000 files. Estimated time remaining: 184.22 seconds.
# Processed 419/2000 files. Estimated time remaining: 184.09 seconds.
# Processed 420/2000 files. Estimated time remaining: 183.91 seconds.
# Processed 421/2000 files. Estimated time remaining: 183.69 seconds.
# Processed 422/2000 files. Estimated time remaining: 183.58 seconds.
# Processed 423/2000 files. Estimated time remaining: 183.36 seconds.
# Processed 424/2000 files. Estimated time remaining: 183.22 seconds.
# Processed 425/2000 files. Estimated time remaining: 183.05 seconds.
# Processed 426/2000 files. Estimated time remaining: 182.83 seconds.
# Processed 427/2000 files. Estimated time remaining: 182.69 seconds.
# Processed 428/2000 files. Estimated time remaining: 182.56 seconds.
# Processed 429/2000 files. Estimated time remaining: 182.31 seconds.
# Processed 430/2000 files. Estimated time remaining: 182.05 seconds.
# Processed 431/2000 files. Estimated time remaining: 181.95 seconds.
# Processed 432/2000 files. Estimated time remaining: 181.78 seconds.
# Processed 433/2000 files. Estimated time remaining: 181.69 seconds.
# Processed 434/2000 files. Estimated time remaining: 181.51 seconds.
# Processed 435/2000 files. Estimated time remaining: 181.35 seconds.
# Processed 436/2000 files. Estimated time remaining: 181.18 seconds.
# Processed 437/2000 files. Estimated time remaining: 181.06 seconds.
# Processed 438/2000 files. Estimated time remaining: 181.00 seconds.
# Processed 439/2000 files. Estimated time remaining: 181.95 seconds.
# Processed 440/2000 files. Estimated time remaining: 182.03 seconds.
# Processed 441/2000 files. Estimated time remaining: 181.86 seconds.
# Processed 442/2000 files. Estimated time remaining: 181.70 seconds.
# Processed 443/2000 files. Estimated time remaining: 181.52 seconds.
# Processed 444/2000 files. Estimated time remaining: 181.37 seconds.
# Processed 445/2000 files. Estimated time remaining: 181.20 seconds.
# Processed 446/2000 files. Estimated time remaining: 181.06 seconds.
# Processed 447/2000 files. Estimated time remaining: 180.91 seconds.
# Processed 448/2000 files. Estimated time remaining: 182.40 seconds.
# Processed 449/2000 files. Estimated time remaining: 182.17 seconds.
# Processed 450/2000 files. Estimated time remaining: 181.99 seconds.
# Processed 451/2000 files. Estimated time remaining: 181.84 seconds.
# Processed 452/2000 files. Estimated time remaining: 181.66 seconds.
# Processed 453/2000 files. Estimated time remaining: 181.50 seconds.
# Processed 454/2000 files. Estimated time remaining: 181.38 seconds.
# Processed 455/2000 files. Estimated time remaining: 181.20 seconds.
# Processed 456/2000 files. Estimated time remaining: 181.05 seconds.
# Processed 457/2000 files. Estimated time remaining: 180.98 seconds.
# Processed 458/2000 files. Estimated time remaining: 180.81 seconds.
# Processed 459/2000 files. Estimated time remaining: 180.68 seconds.
# Processed 460/2000 files. Estimated time remaining: 180.55 seconds.
# Processed 461/2000 files. Estimated time remaining: 180.47 seconds.
# Processed 462/2000 files. Estimated time remaining: 180.31 seconds.
# Processed 463/2000 files. Estimated time remaining: 180.15 seconds.
# Processed 464/2000 files. Estimated time remaining: 180.06 seconds.
# Processed 465/2000 files. Estimated time remaining: 179.85 seconds.
# Processed 466/2000 files. Estimated time remaining: 179.64 seconds.
# Processed 467/2000 files. Estimated time remaining: 179.56 seconds.
# Processed 468/2000 files. Estimated time remaining: 179.35 seconds.
# Processed 469/2000 files. Estimated time remaining: 179.19 seconds.
# Processed 470/2000 files. Estimated time remaining: 179.07 seconds.
# Processed 471/2000 files. Estimated time remaining: 178.91 seconds.
# Processed 472/2000 files. Estimated time remaining: 178.75 seconds.
# Processed 473/2000 files. Estimated time remaining: 178.57 seconds.
# Processed 474/2000 files. Estimated time remaining: 178.49 seconds.
# Processed 475/2000 files. Estimated time remaining: 178.32 seconds.
# Processed 476/2000 files. Estimated time remaining: 178.20 seconds.
# Processed 477/2000 files. Estimated time remaining: 178.03 seconds.
# Processed 478/2000 files. Estimated time remaining: 177.89 seconds.
# Processed 479/2000 files. Estimated time remaining: 177.75 seconds.
# Processed 480/2000 files. Estimated time remaining: 177.55 seconds.
# Processed 481/2000 files. Estimated time remaining: 177.40 seconds.
# Processed 482/2000 files. Estimated time remaining: 177.34 seconds.
# Processed 483/2000 files. Estimated time remaining: 177.12 seconds.
# Processed 484/2000 files. Estimated time remaining: 176.98 seconds.
# Processed 485/2000 files. Estimated time remaining: 176.89 seconds.
# Processed 486/2000 files. Estimated time remaining: 176.66 seconds.
# Processed 487/2000 files. Estimated time remaining: 176.55 seconds.
# Processed 488/2000 files. Estimated time remaining: 176.37 seconds.
# Processed 489/2000 files. Estimated time remaining: 176.23 seconds.
# Processed 490/2000 files. Estimated time remaining: 176.03 seconds.
# Processed 491/2000 files. Estimated time remaining: 175.81 seconds.
# Processed 492/2000 files. Estimated time remaining: 175.62 seconds.
# Processed 493/2000 files. Estimated time remaining: 175.47 seconds.
# Processed 494/2000 files. Estimated time remaining: 175.39 seconds.
# Processed 495/2000 files. Estimated time remaining: 175.27 seconds.
# Processed 496/2000 files. Estimated time remaining: 175.19 seconds.
# Processed 497/2000 files. Estimated time remaining: 175.17 seconds.
# Processed 498/2000 files. Estimated time remaining: 175.07 seconds.
# Processed 499/2000 files. Estimated time remaining: 174.97 seconds.
# Processed 500/2000 files. Estimated time remaining: 174.73 seconds.
# Processed 501/2000 files. Estimated time remaining: 174.55 seconds.
# Processed 502/2000 files. Estimated time remaining: 174.38 seconds.
# Processed 503/2000 files. Estimated time remaining: 174.18 seconds.
# Processed 504/2000 files. Estimated time remaining: 173.99 seconds.
# Processed 505/2000 files. Estimated time remaining: 173.86 seconds.
# Processed 506/2000 files. Estimated time remaining: 173.77 seconds.
# Processed 507/2000 files. Estimated time remaining: 173.63 seconds.
# Processed 508/2000 files. Estimated time remaining: 173.43 seconds.
# Processed 509/2000 files. Estimated time remaining: 173.36 seconds.
# Processed 510/2000 files. Estimated time remaining: 173.27 seconds.
# Processed 511/2000 files. Estimated time remaining: 173.09 seconds.
# Processed 512/2000 files. Estimated time remaining: 172.91 seconds.
# Processed 513/2000 files. Estimated time remaining: 172.75 seconds.
# Processed 514/2000 files. Estimated time remaining: 172.60 seconds.
# Processed 515/2000 files. Estimated time remaining: 172.40 seconds.
# Processed 516/2000 files. Estimated time remaining: 172.25 seconds.
# Processed 517/2000 files. Estimated time remaining: 172.09 seconds.
# Processed 518/2000 files. Estimated time remaining: 171.97 seconds.
# Processed 519/2000 files. Estimated time remaining: 171.83 seconds.
# Processed 520/2000 files. Estimated time remaining: 171.61 seconds.
# Processed 521/2000 files. Estimated time remaining: 171.43 seconds.
# Processed 522/2000 files. Estimated time remaining: 171.33 seconds.
# Processed 523/2000 files. Estimated time remaining: 171.24 seconds.
# Processed 524/2000 files. Estimated time remaining: 171.10 seconds.
# Processed 525/2000 files. Estimated time remaining: 170.90 seconds.
# Processed 526/2000 files. Estimated time remaining: 170.71 seconds.
# Processed 527/2000 files. Estimated time remaining: 170.59 seconds.
# Processed 528/2000 files. Estimated time remaining: 170.51 seconds.
# Processed 529/2000 files. Estimated time remaining: 170.36 seconds.
# Processed 530/2000 files. Estimated time remaining: 170.22 seconds.
# Processed 531/2000 files. Estimated time remaining: 170.11 seconds.
# Processed 532/2000 files. Estimated time remaining: 169.97 seconds.
# Processed 533/2000 files. Estimated time remaining: 169.90 seconds.
# Processed 534/2000 files. Estimated time remaining: 169.74 seconds.
# Processed 535/2000 files. Estimated time remaining: 169.58 seconds.
# Processed 536/2000 files. Estimated time remaining: 169.37 seconds.
# Processed 537/2000 files. Estimated time remaining: 169.20 seconds.
# Processed 538/2000 files. Estimated time remaining: 169.03 seconds.
# Processed 539/2000 files. Estimated time remaining: 168.91 seconds.
# Processed 540/2000 files. Estimated time remaining: 168.80 seconds.
# Processed 541/2000 files. Estimated time remaining: 168.70 seconds.
# Processed 542/2000 files. Estimated time remaining: 168.50 seconds.
# Processed 543/2000 files. Estimated time remaining: 168.44 seconds.
# Processed 544/2000 files. Estimated time remaining: 168.34 seconds.
# Processed 545/2000 files. Estimated time remaining: 168.14 seconds.
# Processed 546/2000 files. Estimated time remaining: 167.94 seconds.
# Processed 547/2000 files. Estimated time remaining: 167.85 seconds.
# Processed 548/2000 files. Estimated time remaining: 167.78 seconds.
# Processed 549/2000 files. Estimated time remaining: 167.60 seconds.
# Processed 550/2000 files. Estimated time remaining: 167.43 seconds.
# Processed 551/2000 files. Estimated time remaining: 167.28 seconds.
# Processed 552/2000 files. Estimated time remaining: 167.12 seconds.
# Processed 553/2000 files. Estimated time remaining: 166.98 seconds.
# Processed 554/2000 files. Estimated time remaining: 166.79 seconds.
# Processed 555/2000 files. Estimated time remaining: 166.71 seconds.
# Processed 556/2000 files. Estimated time remaining: 166.59 seconds.
# Processed 557/2000 files. Estimated time remaining: 166.49 seconds.
# Processed 558/2000 files. Estimated time remaining: 166.40 seconds.
# Processed 559/2000 files. Estimated time remaining: 166.27 seconds.
# Processed 560/2000 files. Estimated time remaining: 166.18 seconds.
# Processed 561/2000 files. Estimated time remaining: 166.04 seconds.
# Processed 562/2000 files. Estimated time remaining: 165.90 seconds.
# Processed 563/2000 files. Estimated time remaining: 165.76 seconds.
# Processed 564/2000 files. Estimated time remaining: 165.62 seconds.
# Processed 565/2000 files. Estimated time remaining: 165.45 seconds.
# Processed 566/2000 files. Estimated time remaining: 165.34 seconds.
# Processed 567/2000 files. Estimated time remaining: 165.24 seconds.
# Processed 568/2000 files. Estimated time remaining: 165.10 seconds.
# Processed 569/2000 files. Estimated time remaining: 164.91 seconds.
# Processed 570/2000 files. Estimated time remaining: 164.76 seconds.
# Processed 571/2000 files. Estimated time remaining: 164.57 seconds.
# Processed 572/2000 files. Estimated time remaining: 164.43 seconds.
# Processed 573/2000 files. Estimated time remaining: 164.30 seconds.
# Processed 574/2000 files. Estimated time remaining: 164.19 seconds.
# Processed 575/2000 files. Estimated time remaining: 164.09 seconds.
# Processed 576/2000 files. Estimated time remaining: 163.93 seconds.
# Processed 577/2000 files. Estimated time remaining: 163.75 seconds.
# Processed 578/2000 files. Estimated time remaining: 163.56 seconds.
# Processed 579/2000 files. Estimated time remaining: 163.43 seconds.
# Processed 580/2000 files. Estimated time remaining: 163.35 seconds.
# Processed 581/2000 files. Estimated time remaining: 163.19 seconds.
# Processed 582/2000 files. Estimated time remaining: 163.07 seconds.
# Processed 583/2000 files. Estimated time remaining: 162.95 seconds.
# Processed 584/2000 files. Estimated time remaining: 162.78 seconds.
# Processed 585/2000 files. Estimated time remaining: 162.70 seconds.
# Processed 586/2000 files. Estimated time remaining: 162.51 seconds.
# Processed 587/2000 files. Estimated time remaining: 162.39 seconds.
# Processed 588/2000 files. Estimated time remaining: 162.28 seconds.
# Processed 589/2000 files. Estimated time remaining: 162.17 seconds.
# Processed 590/2000 files. Estimated time remaining: 162.19 seconds.
# Processed 591/2000 files. Estimated time remaining: 162.03 seconds.
# Processed 592/2000 files. Estimated time remaining: 161.94 seconds.
# Processed 593/2000 files. Estimated time remaining: 162.03 seconds.
# Processed 594/2000 files. Estimated time remaining: 161.93 seconds.
# Processed 595/2000 files. Estimated time remaining: 161.80 seconds.
# Processed 596/2000 files. Estimated time remaining: 161.67 seconds.
# Processed 597/2000 files. Estimated time remaining: 161.52 seconds.
# Processed 598/2000 files. Estimated time remaining: 161.34 seconds.
# Processed 599/2000 files. Estimated time remaining: 161.20 seconds.
# Processed 600/2000 files. Estimated time remaining: 161.05 seconds.
# Processed 601/2000 files. Estimated time remaining: 160.88 seconds.
# Processed 602/2000 files. Estimated time remaining: 160.77 seconds.
# Processed 603/2000 files. Estimated time remaining: 160.63 seconds.
# Processed 604/2000 files. Estimated time remaining: 160.49 seconds.
# Processed 605/2000 files. Estimated time remaining: 160.35 seconds.
# Processed 606/2000 files. Estimated time remaining: 160.22 seconds.
# Processed 607/2000 files. Estimated time remaining: 160.07 seconds.
# Processed 608/2000 files. Estimated time remaining: 159.96 seconds.
# Processed 609/2000 files. Estimated time remaining: 159.83 seconds.
# Processed 610/2000 files. Estimated time remaining: 159.69 seconds.
# Processed 611/2000 files. Estimated time remaining: 159.55 seconds.
# Processed 612/2000 files. Estimated time remaining: 159.41 seconds.
# Processed 613/2000 files. Estimated time remaining: 159.29 seconds.
# Processed 614/2000 files. Estimated time remaining: 159.16 seconds.
# Processed 615/2000 files. Estimated time remaining: 159.01 seconds.
# Processed 616/2000 files. Estimated time remaining: 158.87 seconds.
# Processed 617/2000 files. Estimated time remaining: 158.72 seconds.
# Processed 618/2000 files. Estimated time remaining: 158.60 seconds.
# Processed 619/2000 files. Estimated time remaining: 158.49 seconds.
# Processed 620/2000 files. Estimated time remaining: 158.39 seconds.
# Processed 621/2000 files. Estimated time remaining: 158.26 seconds.
# Processed 622/2000 files. Estimated time remaining: 158.16 seconds.
# Processed 623/2000 files. Estimated time remaining: 158.02 seconds.
# Processed 624/2000 files. Estimated time remaining: 157.92 seconds.
# Processed 625/2000 files. Estimated time remaining: 157.81 seconds.
# Processed 626/2000 files. Estimated time remaining: 157.88 seconds.
# Processed 627/2000 files. Estimated time remaining: 157.76 seconds.
# Processed 628/2000 files. Estimated time remaining: 157.61 seconds.
# Processed 629/2000 files. Estimated time remaining: 157.48 seconds.
# Processed 630/2000 files. Estimated time remaining: 157.36 seconds.
# Processed 631/2000 files. Estimated time remaining: 157.25 seconds.
# Processed 632/2000 files. Estimated time remaining: 157.16 seconds.
# Processed 633/2000 files. Estimated time remaining: 157.02 seconds.
# Processed 634/2000 files. Estimated time remaining: 157.05 seconds.
# Processed 635/2000 files. Estimated time remaining: 156.90 seconds.
# Processed 636/2000 files. Estimated time remaining: 156.79 seconds.
# Processed 637/2000 files. Estimated time remaining: 156.66 seconds.
# Processed 638/2000 files. Estimated time remaining: 156.52 seconds.
# Processed 639/2000 files. Estimated time remaining: 156.45 seconds.
# Processed 640/2000 files. Estimated time remaining: 156.34 seconds.
# Processed 641/2000 files. Estimated time remaining: 156.19 seconds.
# Processed 642/2000 files. Estimated time remaining: 156.03 seconds.
# Processed 643/2000 files. Estimated time remaining: 155.92 seconds.
# Processed 644/2000 files. Estimated time remaining: 155.78 seconds.
# Processed 645/2000 files. Estimated time remaining: 155.62 seconds.
# Processed 646/2000 files. Estimated time remaining: 155.46 seconds.
# Processed 647/2000 files. Estimated time remaining: 155.30 seconds.
# Processed 648/2000 files. Estimated time remaining: 155.19 seconds.
# Processed 649/2000 files. Estimated time remaining: 155.05 seconds.
# Processed 650/2000 files. Estimated time remaining: 154.90 seconds.
# Processed 651/2000 files. Estimated time remaining: 154.79 seconds.
# Processed 652/2000 files. Estimated time remaining: 154.67 seconds.
# Processed 653/2000 files. Estimated time remaining: 154.55 seconds.
# Processed 654/2000 files. Estimated time remaining: 154.47 seconds.
# Processed 655/2000 files. Estimated time remaining: 154.33 seconds.
# Processed 656/2000 files. Estimated time remaining: 154.16 seconds.
# Processed 657/2000 files. Estimated time remaining: 154.03 seconds.
# Processed 658/2000 files. Estimated time remaining: 153.90 seconds.
# Processed 659/2000 files. Estimated time remaining: 153.74 seconds.
# Processed 660/2000 files. Estimated time remaining: 153.59 seconds.
# Processed 661/2000 files. Estimated time remaining: 153.44 seconds.
# Processed 662/2000 files. Estimated time remaining: 153.34 seconds.
# Processed 663/2000 files. Estimated time remaining: 153.23 seconds.
# Processed 664/2000 files. Estimated time remaining: 153.09 seconds.
# Processed 665/2000 files. Estimated time remaining: 152.97 seconds.
# Processed 666/2000 files. Estimated time remaining: 152.83 seconds.
# Processed 667/2000 files. Estimated time remaining: 152.70 seconds.
# Processed 668/2000 files. Estimated time remaining: 152.58 seconds.
# Processed 669/2000 files. Estimated time remaining: 152.41 seconds.
# Processed 670/2000 files. Estimated time remaining: 152.29 seconds.
# Processed 671/2000 files. Estimated time remaining: 152.18 seconds.
# Processed 672/2000 files. Estimated time remaining: 152.78 seconds.
# Processed 673/2000 files. Estimated time remaining: 152.86 seconds.
# Processed 674/2000 files. Estimated time remaining: 152.71 seconds.
# Processed 675/2000 files. Estimated time remaining: 153.44 seconds.
# Processed 676/2000 files. Estimated time remaining: 153.32 seconds.
# Processed 677/2000 files. Estimated time remaining: 153.20 seconds.
# Processed 678/2000 files. Estimated time remaining: 153.08 seconds.
# Processed 679/2000 files. Estimated time remaining: 152.96 seconds.
# Processed 680/2000 files. Estimated time remaining: 152.80 seconds.
# Processed 681/2000 files. Estimated time remaining: 152.71 seconds.
# Processed 682/2000 files. Estimated time remaining: 152.54 seconds.
# Processed 683/2000 files. Estimated time remaining: 152.41 seconds.
# Processed 684/2000 files. Estimated time remaining: 152.30 seconds.
# Processed 685/2000 files. Estimated time remaining: 152.20 seconds.
# Processed 686/2000 files. Estimated time remaining: 152.09 seconds.
# Processed 687/2000 files. Estimated time remaining: 151.96 seconds.
# Processed 688/2000 files. Estimated time remaining: 151.79 seconds.
# Processed 689/2000 files. Estimated time remaining: 151.68 seconds.
# Processed 690/2000 files. Estimated time remaining: 151.57 seconds.
# Processed 691/2000 files. Estimated time remaining: 151.42 seconds.
# Processed 692/2000 files. Estimated time remaining: 151.31 seconds.
# Processed 693/2000 files. Estimated time remaining: 151.17 seconds.
# Processed 694/2000 files. Estimated time remaining: 151.06 seconds.
# Processed 695/2000 files. Estimated time remaining: 150.94 seconds.
# Processed 696/2000 files. Estimated time remaining: 150.85 seconds.
# Processed 697/2000 files. Estimated time remaining: 150.76 seconds.
# Processed 698/2000 files. Estimated time remaining: 150.61 seconds.
# Processed 699/2000 files. Estimated time remaining: 150.50 seconds.
# Processed 700/2000 files. Estimated time remaining: 150.36 seconds.
# Processed 701/2000 files. Estimated time remaining: 150.18 seconds.
# Processed 702/2000 files. Estimated time remaining: 150.03 seconds.
# Processed 703/2000 files. Estimated time remaining: 149.91 seconds.
# Processed 704/2000 files. Estimated time remaining: 149.83 seconds.
# Processed 705/2000 files. Estimated time remaining: 149.74 seconds.
# Processed 706/2000 files. Estimated time remaining: 149.59 seconds.
# Processed 707/2000 files. Estimated time remaining: 149.47 seconds.
# ...
# Processed 1766/2000 files. Estimated time remaining: 39.10 seconds.
# Processed 1767/2000 files. Estimated time remaining: 39.00 seconds.
# Processed 1768/2000 files. Estimated time remaining: 38.84 seconds.
# Processed 1769/2000 files. Estimated time remaining: 38.69 seconds.
# Processed 1770/2000 files. Estimated time remaining: 38.53 seconds.
# Processed 1771/2000 files. Estimated time remaining: 38.39 seconds.
# Processed 1772/2000 files. Estimated time remaining: 38.25 seconds.
# Processed 1773/2000 files. Estimated time remaining: 38.11 seconds.
# Processed 1774/2000 files. Estimated time remaining: 37.97 seconds.
# Processed 1775/2000 files. Estimated time remaining: 37.84 seconds.
# Processed 1776/2000 files. Estimated time remaining: 37.73 seconds.
# Processed 1777/2000 files. Estimated time remaining: 37.60 seconds.
# Processed 1778/2000 files. Estimated time remaining: 37.47 seconds.
# Processed 1779/2000 files. Estimated time remaining: 37.35 seconds.
# Processed 1780/2000 files. Estimated time remaining: 37.21 seconds.
# Processed 1781/2000 files. Estimated time remaining: 37.08 seconds.
# Processed 1782/2000 files. Estimated time remaining: 36.95 seconds.
# Processed 1783/2000 files. Estimated time remaining: 36.83 seconds.
# Processed 1784/2000 files. Estimated time remaining: 36.70 seconds.
# Processed 1785/2000 files. Estimated time remaining: 36.55 seconds.
# Processed 1786/2000 files. Estimated time remaining: 36.43 seconds.
# Processed 1787/2000 files. Estimated time remaining: 36.28 seconds.
# Processed 1788/2000 files. Estimated time remaining: 36.13 seconds.
# Processed 1789/2000 files. Estimated time remaining: 35.97 seconds.
# Processed 1790/2000 files. Estimated time remaining: 35.82 seconds.
# Processed 1791/2000 files. Estimated time remaining: 35.66 seconds.
# Processed 1792/2000 files. Estimated time remaining: 35.52 seconds.
# Processed 1793/2000 files. Estimated time remaining: 35.37 seconds.
# Processed 1794/2000 files. Estimated time remaining: 35.20 seconds.
# Processed 1795/2000 files. Estimated time remaining: 35.04 seconds.
# Processed 1796/2000 files. Estimated time remaining: 34.88 seconds.
# Processed 1797/2000 files. Estimated time remaining: 34.76 seconds.
# Processed 1798/2000 files. Estimated time remaining: 34.63 seconds.
# Processed 1799/2000 files. Estimated time remaining: 34.47 seconds.
# Processed 1800/2000 files. Estimated time remaining: 34.31 seconds.
# Processed 1801/2000 files. Estimated time remaining: 34.17 seconds.
# Processed 1802/2000 files. Estimated time remaining: 34.06 seconds.
# Processed 1803/2000 files. Estimated time remaining: 33.92 seconds.
# Processed 1804/2000 files. Estimated time remaining: 33.78 seconds.
# Processed 1805/2000 files. Estimated time remaining: 33.65 seconds.
# Processed 1806/2000 files. Estimated time remaining: 33.49 seconds.
# Processed 1807/2000 files. Estimated time remaining: 33.36 seconds.
# Processed 1808/2000 files. Estimated time remaining: 33.20 seconds.
# Processed 1809/2000 files. Estimated time remaining: 33.07 seconds.
# Processed 1810/2000 files. Estimated time remaining: 32.91 seconds.
# Processed 1811/2000 files. Estimated time remaining: 32.77 seconds.
# Processed 1812/2000 files. Estimated time remaining: 32.63 seconds.
# Processed 1813/2000 files. Estimated time remaining: 32.50 seconds.
# Processed 1814/2000 files. Estimated time remaining: 32.35 seconds.
# Processed 1815/2000 files. Estimated time remaining: 32.20 seconds.
# Processed 1816/2000 files. Estimated time remaining: 32.03 seconds.
# Processed 1817/2000 files. Estimated time remaining: 31.88 seconds.
# Processed 1818/2000 files. Estimated time remaining: 31.71 seconds.
# Processed 1819/2000 files. Estimated time remaining: 31.54 seconds.
# Processed 1820/2000 files. Estimated time remaining: 31.38 seconds.
# Processed 1821/2000 files. Estimated time remaining: 31.21 seconds.
# Processed 1822/2000 files. Estimated time remaining: 31.05 seconds.
# Processed 1823/2000 files. Estimated time remaining: 30.89 seconds.
# Processed 1824/2000 files. Estimated time remaining: 30.73 seconds.
# Processed 1825/2000 files. Estimated time remaining: 30.57 seconds.
# Processed 1826/2000 files. Estimated time remaining: 30.41 seconds.
# Processed 1827/2000 files. Estimated time remaining: 30.25 seconds.
# Processed 1828/2000 files. Estimated time remaining: 30.11 seconds.
# Processed 1829/2000 files. Estimated time remaining: 29.95 seconds.
# Processed 1830/2000 files. Estimated time remaining: 29.79 seconds.
# Processed 1831/2000 files. Estimated time remaining: 29.64 seconds.
# Processed 1832/2000 files. Estimated time remaining: 29.48 seconds.
# Processed 1833/2000 files. Estimated time remaining: 29.33 seconds.
# Processed 1834/2000 files. Estimated time remaining: 29.16 seconds.
# Processed 1835/2000 files. Estimated time remaining: 29.00 seconds.
# Processed 1836/2000 files. Estimated time remaining: 28.83 seconds.
# Processed 1837/2000 files. Estimated time remaining: 28.66 seconds.
# Processed 1838/2000 files. Estimated time remaining: 28.52 seconds.
# Processed 1839/2000 files. Estimated time remaining: 28.35 seconds.
# Processed 1840/2000 files. Estimated time remaining: 28.18 seconds.
# Processed 1841/2000 files. Estimated time remaining: 28.02 seconds.
# Processed 1842/2000 files. Estimated time remaining: 27.85 seconds.
# Processed 1843/2000 files. Estimated time remaining: 27.71 seconds.
# Processed 1844/2000 files. Estimated time remaining: 27.55 seconds.
# Processed 1845/2000 files. Estimated time remaining: 27.40 seconds.
# Processed 1846/2000 files. Estimated time remaining: 27.25 seconds.
# Processed 1847/2000 files. Estimated time remaining: 27.09 seconds.
# Processed 1848/2000 files. Estimated time remaining: 26.94 seconds.
# Processed 1849/2000 files. Estimated time remaining: 26.78 seconds.
# Processed 1850/2000 files. Estimated time remaining: 26.63 seconds.
# Processed 1851/2000 files. Estimated time remaining: 26.46 seconds.
# Processed 1852/2000 files. Estimated time remaining: 26.30 seconds.
# Processed 1853/2000 files. Estimated time remaining: 26.13 seconds.
# Processed 1854/2000 files. Estimated time remaining: 25.96 seconds.
# Processed 1855/2000 files. Estimated time remaining: 25.79 seconds.
# Processed 1856/2000 files. Estimated time remaining: 25.64 seconds.
# Processed 1857/2000 files. Estimated time remaining: 25.47 seconds.
# Processed 1858/2000 files. Estimated time remaining: 25.32 seconds.
# Processed 1859/2000 files. Estimated time remaining: 25.17 seconds.
# Processed 1860/2000 files. Estimated time remaining: 25.01 seconds.
# Processed 1861/2000 files. Estimated time remaining: 24.85 seconds.
# Processed 1862/2000 files. Estimated time remaining: 24.69 seconds.
# Processed 1863/2000 files. Estimated time remaining: 24.53 seconds.
# Processed 1864/2000 files. Estimated time remaining: 24.37 seconds.
# Processed 1865/2000 files. Estimated time remaining: 24.21 seconds.
# Processed 1866/2000 files. Estimated time remaining: 24.06 seconds.
# Processed 1867/2000 files. Estimated time remaining: 23.89 seconds.
# Processed 1868/2000 files. Estimated time remaining: 23.72 seconds.
# Processed 1869/2000 files. Estimated time remaining: 23.55 seconds.
# Processed 1870/2000 files. Estimated time remaining: 23.39 seconds.
# Processed 1871/2000 files. Estimated time remaining: 23.22 seconds.
# Processed 1872/2000 files. Estimated time remaining: 23.05 seconds.
# Processed 1873/2000 files. Estimated time remaining: 22.88 seconds.
# Processed 1874/2000 files. Estimated time remaining: 22.71 seconds.
# Processed 1875/2000 files. Estimated time remaining: 22.54 seconds.
# Processed 1876/2000 files. Estimated time remaining: 22.37 seconds.
# Processed 1877/2000 files. Estimated time remaining: 22.20 seconds.
# Processed 1878/2000 files. Estimated time remaining: 22.03 seconds.
# Processed 1879/2000 files. Estimated time remaining: 21.85 seconds.
# Processed 1880/2000 files. Estimated time remaining: 21.68 seconds.
# Processed 1881/2000 files. Estimated time remaining: 21.51 seconds.
# Processed 1882/2000 files. Estimated time remaining: 21.35 seconds.
# Processed 1883/2000 files. Estimated time remaining: 21.19 seconds.
# Processed 1884/2000 files. Estimated time remaining: 21.02 seconds.
# Processed 1885/2000 files. Estimated time remaining: 20.85 seconds.
# Processed 1886/2000 files. Estimated time remaining: 20.68 seconds.
# Processed 1887/2000 files. Estimated time remaining: 20.51 seconds.
# Processed 1888/2000 files. Estimated time remaining: 20.34 seconds.
# Processed 1889/2000 files. Estimated time remaining: 20.17 seconds.
# Processed 1890/2000 files. Estimated time remaining: 20.01 seconds.
# Processed 1891/2000 files. Estimated time remaining: 19.84 seconds.
# Processed 1892/2000 files. Estimated time remaining: 19.66 seconds.
# Processed 1893/2000 files. Estimated time remaining: 19.48 seconds.
# Processed 1894/2000 files. Estimated time remaining: 19.31 seconds.
# Processed 1895/2000 files. Estimated time remaining: 19.14 seconds.
# Processed 1896/2000 files. Estimated time remaining: 18.98 seconds.
# Processed 1897/2000 files. Estimated time remaining: 18.81 seconds.
# Processed 1898/2000 files. Estimated time remaining: 18.65 seconds.
# Processed 1899/2000 files. Estimated time remaining: 18.49 seconds.
# Processed 1900/2000 files. Estimated time remaining: 18.32 seconds.
# Processed 1901/2000 files. Estimated time remaining: 18.15 seconds.
# Processed 1902/2000 files. Estimated time remaining: 17.99 seconds.
# Processed 1903/2000 files. Estimated time remaining: 17.82 seconds.
# Processed 1904/2000 files. Estimated time remaining: 17.65 seconds.
# Processed 1905/2000 files. Estimated time remaining: 17.49 seconds.
# Processed 1906/2000 files. Estimated time remaining: 17.32 seconds.
# Processed 1907/2000 files. Estimated time remaining: 17.15 seconds.
# Processed 1908/2000 files. Estimated time remaining: 16.98 seconds.
# Processed 1909/2000 files. Estimated time remaining: 16.81 seconds.
# Processed 1910/2000 files. Estimated time remaining: 16.65 seconds.
# Processed 1911/2000 files. Estimated time remaining: 16.48 seconds.
# Processed 1912/2000 files. Estimated time remaining: 16.31 seconds.
# Processed 1913/2000 files. Estimated time remaining: 16.14 seconds.
# Processed 1914/2000 files. Estimated time remaining: 15.97 seconds.
# Processed 1915/2000 files. Estimated time remaining: 15.80 seconds.
# Processed 1916/2000 files. Estimated time remaining: 15.62 seconds.
# Processed 1917/2000 files. Estimated time remaining: 15.46 seconds.
# Processed 1918/2000 files. Estimated time remaining: 15.29 seconds.
# Processed 1919/2000 files. Estimated time remaining: 15.11 seconds.
# Processed 1920/2000 files. Estimated time remaining: 14.94 seconds.
# Processed 1921/2000 files. Estimated time remaining: 14.76 seconds.
# Processed 1922/2000 files. Estimated time remaining: 14.59 seconds.
# Processed 1923/2000 files. Estimated time remaining: 14.42 seconds.
# Processed 1924/2000 files. Estimated time remaining: 14.24 seconds.
# Processed 1925/2000 files. Estimated time remaining: 14.07 seconds.
# Processed 1926/2000 files. Estimated time remaining: 13.89 seconds.
# Processed 1927/2000 files. Estimated time remaining: 13.72 seconds.
# Processed 1928/2000 files. Estimated time remaining: 13.54 seconds.
# Processed 1929/2000 files. Estimated time remaining: 13.37 seconds.
# Processed 1930/2000 files. Estimated time remaining: 13.19 seconds.
# Processed 1931/2000 files. Estimated time remaining: 13.02 seconds.
# Processed 1932/2000 files. Estimated time remaining: 12.84 seconds.
# Processed 1933/2000 files. Estimated time remaining: 12.66 seconds.
# Processed 1934/2000 files. Estimated time remaining: 12.48 seconds.
# Processed 1935/2000 files. Estimated time remaining: 12.30 seconds.
# Processed 1936/2000 files. Estimated time remaining: 12.13 seconds.
# Processed 1937/2000 files. Estimated time remaining: 11.95 seconds.
# Processed 1938/2000 files. Estimated time remaining: 11.77 seconds.
# Processed 1939/2000 files. Estimated time remaining: 11.59 seconds.
# Processed 1940/2000 files. Estimated time remaining: 11.41 seconds.
# Processed 1941/2000 files. Estimated time remaining: 11.23 seconds.
# Processed 1942/2000 files. Estimated time remaining: 11.05 seconds.
# Processed 1943/2000 files. Estimated time remaining: 10.86 seconds.
# Processed 1944/2000 files. Estimated time remaining: 10.68 seconds.
# Processed 1945/2000 files. Estimated time remaining: 10.50 seconds.
# Processed 1946/2000 files. Estimated time remaining: 10.32 seconds.
# Processed 1947/2000 files. Estimated time remaining: 10.14 seconds.
# Processed 1948/2000 files. Estimated time remaining: 9.96 seconds.
# Processed 1949/2000 files. Estimated time remaining: 9.77 seconds.
# Processed 1950/2000 files. Estimated time remaining: 9.59 seconds.
# Processed 1951/2000 files. Estimated time remaining: 9.41 seconds.
# Processed 1952/2000 files. Estimated time remaining: 9.22 seconds.
# Processed 1953/2000 files. Estimated time remaining: 9.04 seconds.
# Processed 1954/2000 files. Estimated time remaining: 8.85 seconds.
# Processed 1955/2000 files. Estimated time remaining: 8.67 seconds.
# Processed 1956/2000 files. Estimated time remaining: 8.48 seconds.
# Processed 1957/2000 files. Estimated time remaining: 8.30 seconds.
# Processed 1958/2000 files. Estimated time remaining: 8.11 seconds.
# Processed 1959/2000 files. Estimated time remaining: 7.93 seconds.
# Processed 1960/2000 files. Estimated time remaining: 7.74 seconds.
# Processed 1961/2000 files. Estimated time remaining: 7.55 seconds.
# Processed 1962/2000 files. Estimated time remaining: 7.36 seconds.
# Processed 1963/2000 files. Estimated time remaining: 7.18 seconds.
# Processed 1964/2000 files. Estimated time remaining: 6.99 seconds.
# Processed 1965/2000 files. Estimated time remaining: 6.80 seconds.
# Processed 1966/2000 files. Estimated time remaining: 6.61 seconds.
# Processed 1967/2000 files. Estimated time remaining: 6.42 seconds.
# Processed 1968/2000 files. Estimated time remaining: 6.23 seconds.
# Processed 1969/2000 files. Estimated time remaining: 6.05 seconds.
# Processed 1970/2000 files. Estimated time remaining: 5.85 seconds.
# Processed 1971/2000 files. Estimated time remaining: 5.66 seconds.
# Processed 1972/2000 files. Estimated time remaining: 5.47 seconds.
# Processed 1973/2000 files. Estimated time remaining: 5.28 seconds.
# Processed 1974/2000 files. Estimated time remaining: 5.09 seconds.
# Processed 1975/2000 files. Estimated time remaining: 4.90 seconds.
# Processed 1976/2000 files. Estimated time remaining: 4.71 seconds.
# Processed 1977/2000 files. Estimated time remaining: 4.52 seconds.
# Processed 1978/2000 files. Estimated time remaining: 4.32 seconds.
# Processed 1979/2000 files. Estimated time remaining: 4.13 seconds.
# Processed 1980/2000 files. Estimated time remaining: 3.94 seconds.
# Processed 1981/2000 files. Estimated time remaining: 3.74 seconds.
# Processed 1982/2000 files. Estimated time remaining: 3.55 seconds.
# Processed 1983/2000 files. Estimated time remaining: 3.35 seconds.
# Processed 1984/2000 files. Estimated time remaining: 3.16 seconds.
# Processed 1985/2000 files. Estimated time remaining: 2.96 seconds.
# Processed 1986/2000 files. Estimated time remaining: 2.77 seconds.
# Processed 1987/2000 files. Estimated time remaining: 2.57 seconds.
# Processed 1988/2000 files. Estimated time remaining: 2.38 seconds.
# Processed 1989/2000 files. Estimated time remaining: 2.18 seconds.
# Processed 1990/2000 files. Estimated time remaining: 1.98 seconds.
# Processed 1991/2000 files. Estimated time remaining: 1.79 seconds.
# Processed 1992/2000 files. Estimated time remaining: 1.59 seconds.
# Processed 1993/2000 files. Estimated time remaining: 1.39 seconds.
# Processed 1994/2000 files. Estimated time remaining: 1.19 seconds.
# Processed 1995/2000 files. Estimated time remaining: 1.00 seconds.
# Processed 1996/2000 files. Estimated time remaining: 0.80 seconds.
# Processed 1997/2000 files. Estimated time remaining: 0.60 seconds.
# Processed 1998/2000 files. Estimated time remaining: 0.40 seconds.
# Processed 1999/2000 files. Estimated time remaining: 0.20 seconds.
# Processed 2000/2000 files. Estimated time remaining: 0.00 seconds.
# Processing completed.

# %%
#Predicting label image from individual files
import torch
from PIL import Image
from model import Darknet
from torchvision.utils import save_image
import numpy as np
from transform_utils import lidar_transform,intensity_transform


# Prepare the input data
lidar_path = "/DATA2/Vivek/Data/Downstream Task/Test/test_lidar_depth/03_000002.npy"
intensity_path = "/DATA2/Vivek/Data/Downstream Task/Train/train_lidar_depth/03_000011.npy"

# Load the input images
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Darknet(in_channels=1, out_channels=20)  # Initialize your model architecture
#optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
checkpoint = torch.load('/DATA2/Vivek/Code/Implementation/Downstream Task/RangeNet/Output/T1/T1_model.pth.tar')

model.load_state_dict(checkpoint['state_dict'])
#optimizer.load_state_dict(checkpoint['optimizer'])

model.to(device)
model.eval()  # Switch the model to evaluation mode

lidar = np.load(lidar_path)
lidar = np.expand_dims(lidar, axis=0)  # Add channel dimension
lidar = torch.from_numpy(lidar).float()

# Load intensity data with channel dimension added
intensity = np.load(intensity_path)
intensity = np.expand_dims(intensity, axis=0)  # Add channel dimension
intensity = torch.from_numpy(intensity).float()

       
            
#concatenated_img = np.concatenate((lidar[..., np.newaxis], camera,incidence[..., np.newaxis]), axis=2)
#input_data = torch.cat((binary, label,incidence,lidar, color, rgb), dim=0)
input_data = lidar
input_data = input_data.unsqueeze(0) 

input_data = input_data.to(device)
with torch.no_grad():
    output = model(input_data)

output = output.squeeze(dim=0)


# Check if the output tensor is on the GPU and move it to CPU
if output.is_cuda:
    output = output.cpu()

output_array = output.numpy()

output_array = np.argmax(output_array, axis=0)

# Save output array to .npy file
np.save('output.npy', output_array)

# %%
#Predicting label image from entire folder


import os
import torch
import numpy as np
from model import Darknet

def process_lidar_intensity(lidar_path, intensity_path, model, device):
    # Load the lidar data
    lidar = np.load(lidar_path)
    lidar = np.expand_dims(lidar, axis=0)  # Add channel dimension
    lidar = torch.from_numpy(lidar).float().to(device)

    # Load the intensity data
    intensity = np.load(intensity_path)
    intensity = np.expand_dims(intensity, axis=0)  # Add channel dimension
    intensity = torch.from_numpy(intensity).float().to(device)

    # Concatenate the lidar and intensity data
    #input_data = torch.cat((lidar, intensity), dim=0)
    input_data = lidar
    # Add a batch dimension
    input_data = input_data.unsqueeze(0)

    # Perform inference
    with torch.no_grad():
        output = model(input_data)

    output = output.squeeze(dim=0)

    # Move the output tensor to CPU and convert to numpy array
    output_array = output.cpu().numpy()

    # Find the class with the highest probability for each pixel
    output_array = np.argmax(output_array, axis=0)

    return output_array


# Define the paths to the folders containing lidar and intensity images
lidar_folder = "/DATA2/Vivek/Data/Downstream Task/Train/train_lidar_depth/"
intensity_folder = "/DATA2/Vivek/Data/Downstream Task/Train/train_lidar_depth/"
output_folder = "/DATA2/Vivek/Code/Implementation/Downstream Task/RangeNet/Output/Pred_output_train"  # Specify the output folder path

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Initialize your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Darknet(in_channels=1, out_channels=20)  # Initialize your model architecture
checkpoint = torch.load('/DATA2/Vivek/Code/Implementation/Downstream Task/RangeNet/Output/T1/T1_model.pth.tar')
model.load_state_dict(checkpoint['state_dict'])
model.to(device)
model.eval()  # Switch the model to evaluation mode

# Iterate through the files in the folders
for lidar_file in os.listdir(lidar_folder):
    if lidar_file.endswith(".npy"):
        lidar_path = os.path.join(lidar_folder, lidar_file)
        intensity_file = lidar_file.replace("lidar_depth", "intensity_depth")
        intensity_path = os.path.join(intensity_folder, intensity_file)

        # Process lidar and intensity data
        output_array = process_lidar_intensity(lidar_path, intensity_path, model, device)

        # Save output array to .npy file in the output folder
        output_filename = os.path.splitext(lidar_file)[0] + ".npy"
        output_filepath = os.path.join(output_folder, output_filename)
        np.save(output_filepath, output_array)

# %%
#Checking the float and long operation on label tensor 

import numpy as np
import torch

# Load the label file
label_file_path = "/DATA2/Vivek/Vivekk/Data/VoxelScape/Voxel_Downstream_Task/Train/train_lidar_label/03_000859.npy"
semantic_image = np.load(label_file_path)

# Display the unique values before conversion
print("Semantic Image (Before Conversion):")
print(np.unique(semantic_image))

# Convert the label image to a PyTorch tensor and to long data type
semantic_tensor = torch.from_numpy(semantic_image).float()

# Display the unique values after conversion
print("\nSemantic Tensor (After Conversion):")
print(torch.unique(semantic_tensor))
# Out:
# Semantic Image (Before Conversion):
# [ 0.  1.  2.  3.  4.  5.  6.  7.  9. 13. 15. 17. 18.]
#
# Semantic Tensor (After Conversion):
# tensor([ 0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  9., 13., 15., 17., 18.])

# %%
#Predicted Output
import numpy as np
import matplotlib.pyplot as plt

learning_map = {
    0: 0,     # "unlabeled"
    1: 0,     # "outlier" mapped to "unlabeled"
    10: 1,    # "car"
    11: 2,    # "bicycle"
    13: 5,    # "bus" mapped to "other-vehicle"
    15: 3,    # "motorcycle"
    16: 5,    # "on-rails" mapped to "other-vehicle"
    18: 4,    # "truck"
    20: 5,    # "other-vehicle"
    30: 6,    # "person"
    31: 7,    # "bicyclist"
    32: 8,    # "motorcyclist"
    40: 9,    # "road"
    44: 10,   # "parking"
    48: 11,   # "sidewalk"
    49: 12,   # "other-ground"
    50: 13,   # "building"
    51: 14,   # "fence"
    52: 0,    # "other-structure" mapped to "unlabeled"
    60: 9,    # "lane-marking" to "road"
    70: 15,   # "vegetation"
    71: 16,   # "trunk"
    72: 17,   # "terrain"
    80: 18,   # "pole"
    81: 19,   # "traffic-sign"
    99: 0,    # "other-object" to "unlabeled"
    252: 1,   # "moving-car" to "car"
    253: 7,   # "moving-bicyclist" to "bicyclist"
    254: 6,   # "moving-person" to "person"
    255: 8,   # "moving-motorcyclist" to "motorcyclist"
    256: 5,   # "moving-on-rails" mapped to "other-vehicle"
    257: 5,   # "moving-bus" mapped to "other-vehicle"
    258: 4,   # "moving-truck" to "truck"
    259: 5    # "moving-other-vehicle" to "other-vehicle"
}

# Define the inverse mapping dictionary
learning_map_inv = {
    0: 0,     # "unlabeled"
    1: 0,     # "outlier" mapped to "unlabeled"
    10: 1,    # "car"
    11: 2,    # "bicycle"
    13: 5,    # "bus" mapped to "other-vehicle"
    15: 3,    # "motorcycle"
    16: 5,    # "on-rails" mapped to "other-vehicle"
    18: 4,    # "truck"
    20: 5,    # "other-vehicle"
    30: 6,    # "person"
    31: 7,    # "bicyclist"
    32: 8,    # "motorcyclist"
    40: 9,    # "road"
    44: 10,   # "parking"
    48: 11,   # "sidewalk"
    49: 12,   # "other-ground"
    50: 13,   # "building"
    51: 14,   # "fence"
    52: 0,    # "other-structure" mapped to "unlabeled"
    60: 9,    # "lane-marking" to "road"
    70: 15,   # "vegetation"
    71: 16,   # "trunk"
    72: 17,   # "terrain"
    80: 18,   # "pole"
    81: 19,   # "traffic-sign"
    99: 0,    # "other-object" to "unlabeled"
    252: 1,   # "moving-car" to "car"
    253: 7,   # "moving-bicyclist" to "bicyclist"
    254: 6,   # "moving-person" to "person"
    255: 8,   # "moving-motorcyclist" to "motorcyclist"
    256: 5,   # "moving-on-rails" mapped to "other-vehicle"
    257: 5,   # "moving-bus" mapped to "other-vehicle"
    258: 4,   # "moving-truck" to "truck"
    259: 5    # "moving-other-vehicle" to "other-vehicle"
}

# Define the color mapping dictionary
color_map = {
    0: [0, 0, 0],
    1: [0, 0, 255],
    10: [245, 150, 100],
    11: [245, 230, 100],
    13: [250, 80, 100],
    15: [150, 60, 30],
    16: [255, 0, 0],
    18: [180, 30, 80],
    20: [255, 0, 0],
    30: [30, 30, 255],
    31: [200, 40, 255],
    32: [90, 30, 150],
    40: [255, 0, 255],
    44: [255, 150, 255],
    48: [75, 0, 75],
    49: [75, 0, 175],
    50: [0, 200, 255],
    51: [50, 120, 255],
    52: [0, 150, 255],
    60: [170, 255, 150],
    70: [0, 175, 0],
    71: [0, 60, 135],
    72: [80, 240, 150],
    80: [150, 240, 255],
    81: [0, 0, 255],
    99: [255, 255, 50],
    252: [245, 150, 100],
    256: [255, 0, 0],
    253: [200, 40, 255],
    254: [30, 30, 255],
    255: [90, 30, 150],
    257: [250, 80, 100],
    258: [180, 30, 80],
    259: [255, 0, 0]
}

# Load the NumPy file
file_path = "/DATA2/Vivek/Vivekk/Data/VoxelScape/Voxel_Downstream_Task/Train/train_lidar_label/03_000859.npy"
data = np.load(file_path)

# Define inverse mapping function (assuming keys are unique)
def inverse_map(val):
  for key, value in learning_map.items():
    if value == val:
      return key
  return 0  # Assign unlabeled value if not found

# Apply inverse mapping to the data
data_mapped = np.vectorize(inverse_map)(data)

# Create color image based on color map
color_image = np.empty((data.shape[0], data.shape[1], 3), dtype=np.uint8)
for i in range(data_mapped.shape[0]):
  for j in range(data_mapped.shape[1]):
    color_image[i, j] = color_map[data_mapped[i, j]]

# Display the color image without ticks and border
plt.imshow(color_image, extent=(0, data.shape[1], 0, data.shape[0]))  # Set extent
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#target
import numpy as np
import matplotlib.pyplot as plt


# Load the NumPy file
file_path = "/DATA2/Vivek/Data/Downstream Task/Test/test_lidar_label/03_000002.npy"
data = np.load(file_path)

# Define inverse mapping function (assuming keys are unique)
def inverse_map(val):
  for key, value in learning_map.items():
    if value == val:
      return key
  return 0  # Assign unlabeled value if not found

# Apply inverse mapping to the data
data_mapped = np.vectorize(inverse_map)(data)

# Create color image based on color map
color_image = np.empty((data.shape[0], data.shape[1], 3), dtype=np.uint8)
for i in range(data_mapped.shape[0]):
  for j in range(data_mapped.shape[1]):
    color_image[i, j] = color_map[data_mapped[i, j]]

# Display the color image without ticks and border
plt.imshow(color_image, extent=(0, data.shape[1], 0, data.shape[0]))  # Set extent
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the label file
file_path = "/DATA2/Vivek/Vivekk/Data/VoxelScape/Voxel_Downstream_Task/Train/train_lidar_z/03_000668.npy"
data = np.load(file_path)
print(data.shape)

# Plot the 2D data as a grayscale image
plt.imshow(data, cmap='gray')
#plt.xlabel('X-axis')
#plt.ylabel('Y-axis')
plt.show()

print("Data values:\n", data)

# Calculate and print the data range
data_min = np.min(data)
data_max = np.max(data)
print(f"Data range: {data_min} to {data_max}")
# Out:
# (64, 1024)
# Data values:
#  [[ 0.61219656  0.6123923   0.6128005  ...  0.61098206  0.6113018
#    0.61164343]
#  [ 0.3351072   0.3352114   0.33542883 ...  0.3344592   0.33462846
#    0.33480966]
#  [ 0.19663036  0.19668901  0.19681108 ...  0.19627273  0.19636667
#    0.19646752]
#  ...
#  [ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [-1.9636306  -1.9636331  -1.9636378  ... -1.9636095  -1.9636161
#   -1.9636223 ]
#  [ 0.          0.          0.         ...  0.          0.
#    0.        ]]
# Data range: -2.1288056 to 2.318141
