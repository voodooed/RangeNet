# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
import io
import cv2
import time

# %%
def lidar_to_2d_front_view(points,
                           v_res,
                           h_res,
                           v_fov,
                           val="depth",
                           cmap="jet",
                           saveto=None,
                           y_fudge=0.0
                           ):
    """ Takes points in 3D space from LIDAR data and projects them to a 2D
        "front view" image, and saves that image.

    Args:
        points: (np array)
            The numpy array containing the lidar points.
            The shape should be Nx4
            - Where N is the number of points, and
            - each point is specified by 4 values (x, y, z, reflectance)
        v_res: (float)
            vertical resolution of the lidar sensor used.
        h_res: (float)
            horizontal resolution of the lidar sensor used.
        v_fov: (tuple of two floats)
            (minimum_negative_angle, max_positive_angle)
        val: (str)
            What value to use to encode the points that get plotted.
            One of {"depth", "height", "reflectance"}
        cmap: (str)
            Color map to use to color code the `val` values.
            NOTE: Must be a value accepted by matplotlib's scatter function
            Examples: "jet", "gray"
        saveto: (str or None)
            If a string is provided, it saves the image as this filename.
            If None, then it just shows the image.
        y_fudge: (float)
            A hacky fudge factor to use if the theoretical calculations of
            vertical range do not match the actual data.

            For a Velodyne HDL 64E, set this value to 5.
    """

    # DUMMY PROOFING
    assert len(v_fov) ==2, "v_fov must be list/tuple of length 2"
    assert v_fov[0] <= 0, "first element in v_fov must be 0 or negative"
    #assert val in {"depth", "height", "intensity"}, \
        #'val must be one of {"depth", "height", "intensity"}'


    x_lidar = points[:, 0]
    y_lidar = points[:, 1]
    z_lidar = points[:, 2]
    r_lidar = points[:, 3] # Reflectance
    # Distance relative to origin when looked from top
    d_lidar = np.sqrt(x_lidar ** 2 + y_lidar ** 2)
    # Absolute distance relative to origin
    d_lidar_abs = np.sqrt(x_lidar ** 2 + y_lidar ** 2, z_lidar ** 2)

    v_fov_total = -v_fov[0] + v_fov[1]

    # Convert to Radians
    v_res_rad = v_res * (np.pi/180)
    h_res_rad = h_res * (np.pi/180)

    # PROJECT INTO IMAGE COORDINATES
    x_img = np.arctan2(-y_lidar, x_lidar)/ h_res_rad #theta 
    y_img = np.arctan2(z_lidar, d_lidar_abs)/ v_res_rad #phi


    # SHIFT COORDINATES TO MAKE 0,0 THE MINIMUM
    x_min = -360.0 / h_res / 2  # Theoretical min x value based on sensor specs
    x_img -= x_min              # Shift
    x_max = 360.0 / h_res       # Theoretical max x value after shifting

    y_min = v_fov[0] / v_res    # theoretical min y value based on sensor specs
    y_img -= y_min              # Shift
    y_max = v_fov_total / v_res # Theoretical max x value after shifting

    y_max += y_fudge            # Fudge factor if the calculations based on
                                # spec sheet do not match the range of
                                # angles collected by in the data.

    # WHAT DATA TO USE TO ENCODE THE VALUE FOR EACH PIXEL
    if val == "intensity":
        pixel_values = r_lidar
    elif val == "height":
        pixel_values = z_lidar
    elif val == "x":
        pixel_values = x_lidar
    elif val == "y":
        pixel_values = y_lidar
    elif val == "z":
        pixel_values = z_lidar
    
    else:
        pixel_values = d_lidar

    pixel_values=np.array(pixel_values)

    # Rescale x_img and y_img to fit within 64x1024 grid
    x_img_scaled = (x_img / x_max) * 1024
    y_img_scaled = (y_img / y_max) * 64


    # Create a 2D array to store pixel values
    image_array = np.zeros((64, 1024))

    # Assign pixel values to the corresponding grid points
    for i in range(len(x_img_scaled)):
        x_index = int(round(x_img_scaled[i]))
        y_index = int(round(y_img_scaled[i]))
        if 0 <= x_index < 1024 and 0 <= y_index < 64:
            image_array[63-y_index, x_index] = pixel_values[i]

    if saveto is not None:
        np.save(saveto, image_array)

# %%
# set input and output folder paths
folder = 'Train'
input_folder = rf"/DATA2/Vivek/Data/Csv/csv files/Subset_Downstream_Task/{folder}"
output_folder = rf"/DATA2/Vivek/Data/Downstream Task/{folder}/train_lidar_intensity"

# create output folder if it does not exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
HRES = 0.35         # horizontal resolution (assuming 20Hz setting)
VRES = 0.4          # vertical res
#VFOV = (-25, 15) # Field of view (-ve, +ve) along vertical axis
VFOV = (-25, 2) # Field of view (-ve, +ve) along vertical axis
Y_FUDGE = 0         # y fudge factor for velodyne HDL 64E

#val must be one of {"depth", "height", "intensity","angle"}
value = "intensity"



all_files = [filename for filename in os.listdir(input_folder) if filename.endswith('.csv')]
total_files = len(all_files)
start_time = time.time()

for index, filename in enumerate(all_files):
    # read CSV file into pandas dataframe
    df = pd.read_csv(os.path.join(input_folder, filename))
    
    # convert dataframe to numpy array
    lidar = np.array(df[['x', 'y', 'z', 'intensity']])
    
    # apply lidar_to_2d_front_view function
    output_filename = os.path.splitext(filename)[0] + '.npy'
    output_path = os.path.join(output_folder, output_filename)
    lidar_to_2d_front_view(lidar, v_res=VRES, h_res=HRES, v_fov=VFOV, val=value, saveto=output_path, y_fudge=Y_FUDGE)
    
    processed_files = index + 1
    elapsed_time = time.time() - start_time
    estimated_time_remaining = elapsed_time / processed_files * (total_files - processed_files)
    print(f"Processed {processed_files} out of {total_files}. Estimated time remaining: {estimated_time_remaining:.2f} seconds.")
# Out:
# Processed 1 out of 5000. Estimated time remaining: 2920.63 seconds.
# Processed 2 out of 5000. Estimated time remaining: 2861.65 seconds.
# Processed 3 out of 5000. Estimated time remaining: 2864.80 seconds.
# Processed 4 out of 5000. Estimated time remaining: 2873.52 seconds.
# Processed 5 out of 5000. Estimated time remaining: 2896.52 seconds.
# Processed 6 out of 5000. Estimated time remaining: 2890.16 seconds.
# Processed 7 out of 5000. Estimated time remaining: 2895.35 seconds.
# Processed 8 out of 5000. Estimated time remaining: 2900.23 seconds.
# Processed 9 out of 5000. Estimated time remaining: 2889.60 seconds.
# Processed 10 out of 5000. Estimated time remaining: 2624.11 seconds.
# Processed 11 out of 5000. Estimated time remaining: 2589.02 seconds.
# Processed 12 out of 5000. Estimated time remaining: 2467.43 seconds.
# Processed 13 out of 5000. Estimated time remaining: 2365.24 seconds.
# Processed 14 out of 5000. Estimated time remaining: 2224.00 seconds.
# Processed 15 out of 5000. Estimated time remaining: 2269.59 seconds.
# Processed 16 out of 5000. Estimated time remaining: 2319.81 seconds.
# Processed 17 out of 5000. Estimated time remaining: 2343.59 seconds.
# Processed 18 out of 5000. Estimated time remaining: 2373.22 seconds.
# Processed 19 out of 5000. Estimated time remaining: 2404.53 seconds.
# Processed 20 out of 5000. Estimated time remaining: 2424.62 seconds.
# Processed 21 out of 5000. Estimated time remaining: 2447.29 seconds.
# Processed 22 out of 5000. Estimated time remaining: 2460.13 seconds.
# Processed 23 out of 5000. Estimated time remaining: 2481.05 seconds.
# Processed 24 out of 5000. Estimated time remaining: 2497.12 seconds.
# Processed 25 out of 5000. Estimated time remaining: 2513.32 seconds.
# Processed 26 out of 5000. Estimated time remaining: 2528.79 seconds.
# Processed 27 out of 5000. Estimated time remaining: 2544.75 seconds.
# Processed 28 out of 5000. Estimated time remaining: 2552.69 seconds.
# Processed 29 out of 5000. Estimated time remaining: 2555.67 seconds.
# Processed 30 out of 5000. Estimated time remaining: 2564.90 seconds.
# Processed 31 out of 5000. Estimated time remaining: 2567.78 seconds.
# Processed 32 out of 5000. Estimated time remaining: 2577.62 seconds.
# Processed 33 out of 5000. Estimated time remaining: 2587.97 seconds.
# Processed 34 out of 5000. Estimated time remaining: 2597.47 seconds.
# Processed 35 out of 5000. Estimated time remaining: 2608.85 seconds.
# Processed 36 out of 5000. Estimated time remaining: 2618.83 seconds.
# Processed 37 out of 5000. Estimated time remaining: 2624.12 seconds.
# Processed 38 out of 5000. Estimated time remaining: 2630.07 seconds.
# Processed 39 out of 5000. Estimated time remaining: 2633.89 seconds.
# Processed 40 out of 5000. Estimated time remaining: 2640.95 seconds.
# Processed 41 out of 5000. Estimated time remaining: 2644.85 seconds.
# Processed 42 out of 5000. Estimated time remaining: 2651.68 seconds.
# Processed 43 out of 5000. Estimated time remaining: 2658.20 seconds.
# Processed 44 out of 5000. Estimated time remaining: 2663.72 seconds.
# Processed 45 out of 5000. Estimated time remaining: 2668.01 seconds.
# Processed 46 out of 5000. Estimated time remaining: 2670.09 seconds.
# Processed 47 out of 5000. Estimated time remaining: 2668.89 seconds.
# Processed 48 out of 5000. Estimated time remaining: 2669.42 seconds.
# Processed 49 out of 5000. Estimated time remaining: 2672.74 seconds.
# Processed 50 out of 5000. Estimated time remaining: 2676.52 seconds.
# Processed 51 out of 5000. Estimated time remaining: 2679.99 seconds.
# Processed 52 out of 5000. Estimated time remaining: 2683.08 seconds.
# Processed 53 out of 5000. Estimated time remaining: 2686.55 seconds.
# Processed 54 out of 5000. Estimated time remaining: 2689.65 seconds.
# Processed 55 out of 5000. Estimated time remaining: 2693.73 seconds.
# Processed 56 out of 5000. Estimated time remaining: 2694.06 seconds.
# Processed 57 out of 5000. Estimated time remaining: 2695.71 seconds.
# Processed 58 out of 5000. Estimated time remaining: 2698.74 seconds.
# Processed 59 out of 5000. Estimated time remaining: 2700.18 seconds.
# Processed 60 out of 5000. Estimated time remaining: 2697.00 seconds.
# Processed 61 out of 5000. Estimated time remaining: 2696.34 seconds.
# Processed 62 out of 5000. Estimated time remaining: 2696.36 seconds.
# Processed 63 out of 5000. Estimated time remaining: 2695.10 seconds.
# Processed 64 out of 5000. Estimated time remaining: 2697.40 seconds.
# Processed 65 out of 5000. Estimated time remaining: 2699.84 seconds.
# Processed 66 out of 5000. Estimated time remaining: 2700.98 seconds.
# Processed 67 out of 5000. Estimated time remaining: 2702.66 seconds.
# Processed 68 out of 5000. Estimated time remaining: 2703.79 seconds.
# Processed 69 out of 5000. Estimated time remaining: 2705.36 seconds.
# Processed 70 out of 5000. Estimated time remaining: 2705.49 seconds.
# Processed 71 out of 5000. Estimated time remaining: 2707.03 seconds.
# Processed 72 out of 5000. Estimated time remaining: 2704.63 seconds.
# Processed 73 out of 5000. Estimated time remaining: 2703.72 seconds.
# Processed 74 out of 5000. Estimated time remaining: 2703.96 seconds.
# Processed 75 out of 5000. Estimated time remaining: 2705.25 seconds.
# Processed 76 out of 5000. Estimated time remaining: 2706.14 seconds.
# Processed 77 out of 5000. Estimated time remaining: 2708.14 seconds.
# Processed 78 out of 5000. Estimated time remaining: 2708.10 seconds.
# Processed 79 out of 5000. Estimated time remaining: 2707.74 seconds.
# Processed 80 out of 5000. Estimated time remaining: 2709.30 seconds.
# Processed 81 out of 5000. Estimated time remaining: 2706.69 seconds.
# Processed 82 out of 5000. Estimated time remaining: 2710.13 seconds.
# Processed 83 out of 5000. Estimated time remaining: 2712.53 seconds.
# Processed 84 out of 5000. Estimated time remaining: 2715.66 seconds.
# Processed 85 out of 5000. Estimated time remaining: 2718.46 seconds.
# Processed 86 out of 5000. Estimated time remaining: 2720.79 seconds.
# Processed 87 out of 5000. Estimated time remaining: 2722.72 seconds.
# Processed 88 out of 5000. Estimated time remaining: 2725.85 seconds.
# Processed 89 out of 5000. Estimated time remaining: 2727.72 seconds.
# Processed 90 out of 5000. Estimated time remaining: 2728.22 seconds.
# Processed 91 out of 5000. Estimated time remaining: 2729.67 seconds.
# Processed 92 out of 5000. Estimated time remaining: 2728.47 seconds.
# Processed 93 out of 5000. Estimated time remaining: 2728.49 seconds.
# Processed 94 out of 5000. Estimated time remaining: 2730.33 seconds.
# Processed 95 out of 5000. Estimated time remaining: 2730.91 seconds.
# Processed 96 out of 5000. Estimated time remaining: 2730.48 seconds.
# Processed 97 out of 5000. Estimated time remaining: 2728.19 seconds.
# Processed 98 out of 5000. Estimated time remaining: 2725.59 seconds.
# Processed 99 out of 5000. Estimated time remaining: 2726.02 seconds.
# Processed 100 out of 5000. Estimated time remaining: 2726.96 seconds.
# Processed 101 out of 5000. Estimated time remaining: 2726.33 seconds.
# Processed 102 out of 5000. Estimated time remaining: 2725.78 seconds.
# Processed 103 out of 5000. Estimated time remaining: 2725.58 seconds.
# Processed 104 out of 5000. Estimated time remaining: 2726.04 seconds.
# Processed 105 out of 5000. Estimated time remaining: 2728.67 seconds.
# Processed 106 out of 5000. Estimated time remaining: 2729.78 seconds.
# Processed 107 out of 5000. Estimated time remaining: 2730.17 seconds.
# Processed 108 out of 5000. Estimated time remaining: 2732.36 seconds.
# Processed 109 out of 5000. Estimated time remaining: 2732.85 seconds.
# Processed 110 out of 5000. Estimated time remaining: 2733.67 seconds.
# Processed 111 out of 5000. Estimated time remaining: 2734.01 seconds.
# Processed 112 out of 5000. Estimated time remaining: 2734.20 seconds.
# Processed 113 out of 5000. Estimated time remaining: 2734.73 seconds.
# Processed 114 out of 5000. Estimated time remaining: 2735.26 seconds.
# Processed 115 out of 5000. Estimated time remaining: 2734.70 seconds.
# Processed 116 out of 5000. Estimated time remaining: 2733.71 seconds.
# Processed 117 out of 5000. Estimated time remaining: 2732.10 seconds.
# Processed 118 out of 5000. Estimated time remaining: 2732.44 seconds.
# Processed 119 out of 5000. Estimated time remaining: 2733.00 seconds.
# Processed 120 out of 5000. Estimated time remaining: 2734.72 seconds.
# Processed 121 out of 5000. Estimated time remaining: 2736.76 seconds.
# Processed 122 out of 5000. Estimated time remaining: 2736.70 seconds.
# Processed 123 out of 5000. Estimated time remaining: 2738.36 seconds.
# Processed 124 out of 5000. Estimated time remaining: 2737.23 seconds.
# Processed 125 out of 5000. Estimated time remaining: 2739.24 seconds.
# Processed 126 out of 5000. Estimated time remaining: 2741.02 seconds.
# Processed 127 out of 5000. Estimated time remaining: 2742.33 seconds.
# Processed 128 out of 5000. Estimated time remaining: 2743.06 seconds.
# Processed 129 out of 5000. Estimated time remaining: 2744.99 seconds.
# Processed 130 out of 5000. Estimated time remaining: 2745.69 seconds.
# Processed 131 out of 5000. Estimated time remaining: 2747.03 seconds.
# Processed 132 out of 5000. Estimated time remaining: 2746.07 seconds.
# Processed 133 out of 5000. Estimated time remaining: 2746.34 seconds.
# Processed 134 out of 5000. Estimated time remaining: 2743.91 seconds.
# Processed 135 out of 5000. Estimated time remaining: 2743.62 seconds.
# Processed 136 out of 5000. Estimated time remaining: 2744.38 seconds.
# Processed 137 out of 5000. Estimated time remaining: 2745.00 seconds.
# Processed 138 out of 5000. Estimated time remaining: 2743.34 seconds.
# Processed 139 out of 5000. Estimated time remaining: 2743.23 seconds.
# Processed 140 out of 5000. Estimated time remaining: 2742.73 seconds.
# Processed 141 out of 5000. Estimated time remaining: 2743.05 seconds.
# Processed 142 out of 5000. Estimated time remaining: 2743.28 seconds.
# Processed 143 out of 5000. Estimated time remaining: 2743.30 seconds.
# Processed 144 out of 5000. Estimated time remaining: 2743.62 seconds.
# Processed 145 out of 5000. Estimated time remaining: 2742.54 seconds.
# Processed 146 out of 5000. Estimated time remaining: 2742.57 seconds.
# Processed 147 out of 5000. Estimated time remaining: 2742.79 seconds.
# Processed 148 out of 5000. Estimated time remaining: 2742.73 seconds.
# Processed 149 out of 5000. Estimated time remaining: 2741.79 seconds.
# Processed 150 out of 5000. Estimated time remaining: 2741.69 seconds.
# Processed 151 out of 5000. Estimated time remaining: 2741.88 seconds.
# Processed 152 out of 5000. Estimated time remaining: 2742.33 seconds.
# Processed 153 out of 5000. Estimated time remaining: 2742.10 seconds.
# Processed 154 out of 5000. Estimated time remaining: 2742.25 seconds.
# Processed 155 out of 5000. Estimated time remaining: 2742.66 seconds.
# Processed 156 out of 5000. Estimated time remaining: 2742.27 seconds.
# Processed 157 out of 5000. Estimated time remaining: 2742.35 seconds.
# Processed 158 out of 5000. Estimated time remaining: 2741.81 seconds.
# Processed 159 out of 5000. Estimated time remaining: 2742.31 seconds.
# Processed 160 out of 5000. Estimated time remaining: 2741.38 seconds.
# Processed 161 out of 5000. Estimated time remaining: 2740.61 seconds.
# Processed 162 out of 5000. Estimated time remaining: 2740.29 seconds.
# Processed 163 out of 5000. Estimated time remaining: 2740.35 seconds.
# Processed 164 out of 5000. Estimated time remaining: 2740.08 seconds.
# Processed 165 out of 5000. Estimated time remaining: 2739.23 seconds.
# Processed 166 out of 5000. Estimated time remaining: 2739.08 seconds.
# Processed 167 out of 5000. Estimated time remaining: 2738.73 seconds.
# Processed 168 out of 5000. Estimated time remaining: 2738.61 seconds.
# Processed 169 out of 5000. Estimated time remaining: 2738.27 seconds.
# Processed 170 out of 5000. Estimated time remaining: 2738.20 seconds.
# Processed 171 out of 5000. Estimated time remaining: 2737.78 seconds.
# Processed 172 out of 5000. Estimated time remaining: 2737.66 seconds.
# Processed 173 out of 5000. Estimated time remaining: 2737.53 seconds.
# Processed 174 out of 5000. Estimated time remaining: 2737.16 seconds.
# Processed 175 out of 5000. Estimated time remaining: 2736.77 seconds.
# Processed 176 out of 5000. Estimated time remaining: 2736.28 seconds.
# Processed 177 out of 5000. Estimated time remaining: 2735.91 seconds.
# Processed 178 out of 5000. Estimated time remaining: 2735.82 seconds.
# Processed 179 out of 5000. Estimated time remaining: 2735.44 seconds.
# Processed 180 out of 5000. Estimated time remaining: 2735.41 seconds.
# Processed 181 out of 5000. Estimated time remaining: 2735.19 seconds.
# Processed 182 out of 5000. Estimated time remaining: 2735.26 seconds.
# Processed 183 out of 5000. Estimated time remaining: 2735.44 seconds.
# Processed 184 out of 5000. Estimated time remaining: 2735.08 seconds.
# Processed 185 out of 5000. Estimated time remaining: 2733.45 seconds.
# Processed 186 out of 5000. Estimated time remaining: 2732.83 seconds.
# Processed 187 out of 5000. Estimated time remaining: 2732.63 seconds.
# Processed 188 out of 5000. Estimated time remaining: 2731.72 seconds.
# Processed 189 out of 5000. Estimated time remaining: 2731.81 seconds.
# Processed 190 out of 5000. Estimated time remaining: 2732.28 seconds.
# Processed 191 out of 5000. Estimated time remaining: 2731.81 seconds.
# Processed 192 out of 5000. Estimated time remaining: 2731.76 seconds.
# Processed 193 out of 5000. Estimated time remaining: 2731.52 seconds.
# Processed 194 out of 5000. Estimated time remaining: 2732.43 seconds.
# Processed 195 out of 5000. Estimated time remaining: 2731.99 seconds.
# Processed 196 out of 5000. Estimated time remaining: 2730.96 seconds.
# Processed 197 out of 5000. Estimated time remaining: 2730.63 seconds.
# Processed 198 out of 5000. Estimated time remaining: 2730.55 seconds.
# Processed 199 out of 5000. Estimated time remaining: 2730.40 seconds.
# Processed 200 out of 5000. Estimated time remaining: 2730.33 seconds.
# Processed 201 out of 5000. Estimated time remaining: 2729.76 seconds.
# Processed 202 out of 5000. Estimated time remaining: 2729.63 seconds.
# Processed 203 out of 5000. Estimated time remaining: 2729.87 seconds.
# Processed 204 out of 5000. Estimated time remaining: 2729.41 seconds.
# Processed 205 out of 5000. Estimated time remaining: 2729.37 seconds.
# Processed 206 out of 5000. Estimated time remaining: 2729.34 seconds.
# Processed 207 out of 5000. Estimated time remaining: 2728.99 seconds.
# Processed 208 out of 5000. Estimated time remaining: 2728.78 seconds.
# Processed 209 out of 5000. Estimated time remaining: 2728.68 seconds.
# Processed 210 out of 5000. Estimated time remaining: 2728.61 seconds.
# Processed 211 out of 5000. Estimated time remaining: 2729.12 seconds.
# Processed 212 out of 5000. Estimated time remaining: 2729.66 seconds.
# Processed 213 out of 5000. Estimated time remaining: 2730.07 seconds.
# Processed 214 out of 5000. Estimated time remaining: 2730.71 seconds.
# Processed 215 out of 5000. Estimated time remaining: 2731.23 seconds.
# Processed 216 out of 5000. Estimated time remaining: 2731.53 seconds.
# Processed 217 out of 5000. Estimated time remaining: 2731.31 seconds.
# Processed 218 out of 5000. Estimated time remaining: 2732.39 seconds.
# Processed 219 out of 5000. Estimated time remaining: 2733.12 seconds.
# Processed 220 out of 5000. Estimated time remaining: 2733.60 seconds.
# Processed 221 out of 5000. Estimated time remaining: 2733.75 seconds.
# Processed 222 out of 5000. Estimated time remaining: 2733.46 seconds.
# Processed 223 out of 5000. Estimated time remaining: 2734.14 seconds.
# Processed 224 out of 5000. Estimated time remaining: 2734.77 seconds.
# Processed 225 out of 5000. Estimated time remaining: 2735.27 seconds.
# Processed 226 out of 5000. Estimated time remaining: 2735.39 seconds.
# Processed 227 out of 5000. Estimated time remaining: 2735.28 seconds.
# Processed 228 out of 5000. Estimated time remaining: 2734.40 seconds.
# Processed 229 out of 5000. Estimated time remaining: 2734.11 seconds.
# Processed 230 out of 5000. Estimated time remaining: 2733.82 seconds.
# Processed 231 out of 5000. Estimated time remaining: 2733.10 seconds.
# Processed 232 out of 5000. Estimated time remaining: 2732.47 seconds.
# Processed 233 out of 5000. Estimated time remaining: 2731.51 seconds.
# Processed 234 out of 5000. Estimated time remaining: 2730.82 seconds.
# Processed 235 out of 5000. Estimated time remaining: 2730.27 seconds.
# Processed 236 out of 5000. Estimated time remaining: 2728.65 seconds.
# Processed 237 out of 5000. Estimated time remaining: 2727.67 seconds.
# Processed 238 out of 5000. Estimated time remaining: 2727.04 seconds.
# Processed 239 out of 5000. Estimated time remaining: 2726.46 seconds.
# Processed 240 out of 5000. Estimated time remaining: 2726.20 seconds.
# Processed 241 out of 5000. Estimated time remaining: 2725.67 seconds.
# Processed 242 out of 5000. Estimated time remaining: 2725.24 seconds.
# Processed 243 out of 5000. Estimated time remaining: 2724.44 seconds.
# Processed 244 out of 5000. Estimated time remaining: 2723.60 seconds.
# Processed 245 out of 5000. Estimated time remaining: 2723.15 seconds.
# Processed 246 out of 5000. Estimated time remaining: 2721.76 seconds.
# Processed 247 out of 5000. Estimated time remaining: 2721.03 seconds.
# Processed 248 out of 5000. Estimated time remaining: 2720.45 seconds.
# Processed 249 out of 5000. Estimated time remaining: 2718.60 seconds.
# Processed 250 out of 5000. Estimated time remaining: 2717.91 seconds.
# Processed 251 out of 5000. Estimated time remaining: 2717.47 seconds.
# Processed 252 out of 5000. Estimated time remaining: 2716.30 seconds.
# Processed 253 out of 5000. Estimated time remaining: 2715.74 seconds.
# Processed 254 out of 5000. Estimated time remaining: 2715.17 seconds.
# Processed 255 out of 5000. Estimated time remaining: 2714.51 seconds.
# Processed 256 out of 5000. Estimated time remaining: 2713.82 seconds.
# Processed 257 out of 5000. Estimated time remaining: 2713.36 seconds.
# Processed 258 out of 5000. Estimated time remaining: 2711.49 seconds.
# Processed 259 out of 5000. Estimated time remaining: 2710.60 seconds.
# Processed 260 out of 5000. Estimated time remaining: 2710.03 seconds.
# Processed 261 out of 5000. Estimated time remaining: 2709.51 seconds.
# Processed 262 out of 5000. Estimated time remaining: 2709.04 seconds.
# Processed 263 out of 5000. Estimated time remaining: 2708.96 seconds.
# Processed 264 out of 5000. Estimated time remaining: 2708.59 seconds.
# Processed 265 out of 5000. Estimated time remaining: 2708.23 seconds.
# Processed 266 out of 5000. Estimated time remaining: 2707.90 seconds.
# Processed 267 out of 5000. Estimated time remaining: 2707.40 seconds.
# Processed 268 out of 5000. Estimated time remaining: 2707.13 seconds.
# Processed 269 out of 5000. Estimated time remaining: 2706.52 seconds.
# Processed 270 out of 5000. Estimated time remaining: 2705.97 seconds.
# Processed 271 out of 5000. Estimated time remaining: 2705.60 seconds.
# Processed 272 out of 5000. Estimated time remaining: 2704.90 seconds.
# Processed 273 out of 5000. Estimated time remaining: 2704.27 seconds.
# Processed 274 out of 5000. Estimated time remaining: 2703.87 seconds.
# Processed 275 out of 5000. Estimated time remaining: 2703.39 seconds.
# Processed 276 out of 5000. Estimated time remaining: 2702.85 seconds.
# Processed 277 out of 5000. Estimated time remaining: 2702.26 seconds.
# Processed 278 out of 5000. Estimated time remaining: 2701.76 seconds.
# Processed 279 out of 5000. Estimated time remaining: 2701.31 seconds.
# Processed 280 out of 5000. Estimated time remaining: 2700.82 seconds.
# Processed 281 out of 5000. Estimated time remaining: 2700.09 seconds.
# Processed 282 out of 5000. Estimated time remaining: 2699.71 seconds.
# Processed 283 out of 5000. Estimated time remaining: 2698.83 seconds.
# Processed 284 out of 5000. Estimated time remaining: 2698.31 seconds.
# Processed 285 out of 5000. Estimated time remaining: 2697.86 seconds.
# Processed 286 out of 5000. Estimated time remaining: 2697.22 seconds.
# Processed 287 out of 5000. Estimated time remaining: 2696.55 seconds.
# Processed 288 out of 5000. Estimated time remaining: 2695.99 seconds.
# Processed 289 out of 5000. Estimated time remaining: 2695.56 seconds.
# Processed 290 out of 5000. Estimated time remaining: 2694.96 seconds.
# Processed 291 out of 5000. Estimated time remaining: 2694.30 seconds.
# Processed 292 out of 5000. Estimated time remaining: 2693.66 seconds.
# Processed 293 out of 5000. Estimated time remaining: 2692.88 seconds.
# Processed 294 out of 5000. Estimated time remaining: 2692.43 seconds.
# Processed 295 out of 5000. Estimated time remaining: 2692.05 seconds.
# Processed 296 out of 5000. Estimated time remaining: 2691.47 seconds.
# Processed 297 out of 5000. Estimated time remaining: 2690.89 seconds.
# Processed 298 out of 5000. Estimated time remaining: 2690.08 seconds.
# Processed 299 out of 5000. Estimated time remaining: 2690.32 seconds.
# Processed 300 out of 5000. Estimated time remaining: 2690.13 seconds.
# Processed 301 out of 5000. Estimated time remaining: 2690.41 seconds.
# Processed 302 out of 5000. Estimated time remaining: 2690.23 seconds.
# Processed 303 out of 5000. Estimated time remaining: 2689.82 seconds.
# Processed 304 out of 5000. Estimated time remaining: 2689.82 seconds.
# Processed 305 out of 5000. Estimated time remaining: 2689.93 seconds.
# Processed 306 out of 5000. Estimated time remaining: 2690.15 seconds.
# Processed 307 out of 5000. Estimated time remaining: 2690.37 seconds.
# Processed 308 out of 5000. Estimated time remaining: 2689.91 seconds.
# Processed 309 out of 5000. Estimated time remaining: 2689.86 seconds.
# Processed 310 out of 5000. Estimated time remaining: 2689.89 seconds.
# Processed 311 out of 5000. Estimated time remaining: 2689.50 seconds.
# Processed 312 out of 5000. Estimated time remaining: 2689.65 seconds.
# Processed 313 out of 5000. Estimated time remaining: 2688.98 seconds.
# Processed 314 out of 5000. Estimated time remaining: 2689.23 seconds.
# Processed 315 out of 5000. Estimated time remaining: 2689.07 seconds.
# Processed 316 out of 5000. Estimated time remaining: 2688.88 seconds.
# Processed 317 out of 5000. Estimated time remaining: 2688.88 seconds.
# Processed 318 out of 5000. Estimated time remaining: 2688.98 seconds.
# Processed 319 out of 5000. Estimated time remaining: 2689.02 seconds.
# Processed 320 out of 5000. Estimated time remaining: 2688.92 seconds.
# Processed 321 out of 5000. Estimated time remaining: 2690.67 seconds.
# Processed 322 out of 5000. Estimated time remaining: 2691.31 seconds.
# Processed 323 out of 5000. Estimated time remaining: 2692.84 seconds.
# Processed 324 out of 5000. Estimated time remaining: 2692.98 seconds.
# Processed 325 out of 5000. Estimated time remaining: 2694.06 seconds.
# Processed 326 out of 5000. Estimated time remaining: 2695.08 seconds.
# Processed 327 out of 5000. Estimated time remaining: 2695.67 seconds.
# Processed 328 out of 5000. Estimated time remaining: 2695.77 seconds.
# Processed 329 out of 5000. Estimated time remaining: 2696.39 seconds.
# Processed 330 out of 5000. Estimated time remaining: 2696.83 seconds.
# Processed 331 out of 5000. Estimated time remaining: 2696.53 seconds.
# Processed 332 out of 5000. Estimated time remaining: 2696.39 seconds.
# Processed 333 out of 5000. Estimated time remaining: 2696.01 seconds.
# Processed 334 out of 5000. Estimated time remaining: 2696.50 seconds.
# Processed 335 out of 5000. Estimated time remaining: 2696.55 seconds.
# Processed 336 out of 5000. Estimated time remaining: 2696.59 seconds.
# Processed 337 out of 5000. Estimated time remaining: 2696.03 seconds.
# Processed 338 out of 5000. Estimated time remaining: 2695.75 seconds.
# Processed 339 out of 5000. Estimated time remaining: 2695.68 seconds.
# Processed 340 out of 5000. Estimated time remaining: 2695.33 seconds.
# Processed 341 out of 5000. Estimated time remaining: 2694.66 seconds.
# Processed 342 out of 5000. Estimated time remaining: 2694.32 seconds.
# Processed 343 out of 5000. Estimated time remaining: 2693.85 seconds.
# Processed 344 out of 5000. Estimated time remaining: 2692.77 seconds.
# Processed 345 out of 5000. Estimated time remaining: 2692.50 seconds.
# Processed 346 out of 5000. Estimated time remaining: 2692.12 seconds.
# Processed 347 out of 5000. Estimated time remaining: 2691.72 seconds.
# Processed 348 out of 5000. Estimated time remaining: 2691.14 seconds.
# Processed 349 out of 5000. Estimated time remaining: 2690.09 seconds.
# Processed 350 out of 5000. Estimated time remaining: 2689.61 seconds.
# Processed 351 out of 5000. Estimated time remaining: 2688.94 seconds.
# Processed 352 out of 5000. Estimated time remaining: 2688.65 seconds.
# Processed 353 out of 5000. Estimated time remaining: 2688.11 seconds.
# Processed 354 out of 5000. Estimated time remaining: 2687.11 seconds.
# Processed 355 out of 5000. Estimated time remaining: 2686.69 seconds.
# Processed 356 out of 5000. Estimated time remaining: 2685.92 seconds.
# Processed 357 out of 5000. Estimated time remaining: 2685.21 seconds.
# Processed 358 out of 5000. Estimated time remaining: 2684.97 seconds.
# Processed 359 out of 5000. Estimated time remaining: 2684.53 seconds.
# Processed 360 out of 5000. Estimated time remaining: 2683.81 seconds.
# Processed 361 out of 5000. Estimated time remaining: 2683.32 seconds.
# Processed 362 out of 5000. Estimated time remaining: 2682.41 seconds.
# Processed 363 out of 5000. Estimated time remaining: 2681.54 seconds.
# Processed 364 out of 5000. Estimated time remaining: 2680.95 seconds.
# Processed 365 out of 5000. Estimated time remaining: 2680.57 seconds.
# Processed 366 out of 5000. Estimated time remaining: 2679.91 seconds.
# Processed 367 out of 5000. Estimated time remaining: 2679.27 seconds.
# Processed 368 out of 5000. Estimated time remaining: 2677.92 seconds.
# Processed 369 out of 5000. Estimated time remaining: 2677.25 seconds.
# Processed 370 out of 5000. Estimated time remaining: 2676.35 seconds.
# Processed 371 out of 5000. Estimated time remaining: 2675.83 seconds.
# Processed 372 out of 5000. Estimated time remaining: 2674.94 seconds.
# Processed 373 out of 5000. Estimated time remaining: 2674.32 seconds.
# Processed 374 out of 5000. Estimated time remaining: 2673.91 seconds.
# Processed 375 out of 5000. Estimated time remaining: 2673.37 seconds.
# Processed 376 out of 5000. Estimated time remaining: 2672.63 seconds.
# Processed 377 out of 5000. Estimated time remaining: 2671.43 seconds.
# Processed 378 out of 5000. Estimated time remaining: 2670.96 seconds.
# Processed 379 out of 5000. Estimated time remaining: 2670.71 seconds.
# Processed 380 out of 5000. Estimated time remaining: 2670.12 seconds.
# Processed 381 out of 5000. Estimated time remaining: 2669.95 seconds.
# Processed 382 out of 5000. Estimated time remaining: 2669.43 seconds.
# Processed 383 out of 5000. Estimated time remaining: 2669.15 seconds.
# Processed 384 out of 5000. Estimated time remaining: 2668.45 seconds.
# Processed 385 out of 5000. Estimated time remaining: 2667.69 seconds.
# Processed 386 out of 5000. Estimated time remaining: 2667.03 seconds.
# Processed 387 out of 5000. Estimated time remaining: 2666.57 seconds.
# Processed 388 out of 5000. Estimated time remaining: 2665.82 seconds.
# Processed 389 out of 5000. Estimated time remaining: 2665.35 seconds.
# Processed 390 out of 5000. Estimated time remaining: 2664.62 seconds.
# Processed 391 out of 5000. Estimated time remaining: 2664.06 seconds.
# Processed 392 out of 5000. Estimated time remaining: 2663.55 seconds.
# Processed 393 out of 5000. Estimated time remaining: 2663.05 seconds.
# Processed 394 out of 5000. Estimated time remaining: 2662.62 seconds.
# Processed 395 out of 5000. Estimated time remaining: 2661.69 seconds.
# Processed 396 out of 5000. Estimated time remaining: 2661.30 seconds.
# Processed 397 out of 5000. Estimated time remaining: 2660.75 seconds.
# Processed 398 out of 5000. Estimated time remaining: 2660.18 seconds.
# Processed 399 out of 5000. Estimated time remaining: 2659.35 seconds.
# Processed 400 out of 5000. Estimated time remaining: 2658.76 seconds.
# Processed 401 out of 5000. Estimated time remaining: 2658.26 seconds.
# Processed 402 out of 5000. Estimated time remaining: 2657.52 seconds.
# Processed 403 out of 5000. Estimated time remaining: 2657.30 seconds.
# Processed 404 out of 5000. Estimated time remaining: 2656.78 seconds.
# Processed 405 out of 5000. Estimated time remaining: 2656.35 seconds.
# Processed 406 out of 5000. Estimated time remaining: 2655.76 seconds.
# Processed 407 out of 5000. Estimated time remaining: 2655.08 seconds.
# Processed 408 out of 5000. Estimated time remaining: 2654.05 seconds.
# Processed 409 out of 5000. Estimated time remaining: 2653.41 seconds.
# Processed 410 out of 5000. Estimated time remaining: 2652.80 seconds.
# Processed 411 out of 5000. Estimated time remaining: 2651.54 seconds.
# Processed 412 out of 5000. Estimated time remaining: 2650.99 seconds.
# Processed 413 out of 5000. Estimated time remaining: 2650.49 seconds.
# Processed 414 out of 5000. Estimated time remaining: 2649.64 seconds.
# Processed 415 out of 5000. Estimated time remaining: 2649.09 seconds.
# Processed 416 out of 5000. Estimated time remaining: 2648.26 seconds.
# Processed 417 out of 5000. Estimated time remaining: 2647.40 seconds.
# Processed 418 out of 5000. Estimated time remaining: 2646.59 seconds.
# Processed 419 out of 5000. Estimated time remaining: 2646.08 seconds.
# Processed 420 out of 5000. Estimated time remaining: 2645.55 seconds.
# Processed 421 out of 5000. Estimated time remaining: 2644.86 seconds.
# Processed 422 out of 5000. Estimated time remaining: 2643.66 seconds.
# Processed 423 out of 5000. Estimated time remaining: 2642.81 seconds.
# Processed 424 out of 5000. Estimated time remaining: 2642.24 seconds.
# Processed 425 out of 5000. Estimated time remaining: 2641.72 seconds.
# Processed 426 out of 5000. Estimated time remaining: 2640.98 seconds.
# Processed 427 out of 5000. Estimated time remaining: 2640.25 seconds.
# Processed 428 out of 5000. Estimated time remaining: 2639.54 seconds.
# Processed 429 out of 5000. Estimated time remaining: 2638.93 seconds.
# Processed 430 out of 5000. Estimated time remaining: 2638.57 seconds.
# Processed 431 out of 5000. Estimated time remaining: 2638.11 seconds.
# Processed 432 out of 5000. Estimated time remaining: 2637.33 seconds.
# Processed 433 out of 5000. Estimated time remaining: 2636.83 seconds.
# Processed 434 out of 5000. Estimated time remaining: 2636.22 seconds.
# Processed 435 out of 5000. Estimated time remaining: 2635.72 seconds.
# Processed 436 out of 5000. Estimated time remaining: 2635.02 seconds.
# Processed 437 out of 5000. Estimated time remaining: 2634.15 seconds.
# Processed 438 out of 5000. Estimated time remaining: 2633.47 seconds.
# Processed 439 out of 5000. Estimated time remaining: 2632.98 seconds.
# Processed 440 out of 5000. Estimated time remaining: 2632.39 seconds.
# Processed 441 out of 5000. Estimated time remaining: 2631.57 seconds.
# Processed 442 out of 5000. Estimated time remaining: 2631.21 seconds.
# Processed 443 out of 5000. Estimated time remaining: 2630.64 seconds.
# Processed 444 out of 5000. Estimated time remaining: 2630.12 seconds.
# Processed 445 out of 5000. Estimated time remaining: 2629.72 seconds.
# Processed 446 out of 5000. Estimated time remaining: 2628.88 seconds.
# Processed 447 out of 5000. Estimated time remaining: 2627.64 seconds.
# Processed 448 out of 5000. Estimated time remaining: 2627.06 seconds.
# Processed 449 out of 5000. Estimated time remaining: 2626.39 seconds.
# Processed 450 out of 5000. Estimated time remaining: 2625.74 seconds.
# Processed 451 out of 5000. Estimated time remaining: 2625.07 seconds.
# Processed 452 out of 5000. Estimated time remaining: 2624.34 seconds.
# Processed 453 out of 5000. Estimated time remaining: 2623.81 seconds.
# Processed 454 out of 5000. Estimated time remaining: 2623.23 seconds.
# Processed 455 out of 5000. Estimated time remaining: 2622.14 seconds.
# Processed 456 out of 5000. Estimated time remaining: 2621.69 seconds.
# Processed 457 out of 5000. Estimated time remaining: 2621.26 seconds.
# Processed 458 out of 5000. Estimated time remaining: 2620.57 seconds.
# Processed 459 out of 5000. Estimated time remaining: 2620.19 seconds.
# Processed 460 out of 5000. Estimated time remaining: 2619.70 seconds.
# Processed 461 out of 5000. Estimated time remaining: 2619.35 seconds.
# Processed 462 out of 5000. Estimated time remaining: 2618.66 seconds.
# Processed 463 out of 5000. Estimated time remaining: 2618.04 seconds.
# Processed 464 out of 5000. Estimated time remaining: 2617.57 seconds.
# Processed 465 out of 5000. Estimated time remaining: 2616.87 seconds.
# Processed 466 out of 5000. Estimated time remaining: 2616.39 seconds.
# Processed 467 out of 5000. Estimated time remaining: 2616.01 seconds.
# Processed 468 out of 5000. Estimated time remaining: 2615.39 seconds.
# Processed 469 out of 5000. Estimated time remaining: 2614.98 seconds.
# Processed 470 out of 5000. Estimated time remaining: 2614.31 seconds.
# Processed 471 out of 5000. Estimated time remaining: 2613.67 seconds.
# Processed 472 out of 5000. Estimated time remaining: 2613.14 seconds.
# Processed 473 out of 5000. Estimated time remaining: 2612.60 seconds.
# Processed 474 out of 5000. Estimated time remaining: 2611.81 seconds.
# Processed 475 out of 5000. Estimated time remaining: 2611.24 seconds.
# Processed 476 out of 5000. Estimated time remaining: 2610.83 seconds.
# Processed 477 out of 5000. Estimated time remaining: 2610.18 seconds.
# Processed 478 out of 5000. Estimated time remaining: 2609.43 seconds.
# Processed 479 out of 5000. Estimated time remaining: 2609.01 seconds.
# Processed 480 out of 5000. Estimated time remaining: 2608.44 seconds.
# Processed 481 out of 5000. Estimated time remaining: 2607.92 seconds.
# Processed 482 out of 5000. Estimated time remaining: 2607.40 seconds.
# Processed 483 out of 5000. Estimated time remaining: 2607.19 seconds.
# Processed 484 out of 5000. Estimated time remaining: 2606.49 seconds.
# Processed 485 out of 5000. Estimated time remaining: 2605.83 seconds.
# Processed 486 out of 5000. Estimated time remaining: 2605.13 seconds.
# Processed 487 out of 5000. Estimated time remaining: 2604.65 seconds.
# Processed 488 out of 5000. Estimated time remaining: 2604.18 seconds.
# Processed 489 out of 5000. Estimated time remaining: 2603.68 seconds.
# Processed 490 out of 5000. Estimated time remaining: 2603.23 seconds.
# Processed 491 out of 5000. Estimated time remaining: 2602.70 seconds.
# Processed 492 out of 5000. Estimated time remaining: 2602.19 seconds.
# Processed 493 out of 5000. Estimated time remaining: 2601.72 seconds.
# Processed 494 out of 5000. Estimated time remaining: 2601.14 seconds.
# Processed 495 out of 5000. Estimated time remaining: 2600.54 seconds.
# Processed 496 out of 5000. Estimated time remaining: 2600.03 seconds.
# Processed 497 out of 5000. Estimated time remaining: 2599.67 seconds.
# Processed 498 out of 5000. Estimated time remaining: 2599.08 seconds.
# Processed 499 out of 5000. Estimated time remaining: 2598.38 seconds.
# Processed 500 out of 5000. Estimated time remaining: 2597.75 seconds.
# Processed 501 out of 5000. Estimated time remaining: 2597.16 seconds.
# Processed 502 out of 5000. Estimated time remaining: 2596.63 seconds.
# Processed 503 out of 5000. Estimated time remaining: 2596.15 seconds.
# Processed 504 out of 5000. Estimated time remaining: 2595.48 seconds.
# Processed 505 out of 5000. Estimated time remaining: 2594.93 seconds.
# Processed 506 out of 5000. Estimated time remaining: 2594.37 seconds.
# Processed 507 out of 5000. Estimated time remaining: 2594.02 seconds.
# Processed 508 out of 5000. Estimated time remaining: 2593.27 seconds.
# Processed 509 out of 5000. Estimated time remaining: 2592.83 seconds.
# Processed 510 out of 5000. Estimated time remaining: 2592.14 seconds.
# Processed 511 out of 5000. Estimated time remaining: 2591.82 seconds.
# Processed 512 out of 5000. Estimated time remaining: 2591.14 seconds.
# Processed 513 out of 5000. Estimated time remaining: 2590.68 seconds.
# Processed 514 out of 5000. Estimated time remaining: 2590.16 seconds.
# Processed 515 out of 5000. Estimated time remaining: 2589.66 seconds.
# Processed 516 out of 5000. Estimated time remaining: 2591.37 seconds.
# Processed 517 out of 5000. Estimated time remaining: 2595.09 seconds.
# Processed 518 out of 5000. Estimated time remaining: 2597.64 seconds.
# Processed 519 out of 5000. Estimated time remaining: 2603.94 seconds.
# Processed 520 out of 5000. Estimated time remaining: 2610.00 seconds.
# Processed 521 out of 5000. Estimated time remaining: 2612.07 seconds.
# Processed 522 out of 5000. Estimated time remaining: 2616.27 seconds.
# Processed 523 out of 5000. Estimated time remaining: 2621.46 seconds.
# Processed 524 out of 5000. Estimated time remaining: 2626.83 seconds.
# Processed 525 out of 5000. Estimated time remaining: 2631.93 seconds.
# Processed 526 out of 5000. Estimated time remaining: 2637.36 seconds.
# Processed 527 out of 5000. Estimated time remaining: 2640.94 seconds.
# Processed 528 out of 5000. Estimated time remaining: 2647.73 seconds.
# Processed 529 out of 5000. Estimated time remaining: 2652.96 seconds.
# Processed 530 out of 5000. Estimated time remaining: 2656.40 seconds.
# Processed 531 out of 5000. Estimated time remaining: 2661.09 seconds.
# Processed 532 out of 5000. Estimated time remaining: 2668.07 seconds.
# Processed 533 out of 5000. Estimated time remaining: 2672.35 seconds.
# Processed 534 out of 5000. Estimated time remaining: 2674.20 seconds.
# Processed 535 out of 5000. Estimated time remaining: 2679.71 seconds.
# Processed 536 out of 5000. Estimated time remaining: 2680.82 seconds.
# Processed 537 out of 5000. Estimated time remaining: 2683.82 seconds.
# Processed 538 out of 5000. Estimated time remaining: 2688.71 seconds.
# Processed 539 out of 5000. Estimated time remaining: 2694.20 seconds.
# Processed 540 out of 5000. Estimated time remaining: 2695.11 seconds.
# Processed 541 out of 5000. Estimated time remaining: 2698.26 seconds.
# Processed 542 out of 5000. Estimated time remaining: 2702.36 seconds.
# Processed 543 out of 5000. Estimated time remaining: 2704.04 seconds.
# Processed 544 out of 5000. Estimated time remaining: 2705.74 seconds.
# Processed 545 out of 5000. Estimated time remaining: 2710.92 seconds.
# Processed 546 out of 5000. Estimated time remaining: 2713.88 seconds.
# Processed 547 out of 5000. Estimated time remaining: 2717.04 seconds.
# Processed 548 out of 5000. Estimated time remaining: 2720.90 seconds.
# Processed 549 out of 5000. Estimated time remaining: 2723.49 seconds.
# Processed 550 out of 5000. Estimated time remaining: 2726.92 seconds.
# Processed 551 out of 5000. Estimated time remaining: 2729.63 seconds.
# Processed 552 out of 5000. Estimated time remaining: 2732.91 seconds.
# Processed 553 out of 5000. Estimated time remaining: 2735.30 seconds.
# Processed 554 out of 5000. Estimated time remaining: 2740.26 seconds.
# Processed 555 out of 5000. Estimated time remaining: 2745.57 seconds.
# Processed 556 out of 5000. Estimated time remaining: 2751.35 seconds.
# Processed 557 out of 5000. Estimated time remaining: 2752.11 seconds.
# Processed 558 out of 5000. Estimated time remaining: 2757.87 seconds.
# Processed 559 out of 5000. Estimated time remaining: 2760.48 seconds.
# Processed 560 out of 5000. Estimated time remaining: 2766.58 seconds.
# Processed 561 out of 5000. Estimated time remaining: 2772.38 seconds.
# Processed 562 out of 5000. Estimated time remaining: 2774.13 seconds.
# Processed 563 out of 5000. Estimated time remaining: 2778.33 seconds.
# Processed 564 out of 5000. Estimated time remaining: 2780.09 seconds.
# Processed 565 out of 5000. Estimated time remaining: 2784.85 seconds.
# Processed 566 out of 5000. Estimated time remaining: 2787.87 seconds.
# Processed 567 out of 5000. Estimated time remaining: 2791.72 seconds.
# Processed 568 out of 5000. Estimated time remaining: 2794.38 seconds.
# Processed 569 out of 5000. Estimated time remaining: 2798.99 seconds.
# Processed 570 out of 5000. Estimated time remaining: 2803.08 seconds.
# Processed 571 out of 5000. Estimated time remaining: 2805.83 seconds.
# Processed 572 out of 5000. Estimated time remaining: 2810.36 seconds.
# Processed 573 out of 5000. Estimated time remaining: 2815.28 seconds.
# Processed 574 out of 5000. Estimated time remaining: 2819.33 seconds.
# Processed 575 out of 5000. Estimated time remaining: 2822.85 seconds.
# Processed 576 out of 5000. Estimated time remaining: 2828.39 seconds.
# Processed 577 out of 5000. Estimated time remaining: 2833.38 seconds.
# Processed 578 out of 5000. Estimated time remaining: 2837.84 seconds.
# Processed 579 out of 5000. Estimated time remaining: 2839.49 seconds.
# Processed 580 out of 5000. Estimated time remaining: 2845.10 seconds.
# Processed 581 out of 5000. Estimated time remaining: 2848.31 seconds.
# Processed 582 out of 5000. Estimated time remaining: 2850.60 seconds.
# Processed 583 out of 5000. Estimated time remaining: 2852.72 seconds.
# Processed 584 out of 5000. Estimated time remaining: 2855.05 seconds.
# Processed 585 out of 5000. Estimated time remaining: 2859.24 seconds.
# Processed 586 out of 5000. Estimated time remaining: 2862.80 seconds.
# Processed 587 out of 5000. Estimated time remaining: 2863.95 seconds.
# Processed 588 out of 5000. Estimated time remaining: 2866.34 seconds.
# Processed 589 out of 5000. Estimated time remaining: 2869.89 seconds.
# Processed 590 out of 5000. Estimated time remaining: 2870.69 seconds.
# Processed 591 out of 5000. Estimated time remaining: 2874.19 seconds.
# Processed 592 out of 5000. Estimated time remaining: 2874.95 seconds.
# Processed 593 out of 5000. Estimated time remaining: 2877.18 seconds.
# Processed 594 out of 5000. Estimated time remaining: 2879.76 seconds.
# Processed 595 out of 5000. Estimated time remaining: 2882.67 seconds.
# Processed 596 out of 5000. Estimated time remaining: 2887.12 seconds.
# Processed 597 out of 5000. Estimated time remaining: 2888.27 seconds.
# Processed 598 out of 5000. Estimated time remaining: 2890.40 seconds.
# Processed 599 out of 5000. Estimated time remaining: 2891.95 seconds.
# Processed 600 out of 5000. Estimated time remaining: 2894.77 seconds.
# Processed 601 out of 5000. Estimated time remaining: 2897.26 seconds.
# Processed 602 out of 5000. Estimated time remaining: 2898.69 seconds.
# Processed 603 out of 5000. Estimated time remaining: 2902.45 seconds.
# Processed 604 out of 5000. Estimated time remaining: 2904.06 seconds.
# Processed 605 out of 5000. Estimated time remaining: 2907.00 seconds.
# Processed 606 out of 5000. Estimated time remaining: 2906.50 seconds.
# Processed 607 out of 5000. Estimated time remaining: 2909.69 seconds.
# Processed 608 out of 5000. Estimated time remaining: 2914.63 seconds.
# Processed 609 out of 5000. Estimated time remaining: 2917.97 seconds.
# Processed 610 out of 5000. Estimated time remaining: 2920.89 seconds.
# Processed 611 out of 5000. Estimated time remaining: 2923.10 seconds.
# Processed 612 out of 5000. Estimated time remaining: 2925.47 seconds.
# Processed 613 out of 5000. Estimated time remaining: 2927.50 seconds.
# Processed 614 out of 5000. Estimated time remaining: 2930.05 seconds.
# Processed 615 out of 5000. Estimated time remaining: 2931.21 seconds.
# Processed 616 out of 5000. Estimated time remaining: 2931.59 seconds.
# Processed 617 out of 5000. Estimated time remaining: 2933.35 seconds.
# Processed 618 out of 5000. Estimated time remaining: 2933.29 seconds.
# Processed 619 out of 5000. Estimated time remaining: 2933.80 seconds.
# Processed 620 out of 5000. Estimated time remaining: 2933.48 seconds.
# Processed 621 out of 5000. Estimated time remaining: 2934.05 seconds.
# Processed 622 out of 5000. Estimated time remaining: 2936.66 seconds.
# Processed 623 out of 5000. Estimated time remaining: 2938.01 seconds.
# Processed 624 out of 5000. Estimated time remaining: 2938.90 seconds.
# Processed 625 out of 5000. Estimated time remaining: 2940.95 seconds.
# Processed 626 out of 5000. Estimated time remaining: 2942.16 seconds.
# Processed 627 out of 5000. Estimated time remaining: 2944.42 seconds.
# Processed 628 out of 5000. Estimated time remaining: 2947.90 seconds.
# Processed 629 out of 5000. Estimated time remaining: 2951.02 seconds.
# Processed 630 out of 5000. Estimated time remaining: 2954.06 seconds.
# Processed 631 out of 5000. Estimated time remaining: 2956.65 seconds.
# Processed 632 out of 5000. Estimated time remaining: 2962.48 seconds.
# Processed 633 out of 5000. Estimated time remaining: 2965.58 seconds.
# Processed 634 out of 5000. Estimated time remaining: 2968.09 seconds.
# Processed 635 out of 5000. Estimated time remaining: 2970.99 seconds.
# Processed 636 out of 5000. Estimated time remaining: 2974.29 seconds.
# Processed 637 out of 5000. Estimated time remaining: 2976.96 seconds.
# Processed 638 out of 5000. Estimated time remaining: 2979.78 seconds.
# Processed 639 out of 5000. Estimated time remaining: 2980.97 seconds.
# Processed 640 out of 5000. Estimated time remaining: 2982.09 seconds.
# Processed 641 out of 5000. Estimated time remaining: 2982.13 seconds.
# Processed 642 out of 5000. Estimated time remaining: 2984.46 seconds.
# Processed 643 out of 5000. Estimated time remaining: 2986.78 seconds.
# Processed 644 out of 5000. Estimated time remaining: 2989.23 seconds.
# Processed 645 out of 5000. Estimated time remaining: 2991.76 seconds.
# Processed 646 out of 5000. Estimated time remaining: 2993.51 seconds.
# Processed 647 out of 5000. Estimated time remaining: 2995.83 seconds.
# Processed 648 out of 5000. Estimated time remaining: 2997.24 seconds.
# Processed 649 out of 5000. Estimated time remaining: 3000.22 seconds.
# Processed 650 out of 5000. Estimated time remaining: 3003.09 seconds.
# Processed 651 out of 5000. Estimated time remaining: 3003.57 seconds.
# Processed 652 out of 5000. Estimated time remaining: 3006.18 seconds.
# Processed 653 out of 5000. Estimated time remaining: 3006.61 seconds.
# Processed 654 out of 5000. Estimated time remaining: 3009.33 seconds.
# Processed 655 out of 5000. Estimated time remaining: 3011.84 seconds.
# Processed 656 out of 5000. Estimated time remaining: 3013.12 seconds.
# Processed 657 out of 5000. Estimated time remaining: 3016.12 seconds.
# Processed 658 out of 5000. Estimated time remaining: 3018.56 seconds.
# Processed 659 out of 5000. Estimated time remaining: 3019.16 seconds.
# Processed 660 out of 5000. Estimated time remaining: 3020.30 seconds.
# Processed 661 out of 5000. Estimated time remaining: 3021.77 seconds.
# Processed 662 out of 5000. Estimated time remaining: 3022.88 seconds.
# Processed 663 out of 5000. Estimated time remaining: 3023.07 seconds.
# Processed 664 out of 5000. Estimated time remaining: 3024.77 seconds.
# Processed 665 out of 5000. Estimated time remaining: 3025.13 seconds.
# Processed 666 out of 5000. Estimated time remaining: 3027.11 seconds.
# Processed 667 out of 5000. Estimated time remaining: 3029.78 seconds.
# Processed 668 out of 5000. Estimated time remaining: 3031.98 seconds.
# Processed 669 out of 5000. Estimated time remaining: 3034.14 seconds.
# Processed 670 out of 5000. Estimated time remaining: 3035.42 seconds.
# Processed 671 out of 5000. Estimated time remaining: 3036.64 seconds.
# Processed 672 out of 5000. Estimated time remaining: 3037.66 seconds.
# Processed 673 out of 5000. Estimated time remaining: 3038.43 seconds.
# Processed 674 out of 5000. Estimated time remaining: 3041.19 seconds.
# Processed 675 out of 5000. Estimated time remaining: 3042.32 seconds.
# Processed 676 out of 5000. Estimated time remaining: 3044.08 seconds.
# Processed 677 out of 5000. Estimated time remaining: 3043.14 seconds.
# Processed 678 out of 5000. Estimated time remaining: 3043.23 seconds.
# Processed 679 out of 5000. Estimated time remaining: 3045.02 seconds.
# Processed 680 out of 5000. Estimated time remaining: 3046.22 seconds.
# Processed 681 out of 5000. Estimated time remaining: 3047.83 seconds.
# Processed 682 out of 5000. Estimated time remaining: 3049.77 seconds.
# Processed 683 out of 5000. Estimated time remaining: 3052.38 seconds.
# Processed 684 out of 5000. Estimated time remaining: 3054.87 seconds.
# Processed 685 out of 5000. Estimated time remaining: 3055.37 seconds.
# Processed 686 out of 5000. Estimated time remaining: 3056.09 seconds.
# Processed 687 out of 5000. Estimated time remaining: 3058.43 seconds.
# ...
# Processed 4770 out of 5000. Estimated time remaining: 143.67 seconds.
# Processed 4771 out of 5000. Estimated time remaining: 143.04 seconds.
# Processed 4772 out of 5000. Estimated time remaining: 142.42 seconds.
# Processed 4773 out of 5000. Estimated time remaining: 141.79 seconds.
# Processed 4774 out of 5000. Estimated time remaining: 141.17 seconds.
# Processed 4775 out of 5000. Estimated time remaining: 140.54 seconds.
# Processed 4776 out of 5000. Estimated time remaining: 139.91 seconds.
# Processed 4777 out of 5000. Estimated time remaining: 139.29 seconds.
# Processed 4778 out of 5000. Estimated time remaining: 138.66 seconds.
# Processed 4779 out of 5000. Estimated time remaining: 138.04 seconds.
# Processed 4780 out of 5000. Estimated time remaining: 137.41 seconds.
# Processed 4781 out of 5000. Estimated time remaining: 136.78 seconds.
# Processed 4782 out of 5000. Estimated time remaining: 136.15 seconds.
# Processed 4783 out of 5000. Estimated time remaining: 135.53 seconds.
# Processed 4784 out of 5000. Estimated time remaining: 134.90 seconds.
# Processed 4785 out of 5000. Estimated time remaining: 134.28 seconds.
# Processed 4786 out of 5000. Estimated time remaining: 133.65 seconds.
# Processed 4787 out of 5000. Estimated time remaining: 133.03 seconds.
# Processed 4788 out of 5000. Estimated time remaining: 132.40 seconds.
# Processed 4789 out of 5000. Estimated time remaining: 131.77 seconds.
# Processed 4790 out of 5000. Estimated time remaining: 131.15 seconds.
# Processed 4791 out of 5000. Estimated time remaining: 130.52 seconds.
# Processed 4792 out of 5000. Estimated time remaining: 129.90 seconds.
# Processed 4793 out of 5000. Estimated time remaining: 129.27 seconds.
# Processed 4794 out of 5000. Estimated time remaining: 128.65 seconds.
# Processed 4795 out of 5000. Estimated time remaining: 128.02 seconds.
# Processed 4796 out of 5000. Estimated time remaining: 127.39 seconds.
# Processed 4797 out of 5000. Estimated time remaining: 126.77 seconds.
# Processed 4798 out of 5000. Estimated time remaining: 126.14 seconds.
# Processed 4799 out of 5000. Estimated time remaining: 125.52 seconds.
# Processed 4800 out of 5000. Estimated time remaining: 124.89 seconds.
# Processed 4801 out of 5000. Estimated time remaining: 124.27 seconds.
# Processed 4802 out of 5000. Estimated time remaining: 123.64 seconds.
# Processed 4803 out of 5000. Estimated time remaining: 123.02 seconds.
# Processed 4804 out of 5000. Estimated time remaining: 122.39 seconds.
# Processed 4805 out of 5000. Estimated time remaining: 121.77 seconds.
# Processed 4806 out of 5000. Estimated time remaining: 121.15 seconds.
# Processed 4807 out of 5000. Estimated time remaining: 120.52 seconds.
# Processed 4808 out of 5000. Estimated time remaining: 119.90 seconds.
# Processed 4809 out of 5000. Estimated time remaining: 119.27 seconds.
# Processed 4810 out of 5000. Estimated time remaining: 118.65 seconds.
# Processed 4811 out of 5000. Estimated time remaining: 118.02 seconds.
# Processed 4812 out of 5000. Estimated time remaining: 117.39 seconds.
# Processed 4813 out of 5000. Estimated time remaining: 116.77 seconds.
# Processed 4814 out of 5000. Estimated time remaining: 116.14 seconds.
# Processed 4815 out of 5000. Estimated time remaining: 115.52 seconds.
# Processed 4816 out of 5000. Estimated time remaining: 114.89 seconds.
# Processed 4817 out of 5000. Estimated time remaining: 114.27 seconds.
# Processed 4818 out of 5000. Estimated time remaining: 113.64 seconds.
# Processed 4819 out of 5000. Estimated time remaining: 113.02 seconds.
# Processed 4820 out of 5000. Estimated time remaining: 112.39 seconds.
# Processed 4821 out of 5000. Estimated time remaining: 111.77 seconds.
# Processed 4822 out of 5000. Estimated time remaining: 111.14 seconds.
# Processed 4823 out of 5000. Estimated time remaining: 110.52 seconds.
# Processed 4824 out of 5000. Estimated time remaining: 109.89 seconds.
# Processed 4825 out of 5000. Estimated time remaining: 109.27 seconds.
# Processed 4826 out of 5000. Estimated time remaining: 108.64 seconds.
# Processed 4827 out of 5000. Estimated time remaining: 108.01 seconds.
# Processed 4828 out of 5000. Estimated time remaining: 107.39 seconds.
# Processed 4829 out of 5000. Estimated time remaining: 106.76 seconds.
# Processed 4830 out of 5000. Estimated time remaining: 106.14 seconds.
# Processed 4831 out of 5000. Estimated time remaining: 105.52 seconds.
# Processed 4832 out of 5000. Estimated time remaining: 104.89 seconds.
# Processed 4833 out of 5000. Estimated time remaining: 104.27 seconds.
# Processed 4834 out of 5000. Estimated time remaining: 103.64 seconds.
# Processed 4835 out of 5000. Estimated time remaining: 103.01 seconds.
# Processed 4836 out of 5000. Estimated time remaining: 102.39 seconds.
# Processed 4837 out of 5000. Estimated time remaining: 101.77 seconds.
# Processed 4838 out of 5000. Estimated time remaining: 101.15 seconds.
# Processed 4839 out of 5000. Estimated time remaining: 100.52 seconds.
# Processed 4840 out of 5000. Estimated time remaining: 99.90 seconds.
# Processed 4841 out of 5000. Estimated time remaining: 99.28 seconds.
# Processed 4842 out of 5000. Estimated time remaining: 98.65 seconds.
# Processed 4843 out of 5000. Estimated time remaining: 98.03 seconds.
# Processed 4844 out of 5000. Estimated time remaining: 97.40 seconds.
# Processed 4845 out of 5000. Estimated time remaining: 96.78 seconds.
# Processed 4846 out of 5000. Estimated time remaining: 96.15 seconds.
# Processed 4847 out of 5000. Estimated time remaining: 95.53 seconds.
# Processed 4848 out of 5000. Estimated time remaining: 94.90 seconds.
# Processed 4849 out of 5000. Estimated time remaining: 94.27 seconds.
# Processed 4850 out of 5000. Estimated time remaining: 93.65 seconds.
# Processed 4851 out of 5000. Estimated time remaining: 93.02 seconds.
# Processed 4852 out of 5000. Estimated time remaining: 92.40 seconds.
# Processed 4853 out of 5000. Estimated time remaining: 91.77 seconds.
# Processed 4854 out of 5000. Estimated time remaining: 91.15 seconds.
# Processed 4855 out of 5000. Estimated time remaining: 90.52 seconds.
# Processed 4856 out of 5000. Estimated time remaining: 89.90 seconds.
# Processed 4857 out of 5000. Estimated time remaining: 89.27 seconds.
# Processed 4858 out of 5000. Estimated time remaining: 88.65 seconds.
# Processed 4859 out of 5000. Estimated time remaining: 88.02 seconds.
# Processed 4860 out of 5000. Estimated time remaining: 87.40 seconds.
# Processed 4861 out of 5000. Estimated time remaining: 86.77 seconds.
# Processed 4862 out of 5000. Estimated time remaining: 86.15 seconds.
# Processed 4863 out of 5000. Estimated time remaining: 85.52 seconds.
# Processed 4864 out of 5000. Estimated time remaining: 84.90 seconds.
# Processed 4865 out of 5000. Estimated time remaining: 84.27 seconds.
# Processed 4866 out of 5000. Estimated time remaining: 83.65 seconds.
# Processed 4867 out of 5000. Estimated time remaining: 83.02 seconds.
# Processed 4868 out of 5000. Estimated time remaining: 82.40 seconds.
# Processed 4869 out of 5000. Estimated time remaining: 81.77 seconds.
# Processed 4870 out of 5000. Estimated time remaining: 81.15 seconds.
# Processed 4871 out of 5000. Estimated time remaining: 80.52 seconds.
# Processed 4872 out of 5000. Estimated time remaining: 79.90 seconds.
# Processed 4873 out of 5000. Estimated time remaining: 79.27 seconds.
# Processed 4874 out of 5000. Estimated time remaining: 78.65 seconds.
# Processed 4875 out of 5000. Estimated time remaining: 78.02 seconds.
# Processed 4876 out of 5000. Estimated time remaining: 77.40 seconds.
# Processed 4877 out of 5000. Estimated time remaining: 76.77 seconds.
# Processed 4878 out of 5000. Estimated time remaining: 76.15 seconds.
# Processed 4879 out of 5000. Estimated time remaining: 75.52 seconds.
# Processed 4880 out of 5000. Estimated time remaining: 74.90 seconds.
# Processed 4881 out of 5000. Estimated time remaining: 74.27 seconds.
# Processed 4882 out of 5000. Estimated time remaining: 73.65 seconds.
# Processed 4883 out of 5000. Estimated time remaining: 73.02 seconds.
# Processed 4884 out of 5000. Estimated time remaining: 72.40 seconds.
# Processed 4885 out of 5000. Estimated time remaining: 71.77 seconds.
# Processed 4886 out of 5000. Estimated time remaining: 71.15 seconds.
# Processed 4887 out of 5000. Estimated time remaining: 70.52 seconds.
# Processed 4888 out of 5000. Estimated time remaining: 69.90 seconds.
# Processed 4889 out of 5000. Estimated time remaining: 69.28 seconds.
# Processed 4890 out of 5000. Estimated time remaining: 68.65 seconds.
# Processed 4891 out of 5000. Estimated time remaining: 68.03 seconds.
# Processed 4892 out of 5000. Estimated time remaining: 67.40 seconds.
# Processed 4893 out of 5000. Estimated time remaining: 66.78 seconds.
# Processed 4894 out of 5000. Estimated time remaining: 66.15 seconds.
# Processed 4895 out of 5000. Estimated time remaining: 65.53 seconds.
# Processed 4896 out of 5000. Estimated time remaining: 64.90 seconds.
# Processed 4897 out of 5000. Estimated time remaining: 64.28 seconds.
# Processed 4898 out of 5000. Estimated time remaining: 63.65 seconds.
# Processed 4899 out of 5000. Estimated time remaining: 63.03 seconds.
# Processed 4900 out of 5000. Estimated time remaining: 62.40 seconds.
# Processed 4901 out of 5000. Estimated time remaining: 61.78 seconds.
# Processed 4902 out of 5000. Estimated time remaining: 61.16 seconds.
# Processed 4903 out of 5000. Estimated time remaining: 60.53 seconds.
# Processed 4904 out of 5000. Estimated time remaining: 59.91 seconds.
# Processed 4905 out of 5000. Estimated time remaining: 59.28 seconds.
# Processed 4906 out of 5000. Estimated time remaining: 58.66 seconds.
# Processed 4907 out of 5000. Estimated time remaining: 58.04 seconds.
# Processed 4908 out of 5000. Estimated time remaining: 57.41 seconds.
# Processed 4909 out of 5000. Estimated time remaining: 56.79 seconds.
# Processed 4910 out of 5000. Estimated time remaining: 56.16 seconds.
# Processed 4911 out of 5000. Estimated time remaining: 55.54 seconds.
# Processed 4912 out of 5000. Estimated time remaining: 54.91 seconds.
# Processed 4913 out of 5000. Estimated time remaining: 54.29 seconds.
# Processed 4914 out of 5000. Estimated time remaining: 53.67 seconds.
# Processed 4915 out of 5000. Estimated time remaining: 53.04 seconds.
# Processed 4916 out of 5000. Estimated time remaining: 52.42 seconds.
# Processed 4917 out of 5000. Estimated time remaining: 51.79 seconds.
# Processed 4918 out of 5000. Estimated time remaining: 51.17 seconds.
# Processed 4919 out of 5000. Estimated time remaining: 50.55 seconds.
# Processed 4920 out of 5000. Estimated time remaining: 49.92 seconds.
# Processed 4921 out of 5000. Estimated time remaining: 49.30 seconds.
# Processed 4922 out of 5000. Estimated time remaining: 48.67 seconds.
# Processed 4923 out of 5000. Estimated time remaining: 48.05 seconds.
# Processed 4924 out of 5000. Estimated time remaining: 47.42 seconds.
# Processed 4925 out of 5000. Estimated time remaining: 46.80 seconds.
# Processed 4926 out of 5000. Estimated time remaining: 46.18 seconds.
# Processed 4927 out of 5000. Estimated time remaining: 45.55 seconds.
# Processed 4928 out of 5000. Estimated time remaining: 44.93 seconds.
# Processed 4929 out of 5000. Estimated time remaining: 44.30 seconds.
# Processed 4930 out of 5000. Estimated time remaining: 43.68 seconds.
# Processed 4931 out of 5000. Estimated time remaining: 43.05 seconds.
# Processed 4932 out of 5000. Estimated time remaining: 42.43 seconds.
# Processed 4933 out of 5000. Estimated time remaining: 41.81 seconds.
# Processed 4934 out of 5000. Estimated time remaining: 41.18 seconds.
# Processed 4935 out of 5000. Estimated time remaining: 40.56 seconds.
# Processed 4936 out of 5000. Estimated time remaining: 39.93 seconds.
# Processed 4937 out of 5000. Estimated time remaining: 39.31 seconds.
# Processed 4938 out of 5000. Estimated time remaining: 38.69 seconds.
# Processed 4939 out of 5000. Estimated time remaining: 38.06 seconds.
# Processed 4940 out of 5000. Estimated time remaining: 37.44 seconds.
# Processed 4941 out of 5000. Estimated time remaining: 36.81 seconds.
# Processed 4942 out of 5000. Estimated time remaining: 36.19 seconds.
# Processed 4943 out of 5000. Estimated time remaining: 35.56 seconds.
# Processed 4944 out of 5000. Estimated time remaining: 34.94 seconds.
# Processed 4945 out of 5000. Estimated time remaining: 34.32 seconds.
# Processed 4946 out of 5000. Estimated time remaining: 33.69 seconds.
# Processed 4947 out of 5000. Estimated time remaining: 33.07 seconds.
# Processed 4948 out of 5000. Estimated time remaining: 32.44 seconds.
# Processed 4949 out of 5000. Estimated time remaining: 31.82 seconds.
# Processed 4950 out of 5000. Estimated time remaining: 31.20 seconds.
# Processed 4951 out of 5000. Estimated time remaining: 30.57 seconds.
# Processed 4952 out of 5000. Estimated time remaining: 29.95 seconds.
# Processed 4953 out of 5000. Estimated time remaining: 29.32 seconds.
# Processed 4954 out of 5000. Estimated time remaining: 28.70 seconds.
# Processed 4955 out of 5000. Estimated time remaining: 28.07 seconds.
# Processed 4956 out of 5000. Estimated time remaining: 27.45 seconds.
# Processed 4957 out of 5000. Estimated time remaining: 26.83 seconds.
# Processed 4958 out of 5000. Estimated time remaining: 26.20 seconds.
# Processed 4959 out of 5000. Estimated time remaining: 25.58 seconds.
# Processed 4960 out of 5000. Estimated time remaining: 24.95 seconds.
# Processed 4961 out of 5000. Estimated time remaining: 24.33 seconds.
# Processed 4962 out of 5000. Estimated time remaining: 23.71 seconds.
# Processed 4963 out of 5000. Estimated time remaining: 23.08 seconds.
# Processed 4964 out of 5000. Estimated time remaining: 22.46 seconds.
# Processed 4965 out of 5000. Estimated time remaining: 21.83 seconds.
# Processed 4966 out of 5000. Estimated time remaining: 21.21 seconds.
# Processed 4967 out of 5000. Estimated time remaining: 20.59 seconds.
# Processed 4968 out of 5000. Estimated time remaining: 19.96 seconds.
# Processed 4969 out of 5000. Estimated time remaining: 19.34 seconds.
# Processed 4970 out of 5000. Estimated time remaining: 18.71 seconds.
# Processed 4971 out of 5000. Estimated time remaining: 18.09 seconds.
# Processed 4972 out of 5000. Estimated time remaining: 17.47 seconds.
# Processed 4973 out of 5000. Estimated time remaining: 16.84 seconds.
# Processed 4974 out of 5000. Estimated time remaining: 16.22 seconds.
# Processed 4975 out of 5000. Estimated time remaining: 15.60 seconds.
# Processed 4976 out of 5000. Estimated time remaining: 14.97 seconds.
# Processed 4977 out of 5000. Estimated time remaining: 14.35 seconds.
# Processed 4978 out of 5000. Estimated time remaining: 13.72 seconds.
# Processed 4979 out of 5000. Estimated time remaining: 13.10 seconds.
# Processed 4980 out of 5000. Estimated time remaining: 12.48 seconds.
# Processed 4981 out of 5000. Estimated time remaining: 11.85 seconds.
# Processed 4982 out of 5000. Estimated time remaining: 11.23 seconds.
# Processed 4983 out of 5000. Estimated time remaining: 10.60 seconds.
# Processed 4984 out of 5000. Estimated time remaining: 9.98 seconds.
# Processed 4985 out of 5000. Estimated time remaining: 9.36 seconds.
# Processed 4986 out of 5000. Estimated time remaining: 8.73 seconds.
# Processed 4987 out of 5000. Estimated time remaining: 8.11 seconds.
# Processed 4988 out of 5000. Estimated time remaining: 7.48 seconds.
# Processed 4989 out of 5000. Estimated time remaining: 6.86 seconds.
# Processed 4990 out of 5000. Estimated time remaining: 6.24 seconds.
# Processed 4991 out of 5000. Estimated time remaining: 5.61 seconds.
# Processed 4992 out of 5000. Estimated time remaining: 4.99 seconds.
# Processed 4993 out of 5000. Estimated time remaining: 4.37 seconds.
# Processed 4994 out of 5000. Estimated time remaining: 3.74 seconds.
# Processed 4995 out of 5000. Estimated time remaining: 3.12 seconds.
# Processed 4996 out of 5000. Estimated time remaining: 2.49 seconds.
# Processed 4997 out of 5000. Estimated time remaining: 1.87 seconds.
# Processed 4998 out of 5000. Estimated time remaining: 1.25 seconds.
# Processed 4999 out of 5000. Estimated time remaining: 0.62 seconds.
# Processed 5000 out of 5000. Estimated time remaining: 0.00 seconds.
