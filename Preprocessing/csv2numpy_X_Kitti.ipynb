# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
import io
import cv2
import time

# %%
def lidar_to_2d_front_view(points,
                           v_res,
                           h_res,
                           v_fov,
                           val="depth",
                           cmap="jet",
                           saveto=None,
                           y_fudge=0.0
                           ):
    """ Takes points in 3D space from LIDAR data and projects them to a 2D
        "front view" image, and saves that image.

    Args:
        points: (np array)
            The numpy array containing the lidar points.
            The shape should be Nx4
            - Where N is the number of points, and
            - each point is specified by 4 values (x, y, z, reflectance)
        v_res: (float)
            vertical resolution of the lidar sensor used.
        h_res: (float)
            horizontal resolution of the lidar sensor used.
        v_fov: (tuple of two floats)
            (minimum_negative_angle, max_positive_angle)
        val: (str)
            What value to use to encode the points that get plotted.
            One of {"depth", "height", "reflectance"}
        cmap: (str)
            Color map to use to color code the `val` values.
            NOTE: Must be a value accepted by matplotlib's scatter function
            Examples: "jet", "gray"
        saveto: (str or None)
            If a string is provided, it saves the image as this filename.
            If None, then it just shows the image.
        y_fudge: (float)
            A hacky fudge factor to use if the theoretical calculations of
            vertical range do not match the actual data.

            For a Velodyne HDL 64E, set this value to 5.
    """

    # DUMMY PROOFING
    assert len(v_fov) ==2, "v_fov must be list/tuple of length 2"
    assert v_fov[0] <= 0, "first element in v_fov must be 0 or negative"
    #assert val in {"depth", "height", "intensity"}, \
        #'val must be one of {"depth", "height", "intensity"}'


    x_lidar = points[:, 0]
    y_lidar = points[:, 1]
    z_lidar = points[:, 2]
    r_lidar = points[:, 3] # Reflectance
    # Distance relative to origin when looked from top
    d_lidar = np.sqrt(x_lidar ** 2 + y_lidar ** 2)
    # Absolute distance relative to origin
    d_lidar_abs = np.sqrt(x_lidar ** 2 + y_lidar ** 2, z_lidar ** 2)

    v_fov_total = -v_fov[0] + v_fov[1]

    # Convert to Radians
    v_res_rad = v_res * (np.pi/180)
    h_res_rad = h_res * (np.pi/180)

    # PROJECT INTO IMAGE COORDINATES
    x_img = np.arctan2(-y_lidar, x_lidar)/ h_res_rad #theta 
    y_img = np.arctan2(z_lidar, d_lidar_abs)/ v_res_rad #phi


    # SHIFT COORDINATES TO MAKE 0,0 THE MINIMUM
    x_min = -360.0 / h_res / 2  # Theoretical min x value based on sensor specs
    x_img -= x_min              # Shift
    x_max = 360.0 / h_res       # Theoretical max x value after shifting

    y_min = v_fov[0] / v_res    # theoretical min y value based on sensor specs
    y_img -= y_min              # Shift
    y_max = v_fov_total / v_res # Theoretical max x value after shifting

    y_max += y_fudge            # Fudge factor if the calculations based on
                                # spec sheet do not match the range of
                                # angles collected by in the data.

    # WHAT DATA TO USE TO ENCODE THE VALUE FOR EACH PIXEL
    if val == "intensity":
        pixel_values = r_lidar
    elif val == "height":
        pixel_values = z_lidar
    elif val == "x":
        pixel_values = x_lidar
    elif val == "y":
        pixel_values = y_lidar
    elif val == "z":
        pixel_values = z_lidar
    
    else:
        pixel_values = d_lidar

    pixel_values=np.array(pixel_values)

    # Rescale x_img and y_img to fit within 64x1024 grid
    x_img_scaled = (x_img / x_max) * 1024
    y_img_scaled = (y_img / y_max) * 64


    # Create a 2D array to store pixel values
    image_array = np.zeros((64, 1024))

    # Assign pixel values to the corresponding grid points
    for i in range(len(x_img_scaled)):
        x_index = int(round(x_img_scaled[i]))
        y_index = int(round(y_img_scaled[i]))
        if 0 <= x_index < 1024 and 0 <= y_index < 64:
            image_array[63-y_index, x_index] = pixel_values[i]

    if saveto is not None:
        np.save(saveto, image_array)

# %%
# set input and output folder paths
folder = 'Train'
input_folder = rf"/DATA2/Vivek/Data/Csv/csv files/Subset_Downstream_Task/{folder}"
output_folder = rf"/DATA2/Vivek/Data/Downstream Task/{folder}/train_lidar_x"

# create output folder if it does not exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
HRES = 0.35         # horizontal resolution (assuming 20Hz setting)
VRES = 0.4          # vertical res
#VFOV = (-25, 15) # Field of view (-ve, +ve) along vertical axis
VFOV = (-25, 2) # Field of view (-ve, +ve) along vertical axis
Y_FUDGE = 0         # y fudge factor for velodyne HDL 64E

#val must be one of {"depth", "height", "intensity","angle"}
#value = "intensity"
value = "x"


all_files = [filename for filename in os.listdir(input_folder) if filename.endswith('.csv')]
total_files = len(all_files)
start_time = time.time()

for index, filename in enumerate(all_files):
    # read CSV file into pandas dataframe
    df = pd.read_csv(os.path.join(input_folder, filename))
    
    # convert dataframe to numpy array
    lidar = np.array(df[['x', 'y', 'z', 'intensity']])
    
    # apply lidar_to_2d_front_view function
    output_filename = os.path.splitext(filename)[0] + '.npy'
    output_path = os.path.join(output_folder, output_filename)
    lidar_to_2d_front_view(lidar, v_res=VRES, h_res=HRES, v_fov=VFOV, val=value, saveto=output_path, y_fudge=Y_FUDGE)
    
    processed_files = index + 1
    elapsed_time = time.time() - start_time
    estimated_time_remaining = elapsed_time / processed_files * (total_files - processed_files)
    print(f"Processed {processed_files} out of {total_files}. Estimated time remaining: {estimated_time_remaining:.2f} seconds.")
# Out:
# Processed 1 out of 5000. Estimated time remaining: 3050.74 seconds.
# Processed 2 out of 5000. Estimated time remaining: 3022.45 seconds.
# Processed 3 out of 5000. Estimated time remaining: 3064.50 seconds.
# Processed 4 out of 5000. Estimated time remaining: 3116.32 seconds.
# Processed 5 out of 5000. Estimated time remaining: 3127.90 seconds.
# Processed 6 out of 5000. Estimated time remaining: 3132.52 seconds.
# Processed 7 out of 5000. Estimated time remaining: 3116.20 seconds.
# Processed 8 out of 5000. Estimated time remaining: 3105.25 seconds.
# Processed 9 out of 5000. Estimated time remaining: 3109.77 seconds.
# Processed 10 out of 5000. Estimated time remaining: 2829.45 seconds.
# Processed 11 out of 5000. Estimated time remaining: 2785.35 seconds.
# Processed 12 out of 5000. Estimated time remaining: 2669.92 seconds.
# Processed 13 out of 5000. Estimated time remaining: 2573.35 seconds.
# Processed 14 out of 5000. Estimated time remaining: 2424.81 seconds.
# Processed 15 out of 5000. Estimated time remaining: 2481.85 seconds.
# Processed 16 out of 5000. Estimated time remaining: 2531.36 seconds.
# Processed 17 out of 5000. Estimated time remaining: 2556.94 seconds.
# Processed 18 out of 5000. Estimated time remaining: 2582.79 seconds.
# Processed 19 out of 5000. Estimated time remaining: 2617.10 seconds.
# Processed 20 out of 5000. Estimated time remaining: 2635.46 seconds.
# Processed 21 out of 5000. Estimated time remaining: 2656.63 seconds.
# Processed 22 out of 5000. Estimated time remaining: 2681.30 seconds.
# Processed 23 out of 5000. Estimated time remaining: 2699.31 seconds.
# Processed 24 out of 5000. Estimated time remaining: 2717.24 seconds.
# Processed 25 out of 5000. Estimated time remaining: 2735.29 seconds.
# Processed 26 out of 5000. Estimated time remaining: 2754.15 seconds.
# Processed 27 out of 5000. Estimated time remaining: 2774.01 seconds.
# Processed 28 out of 5000. Estimated time remaining: 2791.10 seconds.
# Processed 29 out of 5000. Estimated time remaining: 2800.95 seconds.
# Processed 30 out of 5000. Estimated time remaining: 2817.71 seconds.
# Processed 31 out of 5000. Estimated time remaining: 2815.12 seconds.
# Processed 32 out of 5000. Estimated time remaining: 2825.64 seconds.
# Processed 33 out of 5000. Estimated time remaining: 2835.26 seconds.
# Processed 34 out of 5000. Estimated time remaining: 2847.75 seconds.
# Processed 35 out of 5000. Estimated time remaining: 2857.23 seconds.
# Processed 36 out of 5000. Estimated time remaining: 2866.72 seconds.
# Processed 37 out of 5000. Estimated time remaining: 2873.96 seconds.
# Processed 38 out of 5000. Estimated time remaining: 2880.81 seconds.
# Processed 39 out of 5000. Estimated time remaining: 2882.42 seconds.
# Processed 40 out of 5000. Estimated time remaining: 2890.73 seconds.
# Processed 41 out of 5000. Estimated time remaining: 2894.05 seconds.
# Processed 42 out of 5000. Estimated time remaining: 2899.24 seconds.
# Processed 43 out of 5000. Estimated time remaining: 2905.43 seconds.
# Processed 44 out of 5000. Estimated time remaining: 2912.48 seconds.
# Processed 45 out of 5000. Estimated time remaining: 2922.57 seconds.
# Processed 46 out of 5000. Estimated time remaining: 2928.22 seconds.
# Processed 47 out of 5000. Estimated time remaining: 2926.96 seconds.
# Processed 48 out of 5000. Estimated time remaining: 2926.22 seconds.
# Processed 49 out of 5000. Estimated time remaining: 2927.21 seconds.
# Processed 50 out of 5000. Estimated time remaining: 2928.49 seconds.
# Processed 51 out of 5000. Estimated time remaining: 2931.02 seconds.
# Processed 52 out of 5000. Estimated time remaining: 2937.03 seconds.
# Processed 53 out of 5000. Estimated time remaining: 2941.09 seconds.
# Processed 54 out of 5000. Estimated time remaining: 2947.44 seconds.
# Processed 55 out of 5000. Estimated time remaining: 2948.83 seconds.
# Processed 56 out of 5000. Estimated time remaining: 2948.22 seconds.
# Processed 57 out of 5000. Estimated time remaining: 2951.78 seconds.
# Processed 58 out of 5000. Estimated time remaining: 2956.39 seconds.
# Processed 59 out of 5000. Estimated time remaining: 2959.39 seconds.
# Processed 60 out of 5000. Estimated time remaining: 2959.49 seconds.
# Processed 61 out of 5000. Estimated time remaining: 2961.11 seconds.
# Processed 62 out of 5000. Estimated time remaining: 2962.76 seconds.
# Processed 63 out of 5000. Estimated time remaining: 2960.12 seconds.
# Processed 64 out of 5000. Estimated time remaining: 2962.52 seconds.
# Processed 65 out of 5000. Estimated time remaining: 2966.34 seconds.
# Processed 66 out of 5000. Estimated time remaining: 2967.92 seconds.
# Processed 67 out of 5000. Estimated time remaining: 2970.54 seconds.
# Processed 68 out of 5000. Estimated time remaining: 2973.84 seconds.
# Processed 69 out of 5000. Estimated time remaining: 2977.17 seconds.
# Processed 70 out of 5000. Estimated time remaining: 2977.93 seconds.
# Processed 71 out of 5000. Estimated time remaining: 2979.16 seconds.
# Processed 72 out of 5000. Estimated time remaining: 2977.46 seconds.
# Processed 73 out of 5000. Estimated time remaining: 2976.79 seconds.
# Processed 74 out of 5000. Estimated time remaining: 2976.42 seconds.
# Processed 75 out of 5000. Estimated time remaining: 2981.59 seconds.
# Processed 76 out of 5000. Estimated time remaining: 2984.30 seconds.
# Processed 77 out of 5000. Estimated time remaining: 2988.02 seconds.
# Processed 78 out of 5000. Estimated time remaining: 2990.69 seconds.
# Processed 79 out of 5000. Estimated time remaining: 2991.94 seconds.
# Processed 80 out of 5000. Estimated time remaining: 2994.12 seconds.
# Processed 81 out of 5000. Estimated time remaining: 2991.40 seconds.
# Processed 82 out of 5000. Estimated time remaining: 2992.01 seconds.
# Processed 83 out of 5000. Estimated time remaining: 2992.80 seconds.
# Processed 84 out of 5000. Estimated time remaining: 2994.52 seconds.
# Processed 85 out of 5000. Estimated time remaining: 2995.77 seconds.
# Processed 86 out of 5000. Estimated time remaining: 2997.50 seconds.
# Processed 87 out of 5000. Estimated time remaining: 3002.20 seconds.
# Processed 88 out of 5000. Estimated time remaining: 3004.76 seconds.
# Processed 89 out of 5000. Estimated time remaining: 3005.00 seconds.
# Processed 90 out of 5000. Estimated time remaining: 3003.69 seconds.
# Processed 91 out of 5000. Estimated time remaining: 3005.32 seconds.
# Processed 92 out of 5000. Estimated time remaining: 3006.29 seconds.
# Processed 93 out of 5000. Estimated time remaining: 3006.39 seconds.
# Processed 94 out of 5000. Estimated time remaining: 3010.30 seconds.
# Processed 95 out of 5000. Estimated time remaining: 3011.39 seconds.
# Processed 96 out of 5000. Estimated time remaining: 3010.64 seconds.
# Processed 97 out of 5000. Estimated time remaining: 3009.16 seconds.
# Processed 98 out of 5000. Estimated time remaining: 3006.47 seconds.
# Processed 99 out of 5000. Estimated time remaining: 3007.13 seconds.
# Processed 100 out of 5000. Estimated time remaining: 3006.50 seconds.
# Processed 101 out of 5000. Estimated time remaining: 3004.15 seconds.
# Processed 102 out of 5000. Estimated time remaining: 3002.48 seconds.
# Processed 103 out of 5000. Estimated time remaining: 3000.95 seconds.
# Processed 104 out of 5000. Estimated time remaining: 3001.39 seconds.
# Processed 105 out of 5000. Estimated time remaining: 3001.14 seconds.
# Processed 106 out of 5000. Estimated time remaining: 2999.70 seconds.
# Processed 107 out of 5000. Estimated time remaining: 2998.08 seconds.
# Processed 108 out of 5000. Estimated time remaining: 2998.76 seconds.
# Processed 109 out of 5000. Estimated time remaining: 2996.41 seconds.
# Processed 110 out of 5000. Estimated time remaining: 2994.10 seconds.
# Processed 111 out of 5000. Estimated time remaining: 2992.65 seconds.
# Processed 112 out of 5000. Estimated time remaining: 2990.80 seconds.
# Processed 113 out of 5000. Estimated time remaining: 2991.06 seconds.
# Processed 114 out of 5000. Estimated time remaining: 2991.30 seconds.
# Processed 115 out of 5000. Estimated time remaining: 2990.64 seconds.
# Processed 116 out of 5000. Estimated time remaining: 2990.24 seconds.
# Processed 117 out of 5000. Estimated time remaining: 2988.54 seconds.
# Processed 118 out of 5000. Estimated time remaining: 2989.35 seconds.
# Processed 119 out of 5000. Estimated time remaining: 2990.11 seconds.
# Processed 120 out of 5000. Estimated time remaining: 2990.29 seconds.
# Processed 121 out of 5000. Estimated time remaining: 2990.26 seconds.
# Processed 122 out of 5000. Estimated time remaining: 2989.79 seconds.
# Processed 123 out of 5000. Estimated time remaining: 2989.98 seconds.
# Processed 124 out of 5000. Estimated time remaining: 2988.18 seconds.
# Processed 125 out of 5000. Estimated time remaining: 2987.92 seconds.
# Processed 126 out of 5000. Estimated time remaining: 2987.83 seconds.
# Processed 127 out of 5000. Estimated time remaining: 2987.28 seconds.
# Processed 128 out of 5000. Estimated time remaining: 2986.49 seconds.
# Processed 129 out of 5000. Estimated time remaining: 2987.02 seconds.
# Processed 130 out of 5000. Estimated time remaining: 2985.41 seconds.
# Processed 131 out of 5000. Estimated time remaining: 2985.07 seconds.
# Processed 132 out of 5000. Estimated time remaining: 2982.68 seconds.
# Processed 133 out of 5000. Estimated time remaining: 2982.34 seconds.
# Processed 134 out of 5000. Estimated time remaining: 2978.80 seconds.
# Processed 135 out of 5000. Estimated time remaining: 2979.80 seconds.
# Processed 136 out of 5000. Estimated time remaining: 2980.48 seconds.
# Processed 137 out of 5000. Estimated time remaining: 2980.17 seconds.
# Processed 138 out of 5000. Estimated time remaining: 2977.69 seconds.
# Processed 139 out of 5000. Estimated time remaining: 2976.67 seconds.
# Processed 140 out of 5000. Estimated time remaining: 2975.06 seconds.
# Processed 141 out of 5000. Estimated time remaining: 2975.14 seconds.
# Processed 142 out of 5000. Estimated time remaining: 2973.57 seconds.
# Processed 143 out of 5000. Estimated time remaining: 2972.62 seconds.
# Processed 144 out of 5000. Estimated time remaining: 2971.84 seconds.
# Processed 145 out of 5000. Estimated time remaining: 2969.86 seconds.
# Processed 146 out of 5000. Estimated time remaining: 2972.32 seconds.
# Processed 147 out of 5000. Estimated time remaining: 2971.33 seconds.
# Processed 148 out of 5000. Estimated time remaining: 2971.40 seconds.
# Processed 149 out of 5000. Estimated time remaining: 2970.41 seconds.
# Processed 150 out of 5000. Estimated time remaining: 2970.79 seconds.
# Processed 151 out of 5000. Estimated time remaining: 2971.10 seconds.
# Processed 152 out of 5000. Estimated time remaining: 2971.70 seconds.
# Processed 153 out of 5000. Estimated time remaining: 2970.93 seconds.
# Processed 154 out of 5000. Estimated time remaining: 2971.88 seconds.
# Processed 155 out of 5000. Estimated time remaining: 2971.74 seconds.
# Processed 156 out of 5000. Estimated time remaining: 2972.25 seconds.
# Processed 157 out of 5000. Estimated time remaining: 2972.86 seconds.
# Processed 158 out of 5000. Estimated time remaining: 2971.98 seconds.
# Processed 159 out of 5000. Estimated time remaining: 2972.77 seconds.
# Processed 160 out of 5000. Estimated time remaining: 2971.47 seconds.
# Processed 161 out of 5000. Estimated time remaining: 2970.37 seconds.
# Processed 162 out of 5000. Estimated time remaining: 2971.07 seconds.
# Processed 163 out of 5000. Estimated time remaining: 2971.21 seconds.
# Processed 164 out of 5000. Estimated time remaining: 2970.55 seconds.
# Processed 165 out of 5000. Estimated time remaining: 2970.13 seconds.
# Processed 166 out of 5000. Estimated time remaining: 2970.00 seconds.
# Processed 167 out of 5000. Estimated time remaining: 2969.54 seconds.
# Processed 168 out of 5000. Estimated time remaining: 2970.17 seconds.
# Processed 169 out of 5000. Estimated time remaining: 2969.87 seconds.
# Processed 170 out of 5000. Estimated time remaining: 2969.71 seconds.
# Processed 171 out of 5000. Estimated time remaining: 2970.27 seconds.
# Processed 172 out of 5000. Estimated time remaining: 2970.26 seconds.
# Processed 173 out of 5000. Estimated time remaining: 2970.47 seconds.
# Processed 174 out of 5000. Estimated time remaining: 2970.00 seconds.
# Processed 175 out of 5000. Estimated time remaining: 2970.37 seconds.
# Processed 176 out of 5000. Estimated time remaining: 2970.00 seconds.
# Processed 177 out of 5000. Estimated time remaining: 2969.48 seconds.
# Processed 178 out of 5000. Estimated time remaining: 2968.16 seconds.
# Processed 179 out of 5000. Estimated time remaining: 2967.39 seconds.
# Processed 180 out of 5000. Estimated time remaining: 2966.70 seconds.
# Processed 181 out of 5000. Estimated time remaining: 2966.51 seconds.
# Processed 182 out of 5000. Estimated time remaining: 2966.21 seconds.
# Processed 183 out of 5000. Estimated time remaining: 2966.57 seconds.
# Processed 184 out of 5000. Estimated time remaining: 2966.06 seconds.
# Processed 185 out of 5000. Estimated time remaining: 2963.74 seconds.
# Processed 186 out of 5000. Estimated time remaining: 2962.39 seconds.
# Processed 187 out of 5000. Estimated time remaining: 2963.18 seconds.
# Processed 188 out of 5000. Estimated time remaining: 2962.31 seconds.
# Processed 189 out of 5000. Estimated time remaining: 2961.43 seconds.
# Processed 190 out of 5000. Estimated time remaining: 2960.35 seconds.
# Processed 191 out of 5000. Estimated time remaining: 2959.21 seconds.
# Processed 192 out of 5000. Estimated time remaining: 2959.61 seconds.
# Processed 193 out of 5000. Estimated time remaining: 2959.43 seconds.
# Processed 194 out of 5000. Estimated time remaining: 2959.94 seconds.
# Processed 195 out of 5000. Estimated time remaining: 2959.47 seconds.
# Processed 196 out of 5000. Estimated time remaining: 2960.67 seconds.
# Processed 197 out of 5000. Estimated time remaining: 2960.81 seconds.
# Processed 198 out of 5000. Estimated time remaining: 2960.53 seconds.
# Processed 199 out of 5000. Estimated time remaining: 2959.95 seconds.
# Processed 200 out of 5000. Estimated time remaining: 2959.52 seconds.
# Processed 201 out of 5000. Estimated time remaining: 2958.96 seconds.
# Processed 202 out of 5000. Estimated time remaining: 2958.76 seconds.
# Processed 203 out of 5000. Estimated time remaining: 2958.93 seconds.
# Processed 204 out of 5000. Estimated time remaining: 2957.98 seconds.
# Processed 205 out of 5000. Estimated time remaining: 2957.27 seconds.
# Processed 206 out of 5000. Estimated time remaining: 2956.29 seconds.
# Processed 207 out of 5000. Estimated time remaining: 2956.45 seconds.
# Processed 208 out of 5000. Estimated time remaining: 2955.84 seconds.
# Processed 209 out of 5000. Estimated time remaining: 2955.92 seconds.
# Processed 210 out of 5000. Estimated time remaining: 2955.01 seconds.
# Processed 211 out of 5000. Estimated time remaining: 2954.15 seconds.
# Processed 212 out of 5000. Estimated time remaining: 2952.83 seconds.
# Processed 213 out of 5000. Estimated time remaining: 2951.96 seconds.
# Processed 214 out of 5000. Estimated time remaining: 2950.55 seconds.
# Processed 215 out of 5000. Estimated time remaining: 2949.79 seconds.
# Processed 216 out of 5000. Estimated time remaining: 2949.92 seconds.
# Processed 217 out of 5000. Estimated time remaining: 2948.47 seconds.
# Processed 218 out of 5000. Estimated time remaining: 2947.90 seconds.
# Processed 219 out of 5000. Estimated time remaining: 2947.22 seconds.
# Processed 220 out of 5000. Estimated time remaining: 2946.18 seconds.
# Processed 221 out of 5000. Estimated time remaining: 2944.90 seconds.
# Processed 222 out of 5000. Estimated time remaining: 2944.48 seconds.
# Processed 223 out of 5000. Estimated time remaining: 2944.10 seconds.
# Processed 224 out of 5000. Estimated time remaining: 2944.05 seconds.
# Processed 225 out of 5000. Estimated time remaining: 2943.37 seconds.
# Processed 226 out of 5000. Estimated time remaining: 2942.94 seconds.
# Processed 227 out of 5000. Estimated time remaining: 2942.36 seconds.
# Processed 228 out of 5000. Estimated time remaining: 2941.27 seconds.
# Processed 229 out of 5000. Estimated time remaining: 2941.61 seconds.
# Processed 230 out of 5000. Estimated time remaining: 2941.51 seconds.
# Processed 231 out of 5000. Estimated time remaining: 2940.75 seconds.
# Processed 232 out of 5000. Estimated time remaining: 2941.05 seconds.
# Processed 233 out of 5000. Estimated time remaining: 2940.78 seconds.
# Processed 234 out of 5000. Estimated time remaining: 2941.10 seconds.
# Processed 235 out of 5000. Estimated time remaining: 2941.15 seconds.
# Processed 236 out of 5000. Estimated time remaining: 2940.07 seconds.
# Processed 237 out of 5000. Estimated time remaining: 2939.79 seconds.
# Processed 238 out of 5000. Estimated time remaining: 2940.04 seconds.
# Processed 239 out of 5000. Estimated time remaining: 2939.44 seconds.
# Processed 240 out of 5000. Estimated time remaining: 2939.00 seconds.
# Processed 241 out of 5000. Estimated time remaining: 2939.26 seconds.
# Processed 242 out of 5000. Estimated time remaining: 2938.57 seconds.
# Processed 243 out of 5000. Estimated time remaining: 2938.05 seconds.
# Processed 244 out of 5000. Estimated time remaining: 2937.78 seconds.
# Processed 245 out of 5000. Estimated time remaining: 2936.99 seconds.
# Processed 246 out of 5000. Estimated time remaining: 2935.80 seconds.
# Processed 247 out of 5000. Estimated time remaining: 2935.27 seconds.
# Processed 248 out of 5000. Estimated time remaining: 2935.15 seconds.
# Processed 249 out of 5000. Estimated time remaining: 2932.91 seconds.
# Processed 250 out of 5000. Estimated time remaining: 2932.74 seconds.
# Processed 251 out of 5000. Estimated time remaining: 2932.32 seconds.
# Processed 252 out of 5000. Estimated time remaining: 2931.22 seconds.
# Processed 253 out of 5000. Estimated time remaining: 2930.41 seconds.
# Processed 254 out of 5000. Estimated time remaining: 2929.88 seconds.
# Processed 255 out of 5000. Estimated time remaining: 2929.36 seconds.
# Processed 256 out of 5000. Estimated time remaining: 2929.07 seconds.
# Processed 257 out of 5000. Estimated time remaining: 2928.48 seconds.
# Processed 258 out of 5000. Estimated time remaining: 2927.05 seconds.
# Processed 259 out of 5000. Estimated time remaining: 2926.52 seconds.
# Processed 260 out of 5000. Estimated time remaining: 2926.21 seconds.
# Processed 261 out of 5000. Estimated time remaining: 2925.75 seconds.
# Processed 262 out of 5000. Estimated time remaining: 2925.07 seconds.
# Processed 263 out of 5000. Estimated time remaining: 2924.85 seconds.
# Processed 264 out of 5000. Estimated time remaining: 2924.19 seconds.
# Processed 265 out of 5000. Estimated time remaining: 2923.67 seconds.
# Processed 266 out of 5000. Estimated time remaining: 2923.18 seconds.
# Processed 267 out of 5000. Estimated time remaining: 2922.31 seconds.
# Processed 268 out of 5000. Estimated time remaining: 2921.84 seconds.
# Processed 269 out of 5000. Estimated time remaining: 2921.36 seconds.
# Processed 270 out of 5000. Estimated time remaining: 2920.70 seconds.
# Processed 271 out of 5000. Estimated time remaining: 2921.18 seconds.
# Processed 272 out of 5000. Estimated time remaining: 2920.75 seconds.
# Processed 273 out of 5000. Estimated time remaining: 2920.03 seconds.
# Processed 274 out of 5000. Estimated time remaining: 2919.34 seconds.
# Processed 275 out of 5000. Estimated time remaining: 2919.26 seconds.
# Processed 276 out of 5000. Estimated time remaining: 2918.96 seconds.
# Processed 277 out of 5000. Estimated time remaining: 2918.32 seconds.
# Processed 278 out of 5000. Estimated time remaining: 2917.75 seconds.
# Processed 279 out of 5000. Estimated time remaining: 2919.00 seconds.
# Processed 280 out of 5000. Estimated time remaining: 2918.84 seconds.
# Processed 281 out of 5000. Estimated time remaining: 2918.24 seconds.
# Processed 282 out of 5000. Estimated time remaining: 2917.85 seconds.
# Processed 283 out of 5000. Estimated time remaining: 2917.45 seconds.
# Processed 284 out of 5000. Estimated time remaining: 2916.85 seconds.
# Processed 285 out of 5000. Estimated time remaining: 2916.34 seconds.
# Processed 286 out of 5000. Estimated time remaining: 2915.71 seconds.
# Processed 287 out of 5000. Estimated time remaining: 2915.01 seconds.
# Processed 288 out of 5000. Estimated time remaining: 2914.51 seconds.
# Processed 289 out of 5000. Estimated time remaining: 2914.05 seconds.
# Processed 290 out of 5000. Estimated time remaining: 2913.41 seconds.
# Processed 291 out of 5000. Estimated time remaining: 2912.66 seconds.
# Processed 292 out of 5000. Estimated time remaining: 2912.56 seconds.
# Processed 293 out of 5000. Estimated time remaining: 2911.74 seconds.
# Processed 294 out of 5000. Estimated time remaining: 2911.18 seconds.
# Processed 295 out of 5000. Estimated time remaining: 2911.34 seconds.
# Processed 296 out of 5000. Estimated time remaining: 2911.09 seconds.
# Processed 297 out of 5000. Estimated time remaining: 2910.44 seconds.
# Processed 298 out of 5000. Estimated time remaining: 2909.49 seconds.
# Processed 299 out of 5000. Estimated time remaining: 2909.11 seconds.
# Processed 300 out of 5000. Estimated time remaining: 2908.18 seconds.
# Processed 301 out of 5000. Estimated time remaining: 2907.86 seconds.
# Processed 302 out of 5000. Estimated time remaining: 2907.02 seconds.
# Processed 303 out of 5000. Estimated time remaining: 2906.12 seconds.
# Processed 304 out of 5000. Estimated time remaining: 2905.23 seconds.
# Processed 305 out of 5000. Estimated time remaining: 2904.75 seconds.
# Processed 306 out of 5000. Estimated time remaining: 2904.22 seconds.
# Processed 307 out of 5000. Estimated time remaining: 2903.72 seconds.
# Processed 308 out of 5000. Estimated time remaining: 2902.45 seconds.
# Processed 309 out of 5000. Estimated time remaining: 2902.19 seconds.
# Processed 310 out of 5000. Estimated time remaining: 2901.51 seconds.
# Processed 311 out of 5000. Estimated time remaining: 2900.75 seconds.
# Processed 312 out of 5000. Estimated time remaining: 2900.66 seconds.
# Processed 313 out of 5000. Estimated time remaining: 2899.24 seconds.
# Processed 314 out of 5000. Estimated time remaining: 2898.66 seconds.
# Processed 315 out of 5000. Estimated time remaining: 2898.10 seconds.
# Processed 316 out of 5000. Estimated time remaining: 2897.33 seconds.
# Processed 317 out of 5000. Estimated time remaining: 2896.88 seconds.
# Processed 318 out of 5000. Estimated time remaining: 2896.15 seconds.
# Processed 319 out of 5000. Estimated time remaining: 2895.42 seconds.
# Processed 320 out of 5000. Estimated time remaining: 2895.05 seconds.
# Processed 321 out of 5000. Estimated time remaining: 2894.97 seconds.
# Processed 322 out of 5000. Estimated time remaining: 2894.53 seconds.
# Processed 323 out of 5000. Estimated time remaining: 2893.73 seconds.
# Processed 324 out of 5000. Estimated time remaining: 2895.53 seconds.
# Processed 325 out of 5000. Estimated time remaining: 2895.35 seconds.
# Processed 326 out of 5000. Estimated time remaining: 2895.02 seconds.
# Processed 327 out of 5000. Estimated time remaining: 2894.84 seconds.
# Processed 328 out of 5000. Estimated time remaining: 2894.31 seconds.
# Processed 329 out of 5000. Estimated time remaining: 2893.60 seconds.
# Processed 330 out of 5000. Estimated time remaining: 2893.08 seconds.
# Processed 331 out of 5000. Estimated time remaining: 2892.35 seconds.
# Processed 332 out of 5000. Estimated time remaining: 2893.56 seconds.
# Processed 333 out of 5000. Estimated time remaining: 2893.37 seconds.
# Processed 334 out of 5000. Estimated time remaining: 2894.03 seconds.
# Processed 335 out of 5000. Estimated time remaining: 2893.60 seconds.
# Processed 336 out of 5000. Estimated time remaining: 2894.26 seconds.
# Processed 337 out of 5000. Estimated time remaining: 2893.77 seconds.
# Processed 338 out of 5000. Estimated time remaining: 2893.67 seconds.
# Processed 339 out of 5000. Estimated time remaining: 2893.78 seconds.
# Processed 340 out of 5000. Estimated time remaining: 2894.25 seconds.
# Processed 341 out of 5000. Estimated time remaining: 2895.30 seconds.
# Processed 342 out of 5000. Estimated time remaining: 2896.08 seconds.
# Processed 343 out of 5000. Estimated time remaining: 2895.89 seconds.
# Processed 344 out of 5000. Estimated time remaining: 2895.80 seconds.
# Processed 345 out of 5000. Estimated time remaining: 2895.64 seconds.
# Processed 346 out of 5000. Estimated time remaining: 2896.05 seconds.
# Processed 347 out of 5000. Estimated time remaining: 2895.43 seconds.
# Processed 348 out of 5000. Estimated time remaining: 2895.41 seconds.
# Processed 349 out of 5000. Estimated time remaining: 2894.49 seconds.
# Processed 350 out of 5000. Estimated time remaining: 2894.00 seconds.
# Processed 351 out of 5000. Estimated time remaining: 2893.85 seconds.
# Processed 352 out of 5000. Estimated time remaining: 2894.93 seconds.
# Processed 353 out of 5000. Estimated time remaining: 2895.16 seconds.
# Processed 354 out of 5000. Estimated time remaining: 2894.95 seconds.
# Processed 355 out of 5000. Estimated time remaining: 2894.36 seconds.
# Processed 356 out of 5000. Estimated time remaining: 2893.80 seconds.
# Processed 357 out of 5000. Estimated time remaining: 2893.20 seconds.
# Processed 358 out of 5000. Estimated time remaining: 2893.34 seconds.
# Processed 359 out of 5000. Estimated time remaining: 2893.42 seconds.
# Processed 360 out of 5000. Estimated time remaining: 2894.00 seconds.
# Processed 361 out of 5000. Estimated time remaining: 2893.56 seconds.
# Processed 362 out of 5000. Estimated time remaining: 2893.09 seconds.
# Processed 363 out of 5000. Estimated time remaining: 2893.59 seconds.
# Processed 364 out of 5000. Estimated time remaining: 2893.04 seconds.
# Processed 365 out of 5000. Estimated time remaining: 2892.94 seconds.
# Processed 366 out of 5000. Estimated time remaining: 2893.92 seconds.
# Processed 367 out of 5000. Estimated time remaining: 2893.25 seconds.
# Processed 368 out of 5000. Estimated time remaining: 2891.93 seconds.
# Processed 369 out of 5000. Estimated time remaining: 2891.34 seconds.
# Processed 370 out of 5000. Estimated time remaining: 2890.82 seconds.
# Processed 371 out of 5000. Estimated time remaining: 2904.65 seconds.
# Processed 372 out of 5000. Estimated time remaining: 2907.45 seconds.
# Processed 373 out of 5000. Estimated time remaining: 2907.13 seconds.
# Processed 374 out of 5000. Estimated time remaining: 2907.53 seconds.
# Processed 375 out of 5000. Estimated time remaining: 2907.90 seconds.
# Processed 376 out of 5000. Estimated time remaining: 2907.95 seconds.
# Processed 377 out of 5000. Estimated time remaining: 2916.97 seconds.
# Processed 378 out of 5000. Estimated time remaining: 2917.11 seconds.
# Processed 379 out of 5000. Estimated time remaining: 2916.64 seconds.
# Processed 380 out of 5000. Estimated time remaining: 2916.27 seconds.
# Processed 381 out of 5000. Estimated time remaining: 2916.08 seconds.
# Processed 382 out of 5000. Estimated time remaining: 2916.21 seconds.
# Processed 383 out of 5000. Estimated time remaining: 2916.39 seconds.
# Processed 384 out of 5000. Estimated time remaining: 2915.78 seconds.
# Processed 385 out of 5000. Estimated time remaining: 2915.60 seconds.
# Processed 386 out of 5000. Estimated time remaining: 2916.48 seconds.
# Processed 387 out of 5000. Estimated time remaining: 2915.83 seconds.
# Processed 388 out of 5000. Estimated time remaining: 2916.98 seconds.
# Processed 389 out of 5000. Estimated time remaining: 2916.22 seconds.
# Processed 390 out of 5000. Estimated time remaining: 2915.56 seconds.
# Processed 391 out of 5000. Estimated time remaining: 2915.30 seconds.
# Processed 392 out of 5000. Estimated time remaining: 2914.72 seconds.
# Processed 393 out of 5000. Estimated time remaining: 2914.14 seconds.
# Processed 394 out of 5000. Estimated time remaining: 2914.24 seconds.
# Processed 395 out of 5000. Estimated time remaining: 2913.67 seconds.
# Processed 396 out of 5000. Estimated time remaining: 2913.14 seconds.
# Processed 397 out of 5000. Estimated time remaining: 2914.09 seconds.
# Processed 398 out of 5000. Estimated time remaining: 2912.86 seconds.
# Processed 399 out of 5000. Estimated time remaining: 2912.56 seconds.
# Processed 400 out of 5000. Estimated time remaining: 2912.31 seconds.
# Processed 401 out of 5000. Estimated time remaining: 2913.69 seconds.
# Processed 402 out of 5000. Estimated time remaining: 2912.39 seconds.
# Processed 403 out of 5000. Estimated time remaining: 2912.53 seconds.
# Processed 404 out of 5000. Estimated time remaining: 2912.73 seconds.
# Processed 405 out of 5000. Estimated time remaining: 2912.41 seconds.
# Processed 406 out of 5000. Estimated time remaining: 2912.76 seconds.
# Processed 407 out of 5000. Estimated time remaining: 2911.72 seconds.
# Processed 408 out of 5000. Estimated time remaining: 2913.31 seconds.
# Processed 409 out of 5000. Estimated time remaining: 2912.36 seconds.
# Processed 410 out of 5000. Estimated time remaining: 2911.38 seconds.
# Processed 411 out of 5000. Estimated time remaining: 2910.41 seconds.
# Processed 412 out of 5000. Estimated time remaining: 2911.33 seconds.
# Processed 413 out of 5000. Estimated time remaining: 2910.77 seconds.
# Processed 414 out of 5000. Estimated time remaining: 2909.54 seconds.
# Processed 415 out of 5000. Estimated time remaining: 2909.35 seconds.
# Processed 416 out of 5000. Estimated time remaining: 2909.67 seconds.
# Processed 417 out of 5000. Estimated time remaining: 2910.70 seconds.
# Processed 418 out of 5000. Estimated time remaining: 2910.58 seconds.
# Processed 419 out of 5000. Estimated time remaining: 2913.41 seconds.
# Processed 420 out of 5000. Estimated time remaining: 2912.49 seconds.
# Processed 421 out of 5000. Estimated time remaining: 2912.14 seconds.
# Processed 422 out of 5000. Estimated time remaining: 2911.56 seconds.
# Processed 423 out of 5000. Estimated time remaining: 2917.50 seconds.
# Processed 424 out of 5000. Estimated time remaining: 2931.32 seconds.
# Processed 425 out of 5000. Estimated time remaining: 2940.55 seconds.
# Processed 426 out of 5000. Estimated time remaining: 2939.59 seconds.
# Processed 427 out of 5000. Estimated time remaining: 2939.40 seconds.
# Processed 428 out of 5000. Estimated time remaining: 2938.00 seconds.
# Processed 429 out of 5000. Estimated time remaining: 2937.43 seconds.
# Processed 430 out of 5000. Estimated time remaining: 2936.96 seconds.
# Processed 431 out of 5000. Estimated time remaining: 2936.18 seconds.
# Processed 432 out of 5000. Estimated time remaining: 2935.33 seconds.
# Processed 433 out of 5000. Estimated time remaining: 2939.52 seconds.
# Processed 434 out of 5000. Estimated time remaining: 2939.05 seconds.
# Processed 435 out of 5000. Estimated time remaining: 2938.36 seconds.
# Processed 436 out of 5000. Estimated time remaining: 2937.55 seconds.
# Processed 437 out of 5000. Estimated time remaining: 2936.93 seconds.
# Processed 438 out of 5000. Estimated time remaining: 2936.72 seconds.
# Processed 439 out of 5000. Estimated time remaining: 2936.15 seconds.
# Processed 440 out of 5000. Estimated time remaining: 2935.55 seconds.
# Processed 441 out of 5000. Estimated time remaining: 2939.13 seconds.
# Processed 442 out of 5000. Estimated time remaining: 2938.11 seconds.
# Processed 443 out of 5000. Estimated time remaining: 2937.70 seconds.
# Processed 444 out of 5000. Estimated time remaining: 2937.35 seconds.
# Processed 445 out of 5000. Estimated time remaining: 2937.01 seconds.
# Processed 446 out of 5000. Estimated time remaining: 2936.11 seconds.
# Processed 447 out of 5000. Estimated time remaining: 2934.61 seconds.
# Processed 448 out of 5000. Estimated time remaining: 2933.97 seconds.
# Processed 449 out of 5000. Estimated time remaining: 2932.98 seconds.
# Processed 450 out of 5000. Estimated time remaining: 2937.22 seconds.
# Processed 451 out of 5000. Estimated time remaining: 2941.65 seconds.
# Processed 452 out of 5000. Estimated time remaining: 2943.95 seconds.
# Processed 453 out of 5000. Estimated time remaining: 2946.27 seconds.
# Processed 454 out of 5000. Estimated time remaining: 2951.54 seconds.
# Processed 455 out of 5000. Estimated time remaining: 2952.90 seconds.
# Processed 456 out of 5000. Estimated time remaining: 2957.33 seconds.
# Processed 457 out of 5000. Estimated time remaining: 2960.59 seconds.
# Processed 458 out of 5000. Estimated time remaining: 2963.47 seconds.
# Processed 459 out of 5000. Estimated time remaining: 2962.87 seconds.
# Processed 460 out of 5000. Estimated time remaining: 2967.68 seconds.
# Processed 461 out of 5000. Estimated time remaining: 2973.34 seconds.
# Processed 462 out of 5000. Estimated time remaining: 2975.83 seconds.
# Processed 463 out of 5000. Estimated time remaining: 2978.07 seconds.
# Processed 464 out of 5000. Estimated time remaining: 2981.23 seconds.
# Processed 465 out of 5000. Estimated time remaining: 2985.21 seconds.
# Processed 466 out of 5000. Estimated time remaining: 2987.96 seconds.
# Processed 467 out of 5000. Estimated time remaining: 2989.89 seconds.
# Processed 468 out of 5000. Estimated time remaining: 2992.29 seconds.
# Processed 469 out of 5000. Estimated time remaining: 2997.31 seconds.
# Processed 470 out of 5000. Estimated time remaining: 3006.20 seconds.
# Processed 471 out of 5000. Estimated time remaining: 3012.22 seconds.
# Processed 472 out of 5000. Estimated time remaining: 3017.09 seconds.
# Processed 473 out of 5000. Estimated time remaining: 3022.14 seconds.
# Processed 474 out of 5000. Estimated time remaining: 3026.13 seconds.
# Processed 475 out of 5000. Estimated time remaining: 3028.22 seconds.
# Processed 476 out of 5000. Estimated time remaining: 3029.61 seconds.
# Processed 477 out of 5000. Estimated time remaining: 3033.60 seconds.
# Processed 478 out of 5000. Estimated time remaining: 3039.29 seconds.
# Processed 479 out of 5000. Estimated time remaining: 3041.19 seconds.
# Processed 480 out of 5000. Estimated time remaining: 3045.67 seconds.
# Processed 481 out of 5000. Estimated time remaining: 3050.24 seconds.
# Processed 482 out of 5000. Estimated time remaining: 3053.02 seconds.
# Processed 483 out of 5000. Estimated time remaining: 3055.29 seconds.
# Processed 484 out of 5000. Estimated time remaining: 3056.74 seconds.
# Processed 485 out of 5000. Estimated time remaining: 3057.22 seconds.
# Processed 486 out of 5000. Estimated time remaining: 3058.91 seconds.
# Processed 487 out of 5000. Estimated time remaining: 3062.60 seconds.
# Processed 488 out of 5000. Estimated time remaining: 3065.10 seconds.
# Processed 489 out of 5000. Estimated time remaining: 3067.86 seconds.
# Processed 490 out of 5000. Estimated time remaining: 3075.55 seconds.
# Processed 491 out of 5000. Estimated time remaining: 3078.70 seconds.
# Processed 492 out of 5000. Estimated time remaining: 3082.96 seconds.
# Processed 493 out of 5000. Estimated time remaining: 3085.72 seconds.
# Processed 494 out of 5000. Estimated time remaining: 3089.47 seconds.
# Processed 495 out of 5000. Estimated time remaining: 3093.84 seconds.
# Processed 496 out of 5000. Estimated time remaining: 3095.76 seconds.
# Processed 497 out of 5000. Estimated time remaining: 3098.39 seconds.
# Processed 498 out of 5000. Estimated time remaining: 3101.92 seconds.
# Processed 499 out of 5000. Estimated time remaining: 3105.82 seconds.
# Processed 500 out of 5000. Estimated time remaining: 3110.44 seconds.
# Processed 501 out of 5000. Estimated time remaining: 3112.55 seconds.
# Processed 502 out of 5000. Estimated time remaining: 3116.61 seconds.
# Processed 503 out of 5000. Estimated time remaining: 3119.27 seconds.
# Processed 504 out of 5000. Estimated time remaining: 3119.18 seconds.
# Processed 505 out of 5000. Estimated time remaining: 3125.28 seconds.
# Processed 506 out of 5000. Estimated time remaining: 3131.40 seconds.
# Processed 507 out of 5000. Estimated time remaining: 3135.02 seconds.
# Processed 508 out of 5000. Estimated time remaining: 3135.06 seconds.
# Processed 509 out of 5000. Estimated time remaining: 3137.86 seconds.
# Processed 510 out of 5000. Estimated time remaining: 3138.90 seconds.
# Processed 511 out of 5000. Estimated time remaining: 3141.86 seconds.
# Processed 512 out of 5000. Estimated time remaining: 3143.74 seconds.
# Processed 513 out of 5000. Estimated time remaining: 3148.65 seconds.
# Processed 514 out of 5000. Estimated time remaining: 3150.66 seconds.
# Processed 515 out of 5000. Estimated time remaining: 3154.33 seconds.
# Processed 516 out of 5000. Estimated time remaining: 3158.63 seconds.
# Processed 517 out of 5000. Estimated time remaining: 3161.01 seconds.
# Processed 518 out of 5000. Estimated time remaining: 3162.45 seconds.
# Processed 519 out of 5000. Estimated time remaining: 3167.40 seconds.
# Processed 520 out of 5000. Estimated time remaining: 3172.32 seconds.
# Processed 521 out of 5000. Estimated time remaining: 3173.17 seconds.
# Processed 522 out of 5000. Estimated time remaining: 3176.31 seconds.
# Processed 523 out of 5000. Estimated time remaining: 3180.49 seconds.
# Processed 524 out of 5000. Estimated time remaining: 3184.37 seconds.
# Processed 525 out of 5000. Estimated time remaining: 3188.33 seconds.
# Processed 526 out of 5000. Estimated time remaining: 3192.59 seconds.
# Processed 527 out of 5000. Estimated time remaining: 3195.04 seconds.
# Processed 528 out of 5000. Estimated time remaining: 3200.70 seconds.
# Processed 529 out of 5000. Estimated time remaining: 3204.55 seconds.
# Processed 530 out of 5000. Estimated time remaining: 3206.87 seconds.
# Processed 531 out of 5000. Estimated time remaining: 3210.40 seconds.
# Processed 532 out of 5000. Estimated time remaining: 3216.27 seconds.
# Processed 533 out of 5000. Estimated time remaining: 3219.47 seconds.
# Processed 534 out of 5000. Estimated time remaining: 3220.04 seconds.
# Processed 535 out of 5000. Estimated time remaining: 3224.27 seconds.
# Processed 536 out of 5000. Estimated time remaining: 3224.43 seconds.
# Processed 537 out of 5000. Estimated time remaining: 3226.25 seconds.
# Processed 538 out of 5000. Estimated time remaining: 3230.00 seconds.
# Processed 539 out of 5000. Estimated time remaining: 3234.52 seconds.
# Processed 540 out of 5000. Estimated time remaining: 3234.23 seconds.
# Processed 541 out of 5000. Estimated time remaining: 3236.27 seconds.
# Processed 542 out of 5000. Estimated time remaining: 3239.32 seconds.
# Processed 543 out of 5000. Estimated time remaining: 3239.79 seconds.
# Processed 544 out of 5000. Estimated time remaining: 3240.36 seconds.
# Processed 545 out of 5000. Estimated time remaining: 3244.44 seconds.
# Processed 546 out of 5000. Estimated time remaining: 3246.34 seconds.
# Processed 547 out of 5000. Estimated time remaining: 3248.44 seconds.
# Processed 548 out of 5000. Estimated time remaining: 3251.05 seconds.
# Processed 549 out of 5000. Estimated time remaining: 3252.46 seconds.
# Processed 550 out of 5000. Estimated time remaining: 3255.02 seconds.
# Processed 551 out of 5000. Estimated time remaining: 3256.63 seconds.
# Processed 552 out of 5000. Estimated time remaining: 3259.09 seconds.
# Processed 553 out of 5000. Estimated time remaining: 3260.28 seconds.
# Processed 554 out of 5000. Estimated time remaining: 3263.96 seconds.
# Processed 555 out of 5000. Estimated time remaining: 3268.27 seconds.
# Processed 556 out of 5000. Estimated time remaining: 3273.07 seconds.
# Processed 557 out of 5000. Estimated time remaining: 3272.83 seconds.
# Processed 558 out of 5000. Estimated time remaining: 3277.41 seconds.
# Processed 559 out of 5000. Estimated time remaining: 3279.05 seconds.
# Processed 560 out of 5000. Estimated time remaining: 3284.23 seconds.
# Processed 561 out of 5000. Estimated time remaining: 3288.76 seconds.
# Processed 562 out of 5000. Estimated time remaining: 3289.63 seconds.
# Processed 563 out of 5000. Estimated time remaining: 3292.75 seconds.
# Processed 564 out of 5000. Estimated time remaining: 3293.61 seconds.
# Processed 565 out of 5000. Estimated time remaining: 3297.26 seconds.
# Processed 566 out of 5000. Estimated time remaining: 3299.09 seconds.
# Processed 567 out of 5000. Estimated time remaining: 3301.98 seconds.
# Processed 568 out of 5000. Estimated time remaining: 3303.79 seconds.
# Processed 569 out of 5000. Estimated time remaining: 3307.33 seconds.
# Processed 570 out of 5000. Estimated time remaining: 3310.15 seconds.
# Processed 571 out of 5000. Estimated time remaining: 3312.14 seconds.
# Processed 572 out of 5000. Estimated time remaining: 3315.71 seconds.
# Processed 573 out of 5000. Estimated time remaining: 3319.74 seconds.
# Processed 574 out of 5000. Estimated time remaining: 3322.76 seconds.
# Processed 575 out of 5000. Estimated time remaining: 3325.15 seconds.
# Processed 576 out of 5000. Estimated time remaining: 3329.61 seconds.
# Processed 577 out of 5000. Estimated time remaining: 3333.81 seconds.
# Processed 578 out of 5000. Estimated time remaining: 3337.08 seconds.
# Processed 579 out of 5000. Estimated time remaining: 3337.78 seconds.
# Processed 580 out of 5000. Estimated time remaining: 3342.67 seconds.
# Processed 581 out of 5000. Estimated time remaining: 3344.74 seconds.
# Processed 582 out of 5000. Estimated time remaining: 3345.93 seconds.
# Processed 583 out of 5000. Estimated time remaining: 3347.27 seconds.
# Processed 584 out of 5000. Estimated time remaining: 3348.38 seconds.
# Processed 585 out of 5000. Estimated time remaining: 3351.90 seconds.
# Processed 586 out of 5000. Estimated time remaining: 3354.14 seconds.
# Processed 587 out of 5000. Estimated time remaining: 3354.58 seconds.
# Processed 588 out of 5000. Estimated time remaining: 3356.06 seconds.
# Processed 589 out of 5000. Estimated time remaining: 3358.54 seconds.
# Processed 590 out of 5000. Estimated time remaining: 3358.69 seconds.
# Processed 591 out of 5000. Estimated time remaining: 3361.06 seconds.
# Processed 592 out of 5000. Estimated time remaining: 3360.95 seconds.
# Processed 593 out of 5000. Estimated time remaining: 3362.27 seconds.
# Processed 594 out of 5000. Estimated time remaining: 3363.94 seconds.
# Processed 595 out of 5000. Estimated time remaining: 3366.01 seconds.
# Processed 596 out of 5000. Estimated time remaining: 3369.42 seconds.
# Processed 597 out of 5000. Estimated time remaining: 3369.83 seconds.
# Processed 598 out of 5000. Estimated time remaining: 3370.93 seconds.
# Processed 599 out of 5000. Estimated time remaining: 3371.46 seconds.
# Processed 600 out of 5000. Estimated time remaining: 3373.39 seconds.
# Processed 601 out of 5000. Estimated time remaining: 3374.97 seconds.
# Processed 602 out of 5000. Estimated time remaining: 3375.38 seconds.
# Processed 603 out of 5000. Estimated time remaining: 3378.47 seconds.
# Processed 604 out of 5000. Estimated time remaining: 3379.16 seconds.
# Processed 605 out of 5000. Estimated time remaining: 3381.20 seconds.
# Processed 606 out of 5000. Estimated time remaining: 3379.80 seconds.
# Processed 607 out of 5000. Estimated time remaining: 3382.12 seconds.
# Processed 608 out of 5000. Estimated time remaining: 3386.00 seconds.
# Processed 609 out of 5000. Estimated time remaining: 3388.48 seconds.
# Processed 610 out of 5000. Estimated time remaining: 3390.83 seconds.
# Processed 611 out of 5000. Estimated time remaining: 3392.22 seconds.
# Processed 612 out of 5000. Estimated time remaining: 3393.47 seconds.
# Processed 613 out of 5000. Estimated time remaining: 3394.64 seconds.
# Processed 614 out of 5000. Estimated time remaining: 3396.56 seconds.
# Processed 615 out of 5000. Estimated time remaining: 3396.77 seconds.
# Processed 616 out of 5000. Estimated time remaining: 3395.92 seconds.
# Processed 617 out of 5000. Estimated time remaining: 3397.20 seconds.
# Processed 618 out of 5000. Estimated time remaining: 3396.05 seconds.
# Processed 619 out of 5000. Estimated time remaining: 3395.54 seconds.
# Processed 620 out of 5000. Estimated time remaining: 3394.81 seconds.
# Processed 621 out of 5000. Estimated time remaining: 3394.42 seconds.
# Processed 622 out of 5000. Estimated time remaining: 3396.06 seconds.
# Processed 623 out of 5000. Estimated time remaining: 3396.59 seconds.
# Processed 624 out of 5000. Estimated time remaining: 3396.66 seconds.
# Processed 625 out of 5000. Estimated time remaining: 3397.76 seconds.
# Processed 626 out of 5000. Estimated time remaining: 3398.29 seconds.
# Processed 627 out of 5000. Estimated time remaining: 3399.64 seconds.
# Processed 628 out of 5000. Estimated time remaining: 3402.37 seconds.
# Processed 629 out of 5000. Estimated time remaining: 3404.59 seconds.
# Processed 630 out of 5000. Estimated time remaining: 3406.85 seconds.
# Processed 631 out of 5000. Estimated time remaining: 3408.57 seconds.
# Processed 632 out of 5000. Estimated time remaining: 3413.64 seconds.
# Processed 633 out of 5000. Estimated time remaining: 3415.89 seconds.
# Processed 634 out of 5000. Estimated time remaining: 3417.88 seconds.
# Processed 635 out of 5000. Estimated time remaining: 3419.68 seconds.
# Processed 636 out of 5000. Estimated time remaining: 3422.15 seconds.
# Processed 637 out of 5000. Estimated time remaining: 3424.02 seconds.
# Processed 638 out of 5000. Estimated time remaining: 3426.02 seconds.
# Processed 639 out of 5000. Estimated time remaining: 3426.39 seconds.
# Processed 640 out of 5000. Estimated time remaining: 3426.65 seconds.
# Processed 641 out of 5000. Estimated time remaining: 3425.99 seconds.
# Processed 642 out of 5000. Estimated time remaining: 3427.60 seconds.
# Processed 643 out of 5000. Estimated time remaining: 3429.01 seconds.
# Processed 644 out of 5000. Estimated time remaining: 3430.68 seconds.
# Processed 645 out of 5000. Estimated time remaining: 3432.41 seconds.
# Processed 646 out of 5000. Estimated time remaining: 3433.38 seconds.
# Processed 647 out of 5000. Estimated time remaining: 3435.02 seconds.
# Processed 648 out of 5000. Estimated time remaining: 3435.64 seconds.
# Processed 649 out of 5000. Estimated time remaining: 3437.92 seconds.
# Processed 650 out of 5000. Estimated time remaining: 3439.90 seconds.
# Processed 651 out of 5000. Estimated time remaining: 3439.68 seconds.
# Processed 652 out of 5000. Estimated time remaining: 3441.62 seconds.
# Processed 653 out of 5000. Estimated time remaining: 3441.12 seconds.
# Processed 654 out of 5000. Estimated time remaining: 3442.97 seconds.
# Processed 655 out of 5000. Estimated time remaining: 3444.80 seconds.
# Processed 656 out of 5000. Estimated time remaining: 3445.25 seconds.
# Processed 657 out of 5000. Estimated time remaining: 3447.53 seconds.
# Processed 658 out of 5000. Estimated time remaining: 3449.39 seconds.
# Processed 659 out of 5000. Estimated time remaining: 3448.88 seconds.
# Processed 660 out of 5000. Estimated time remaining: 3449.47 seconds.
# Processed 661 out of 5000. Estimated time remaining: 3450.07 seconds.
# Processed 662 out of 5000. Estimated time remaining: 3450.65 seconds.
# Processed 663 out of 5000. Estimated time remaining: 3450.09 seconds.
# Processed 664 out of 5000. Estimated time remaining: 3451.27 seconds.
# Processed 665 out of 5000. Estimated time remaining: 3450.67 seconds.
# Processed 666 out of 5000. Estimated time remaining: 3451.84 seconds.
# Processed 667 out of 5000. Estimated time remaining: 3453.72 seconds.
# Processed 668 out of 5000. Estimated time remaining: 3455.31 seconds.
# Processed 669 out of 5000. Estimated time remaining: 3456.72 seconds.
# Processed 670 out of 5000. Estimated time remaining: 3457.34 seconds.
# Processed 671 out of 5000. Estimated time remaining: 3457.68 seconds.
# Processed 672 out of 5000. Estimated time remaining: 3458.25 seconds.
# Processed 673 out of 5000. Estimated time remaining: 3458.15 seconds.
# Processed 674 out of 5000. Estimated time remaining: 3460.03 seconds.
# Processed 675 out of 5000. Estimated time remaining: 3460.55 seconds.
# Processed 676 out of 5000. Estimated time remaining: 3461.24 seconds.
# Processed 677 out of 5000. Estimated time remaining: 3460.14 seconds.
# Processed 678 out of 5000. Estimated time remaining: 3459.54 seconds.
# Processed 679 out of 5000. Estimated time remaining: 3460.36 seconds.
# Processed 680 out of 5000. Estimated time remaining: 3460.87 seconds.
# Processed 681 out of 5000. Estimated time remaining: 3461.79 seconds.
# Processed 682 out of 5000. Estimated time remaining: 3463.07 seconds.
# Processed 683 out of 5000. Estimated time remaining: 3464.88 seconds.
# Processed 684 out of 5000. Estimated time remaining: 3466.72 seconds.
# Processed 685 out of 5000. Estimated time remaining: 3466.46 seconds.
# Processed 686 out of 5000. Estimated time remaining: 3466.50 seconds.
# Processed 687 out of 5000. Estimated time remaining: 3468.19 seconds.
# ...
# Processed 4770 out of 5000. Estimated time remaining: 146.82 seconds.
# Processed 4771 out of 5000. Estimated time remaining: 146.18 seconds.
# Processed 4772 out of 5000. Estimated time remaining: 145.54 seconds.
# Processed 4773 out of 5000. Estimated time remaining: 144.90 seconds.
# Processed 4774 out of 5000. Estimated time remaining: 144.26 seconds.
# Processed 4775 out of 5000. Estimated time remaining: 143.62 seconds.
# Processed 4776 out of 5000. Estimated time remaining: 142.98 seconds.
# Processed 4777 out of 5000. Estimated time remaining: 142.34 seconds.
# Processed 4778 out of 5000. Estimated time remaining: 141.70 seconds.
# Processed 4779 out of 5000. Estimated time remaining: 141.06 seconds.
# Processed 4780 out of 5000. Estimated time remaining: 140.42 seconds.
# Processed 4781 out of 5000. Estimated time remaining: 139.77 seconds.
# Processed 4782 out of 5000. Estimated time remaining: 139.13 seconds.
# Processed 4783 out of 5000. Estimated time remaining: 138.49 seconds.
# Processed 4784 out of 5000. Estimated time remaining: 137.85 seconds.
# Processed 4785 out of 5000. Estimated time remaining: 137.21 seconds.
# Processed 4786 out of 5000. Estimated time remaining: 136.57 seconds.
# Processed 4787 out of 5000. Estimated time remaining: 135.93 seconds.
# Processed 4788 out of 5000. Estimated time remaining: 135.29 seconds.
# Processed 4789 out of 5000. Estimated time remaining: 134.65 seconds.
# Processed 4790 out of 5000. Estimated time remaining: 134.01 seconds.
# Processed 4791 out of 5000. Estimated time remaining: 133.37 seconds.
# Processed 4792 out of 5000. Estimated time remaining: 132.73 seconds.
# Processed 4793 out of 5000. Estimated time remaining: 132.09 seconds.
# Processed 4794 out of 5000. Estimated time remaining: 131.45 seconds.
# Processed 4795 out of 5000. Estimated time remaining: 130.81 seconds.
# Processed 4796 out of 5000. Estimated time remaining: 130.17 seconds.
# Processed 4797 out of 5000. Estimated time remaining: 129.53 seconds.
# Processed 4798 out of 5000. Estimated time remaining: 128.89 seconds.
# Processed 4799 out of 5000. Estimated time remaining: 128.25 seconds.
# Processed 4800 out of 5000. Estimated time remaining: 127.61 seconds.
# Processed 4801 out of 5000. Estimated time remaining: 126.97 seconds.
# Processed 4802 out of 5000. Estimated time remaining: 126.33 seconds.
# Processed 4803 out of 5000. Estimated time remaining: 125.70 seconds.
# Processed 4804 out of 5000. Estimated time remaining: 125.06 seconds.
# Processed 4805 out of 5000. Estimated time remaining: 124.42 seconds.
# Processed 4806 out of 5000. Estimated time remaining: 123.78 seconds.
# Processed 4807 out of 5000. Estimated time remaining: 123.14 seconds.
# Processed 4808 out of 5000. Estimated time remaining: 122.50 seconds.
# Processed 4809 out of 5000. Estimated time remaining: 121.86 seconds.
# Processed 4810 out of 5000. Estimated time remaining: 121.22 seconds.
# Processed 4811 out of 5000. Estimated time remaining: 120.58 seconds.
# Processed 4812 out of 5000. Estimated time remaining: 119.94 seconds.
# Processed 4813 out of 5000. Estimated time remaining: 119.31 seconds.
# Processed 4814 out of 5000. Estimated time remaining: 118.67 seconds.
# Processed 4815 out of 5000. Estimated time remaining: 118.03 seconds.
# Processed 4816 out of 5000. Estimated time remaining: 117.39 seconds.
# Processed 4817 out of 5000. Estimated time remaining: 116.75 seconds.
# Processed 4818 out of 5000. Estimated time remaining: 116.11 seconds.
# Processed 4819 out of 5000. Estimated time remaining: 115.47 seconds.
# Processed 4820 out of 5000. Estimated time remaining: 114.83 seconds.
# Processed 4821 out of 5000. Estimated time remaining: 114.19 seconds.
# Processed 4822 out of 5000. Estimated time remaining: 113.55 seconds.
# Processed 4823 out of 5000. Estimated time remaining: 112.91 seconds.
# Processed 4824 out of 5000. Estimated time remaining: 112.27 seconds.
# Processed 4825 out of 5000. Estimated time remaining: 111.63 seconds.
# Processed 4826 out of 5000. Estimated time remaining: 110.99 seconds.
# Processed 4827 out of 5000. Estimated time remaining: 110.35 seconds.
# Processed 4828 out of 5000. Estimated time remaining: 109.71 seconds.
# Processed 4829 out of 5000. Estimated time remaining: 109.08 seconds.
# Processed 4830 out of 5000. Estimated time remaining: 108.44 seconds.
# Processed 4831 out of 5000. Estimated time remaining: 107.80 seconds.
# Processed 4832 out of 5000. Estimated time remaining: 107.16 seconds.
# Processed 4833 out of 5000. Estimated time remaining: 106.52 seconds.
# Processed 4834 out of 5000. Estimated time remaining: 105.88 seconds.
# Processed 4835 out of 5000. Estimated time remaining: 105.24 seconds.
# Processed 4836 out of 5000. Estimated time remaining: 104.60 seconds.
# Processed 4837 out of 5000. Estimated time remaining: 103.97 seconds.
# Processed 4838 out of 5000. Estimated time remaining: 103.33 seconds.
# Processed 4839 out of 5000. Estimated time remaining: 102.70 seconds.
# Processed 4840 out of 5000. Estimated time remaining: 102.06 seconds.
# Processed 4841 out of 5000. Estimated time remaining: 101.42 seconds.
# Processed 4842 out of 5000. Estimated time remaining: 100.78 seconds.
# Processed 4843 out of 5000. Estimated time remaining: 100.14 seconds.
# Processed 4844 out of 5000. Estimated time remaining: 99.50 seconds.
# Processed 4845 out of 5000. Estimated time remaining: 98.86 seconds.
# Processed 4846 out of 5000. Estimated time remaining: 98.23 seconds.
# Processed 4847 out of 5000. Estimated time remaining: 97.59 seconds.
# Processed 4848 out of 5000. Estimated time remaining: 96.95 seconds.
# Processed 4849 out of 5000. Estimated time remaining: 96.31 seconds.
# Processed 4850 out of 5000. Estimated time remaining: 95.67 seconds.
# Processed 4851 out of 5000. Estimated time remaining: 95.03 seconds.
# Processed 4852 out of 5000. Estimated time remaining: 94.39 seconds.
# Processed 4853 out of 5000. Estimated time remaining: 93.75 seconds.
# Processed 4854 out of 5000. Estimated time remaining: 93.11 seconds.
# Processed 4855 out of 5000. Estimated time remaining: 92.47 seconds.
# Processed 4856 out of 5000. Estimated time remaining: 91.83 seconds.
# Processed 4857 out of 5000. Estimated time remaining: 91.19 seconds.
# Processed 4858 out of 5000. Estimated time remaining: 90.56 seconds.
# Processed 4859 out of 5000. Estimated time remaining: 89.92 seconds.
# Processed 4860 out of 5000. Estimated time remaining: 89.28 seconds.
# Processed 4861 out of 5000. Estimated time remaining: 88.64 seconds.
# Processed 4862 out of 5000. Estimated time remaining: 88.00 seconds.
# Processed 4863 out of 5000. Estimated time remaining: 87.36 seconds.
# Processed 4864 out of 5000. Estimated time remaining: 86.72 seconds.
# Processed 4865 out of 5000. Estimated time remaining: 86.08 seconds.
# Processed 4866 out of 5000. Estimated time remaining: 85.44 seconds.
# Processed 4867 out of 5000. Estimated time remaining: 84.80 seconds.
# Processed 4868 out of 5000. Estimated time remaining: 84.17 seconds.
# Processed 4869 out of 5000. Estimated time remaining: 83.53 seconds.
# Processed 4870 out of 5000. Estimated time remaining: 82.89 seconds.
# Processed 4871 out of 5000. Estimated time remaining: 82.25 seconds.
# Processed 4872 out of 5000. Estimated time remaining: 81.61 seconds.
# Processed 4873 out of 5000. Estimated time remaining: 80.98 seconds.
# Processed 4874 out of 5000. Estimated time remaining: 80.34 seconds.
# Processed 4875 out of 5000. Estimated time remaining: 79.70 seconds.
# Processed 4876 out of 5000. Estimated time remaining: 79.06 seconds.
# Processed 4877 out of 5000. Estimated time remaining: 78.42 seconds.
# Processed 4878 out of 5000. Estimated time remaining: 77.78 seconds.
# Processed 4879 out of 5000. Estimated time remaining: 77.14 seconds.
# Processed 4880 out of 5000. Estimated time remaining: 76.50 seconds.
# Processed 4881 out of 5000. Estimated time remaining: 75.86 seconds.
# Processed 4882 out of 5000. Estimated time remaining: 75.22 seconds.
# Processed 4883 out of 5000. Estimated time remaining: 74.58 seconds.
# Processed 4884 out of 5000. Estimated time remaining: 73.95 seconds.
# Processed 4885 out of 5000. Estimated time remaining: 73.31 seconds.
# Processed 4886 out of 5000. Estimated time remaining: 72.67 seconds.
# Processed 4887 out of 5000. Estimated time remaining: 72.03 seconds.
# Processed 4888 out of 5000. Estimated time remaining: 71.39 seconds.
# Processed 4889 out of 5000. Estimated time remaining: 70.76 seconds.
# Processed 4890 out of 5000. Estimated time remaining: 70.12 seconds.
# Processed 4891 out of 5000. Estimated time remaining: 69.48 seconds.
# Processed 4892 out of 5000. Estimated time remaining: 68.84 seconds.
# Processed 4893 out of 5000. Estimated time remaining: 68.21 seconds.
# Processed 4894 out of 5000. Estimated time remaining: 67.57 seconds.
# Processed 4895 out of 5000. Estimated time remaining: 66.93 seconds.
# Processed 4896 out of 5000. Estimated time remaining: 66.29 seconds.
# Processed 4897 out of 5000. Estimated time remaining: 65.65 seconds.
# Processed 4898 out of 5000. Estimated time remaining: 65.01 seconds.
# Processed 4899 out of 5000. Estimated time remaining: 64.37 seconds.
# Processed 4900 out of 5000. Estimated time remaining: 63.74 seconds.
# Processed 4901 out of 5000. Estimated time remaining: 63.10 seconds.
# Processed 4902 out of 5000. Estimated time remaining: 62.46 seconds.
# Processed 4903 out of 5000. Estimated time remaining: 61.82 seconds.
# Processed 4904 out of 5000. Estimated time remaining: 61.19 seconds.
# Processed 4905 out of 5000. Estimated time remaining: 60.55 seconds.
# Processed 4906 out of 5000. Estimated time remaining: 59.91 seconds.
# Processed 4907 out of 5000. Estimated time remaining: 59.27 seconds.
# Processed 4908 out of 5000. Estimated time remaining: 58.63 seconds.
# Processed 4909 out of 5000. Estimated time remaining: 58.00 seconds.
# Processed 4910 out of 5000. Estimated time remaining: 57.36 seconds.
# Processed 4911 out of 5000. Estimated time remaining: 56.72 seconds.
# Processed 4912 out of 5000. Estimated time remaining: 56.08 seconds.
# Processed 4913 out of 5000. Estimated time remaining: 55.44 seconds.
# Processed 4914 out of 5000. Estimated time remaining: 54.81 seconds.
# Processed 4915 out of 5000. Estimated time remaining: 54.17 seconds.
# Processed 4916 out of 5000. Estimated time remaining: 53.53 seconds.
# Processed 4917 out of 5000. Estimated time remaining: 52.89 seconds.
# Processed 4918 out of 5000. Estimated time remaining: 52.26 seconds.
# Processed 4919 out of 5000. Estimated time remaining: 51.62 seconds.
# Processed 4920 out of 5000. Estimated time remaining: 50.98 seconds.
# Processed 4921 out of 5000. Estimated time remaining: 50.34 seconds.
# Processed 4922 out of 5000. Estimated time remaining: 49.71 seconds.
# Processed 4923 out of 5000. Estimated time remaining: 49.07 seconds.
# Processed 4924 out of 5000. Estimated time remaining: 48.43 seconds.
# Processed 4925 out of 5000. Estimated time remaining: 47.79 seconds.
# Processed 4926 out of 5000. Estimated time remaining: 47.16 seconds.
# Processed 4927 out of 5000. Estimated time remaining: 46.52 seconds.
# Processed 4928 out of 5000. Estimated time remaining: 45.88 seconds.
# Processed 4929 out of 5000. Estimated time remaining: 45.24 seconds.
# Processed 4930 out of 5000. Estimated time remaining: 44.61 seconds.
# Processed 4931 out of 5000. Estimated time remaining: 43.97 seconds.
# Processed 4932 out of 5000. Estimated time remaining: 43.33 seconds.
# Processed 4933 out of 5000. Estimated time remaining: 42.69 seconds.
# Processed 4934 out of 5000. Estimated time remaining: 42.05 seconds.
# Processed 4935 out of 5000. Estimated time remaining: 41.42 seconds.
# Processed 4936 out of 5000. Estimated time remaining: 40.78 seconds.
# Processed 4937 out of 5000. Estimated time remaining: 40.14 seconds.
# Processed 4938 out of 5000. Estimated time remaining: 39.50 seconds.
# Processed 4939 out of 5000. Estimated time remaining: 38.87 seconds.
# Processed 4940 out of 5000. Estimated time remaining: 38.23 seconds.
# Processed 4941 out of 5000. Estimated time remaining: 37.59 seconds.
# Processed 4942 out of 5000. Estimated time remaining: 36.95 seconds.
# Processed 4943 out of 5000. Estimated time remaining: 36.32 seconds.
# Processed 4944 out of 5000. Estimated time remaining: 35.68 seconds.
# Processed 4945 out of 5000. Estimated time remaining: 35.04 seconds.
# Processed 4946 out of 5000. Estimated time remaining: 34.40 seconds.
# Processed 4947 out of 5000. Estimated time remaining: 33.77 seconds.
# Processed 4948 out of 5000. Estimated time remaining: 33.13 seconds.
# Processed 4949 out of 5000. Estimated time remaining: 32.49 seconds.
# Processed 4950 out of 5000. Estimated time remaining: 31.85 seconds.
# Processed 4951 out of 5000. Estimated time remaining: 31.22 seconds.
# Processed 4952 out of 5000. Estimated time remaining: 30.58 seconds.
# Processed 4953 out of 5000. Estimated time remaining: 29.94 seconds.
# Processed 4954 out of 5000. Estimated time remaining: 29.30 seconds.
# Processed 4955 out of 5000. Estimated time remaining: 28.67 seconds.
# Processed 4956 out of 5000. Estimated time remaining: 28.03 seconds.
# Processed 4957 out of 5000. Estimated time remaining: 27.39 seconds.
# Processed 4958 out of 5000. Estimated time remaining: 26.75 seconds.
# Processed 4959 out of 5000. Estimated time remaining: 26.12 seconds.
# Processed 4960 out of 5000. Estimated time remaining: 25.48 seconds.
# Processed 4961 out of 5000. Estimated time remaining: 24.84 seconds.
# Processed 4962 out of 5000. Estimated time remaining: 24.21 seconds.
# Processed 4963 out of 5000. Estimated time remaining: 23.57 seconds.
# Processed 4964 out of 5000. Estimated time remaining: 22.93 seconds.
# Processed 4965 out of 5000. Estimated time remaining: 22.29 seconds.
# Processed 4966 out of 5000. Estimated time remaining: 21.66 seconds.
# Processed 4967 out of 5000. Estimated time remaining: 21.02 seconds.
# Processed 4968 out of 5000. Estimated time remaining: 20.38 seconds.
# Processed 4969 out of 5000. Estimated time remaining: 19.75 seconds.
# Processed 4970 out of 5000. Estimated time remaining: 19.11 seconds.
# Processed 4971 out of 5000. Estimated time remaining: 18.47 seconds.
# Processed 4972 out of 5000. Estimated time remaining: 17.83 seconds.
# Processed 4973 out of 5000. Estimated time remaining: 17.20 seconds.
# Processed 4974 out of 5000. Estimated time remaining: 16.56 seconds.
# Processed 4975 out of 5000. Estimated time remaining: 15.92 seconds.
# Processed 4976 out of 5000. Estimated time remaining: 15.29 seconds.
# Processed 4977 out of 5000. Estimated time remaining: 14.65 seconds.
# Processed 4978 out of 5000. Estimated time remaining: 14.01 seconds.
# Processed 4979 out of 5000. Estimated time remaining: 13.37 seconds.
# Processed 4980 out of 5000. Estimated time remaining: 12.74 seconds.
# Processed 4981 out of 5000. Estimated time remaining: 12.10 seconds.
# Processed 4982 out of 5000. Estimated time remaining: 11.46 seconds.
# Processed 4983 out of 5000. Estimated time remaining: 10.83 seconds.
# Processed 4984 out of 5000. Estimated time remaining: 10.19 seconds.
# Processed 4985 out of 5000. Estimated time remaining: 9.55 seconds.
# Processed 4986 out of 5000. Estimated time remaining: 8.92 seconds.
# Processed 4987 out of 5000. Estimated time remaining: 8.28 seconds.
# Processed 4988 out of 5000. Estimated time remaining: 7.64 seconds.
# Processed 4989 out of 5000. Estimated time remaining: 7.00 seconds.
# Processed 4990 out of 5000. Estimated time remaining: 6.37 seconds.
# Processed 4991 out of 5000. Estimated time remaining: 5.73 seconds.
# Processed 4992 out of 5000. Estimated time remaining: 5.09 seconds.
# Processed 4993 out of 5000. Estimated time remaining: 4.46 seconds.
# Processed 4994 out of 5000. Estimated time remaining: 3.82 seconds.
# Processed 4995 out of 5000. Estimated time remaining: 3.18 seconds.
# Processed 4996 out of 5000. Estimated time remaining: 2.55 seconds.
# Processed 4997 out of 5000. Estimated time remaining: 1.91 seconds.
# Processed 4998 out of 5000. Estimated time remaining: 1.27 seconds.
# Processed 4999 out of 5000. Estimated time remaining: 0.64 seconds.
# Processed 5000 out of 5000. Estimated time remaining: 0.00 seconds.
